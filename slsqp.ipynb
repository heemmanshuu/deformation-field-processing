# %%
# %load_ext autoreload
# %autoreload 2

# 3rd party imports
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
np.set_printoptions(linewidth=1000)

from scipy.optimize import minimize


# Local imports
import modules.laplacian as laplacian
import modules.jacobian as jacobian
import modules.correspondences as correspondences

import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Iterative SLSQP

# %%
# define helper functions

def idx_adjacency(shape):
    idx_adj = {}
    for z in range(shape[0]):
        for y in range(shape[1]):
            for x in range(shape[2]):
                l_idx = laplacian.get_laplacian_index(z, y, x, shape)
                adjacent_indices = laplacian.get_adjacent_indices(z, y, x, shape)
                idx_adj[l_idx] = adjacent_indices
    return idx_adj

# Define the objective function
def objective(phi, A_, b_):
    return np.linalg.norm(A_ @ phi - b_)**2

# Define the objective function
def objective2(phi, phi_init, A_, b_):
    return np.linalg.norm(phi - phi_init) + np.linalg.norm(A_ @ phi - b_)

def objective3(phi, phi_init, A_, b_):
    return np.linalg.norm(phi - phi_init)

def objectiveLapl(phi, phi_init, A_, b_):
    return np.linalg.norm(phi - phi_init, ord=1) + np.linalg.norm(A_ @ phi - b_)

def objectiveLapl2(phi, phi_init, A_, b_):
    return np.linalg.norm(phi - phi_init, ord=1)


def nearest_center(shape, n):
    near_cent = {}
    for z in range(shape[0]):
        for y in range(shape[1]):
            for x in range(shape[2]):
                l_idx = laplacian.get_laplacian_index(z, y, x, shape)
                z_cent = z
                y_cent = y
                x_cent = x
                if (x-n < 0):
                    x_cent = n
                elif (shape[2]-x < n+1):
                    x_cent = shape[2]-n-1

                if (y-n < 0):
                    y_cent = n
                elif (shape[1]-y < n):
                    y_cent = shape[1]-n-1
                center_indices = [z, y_cent, x_cent]
                near_cent[l_idx] = center_indices
                # print("Nearest center values for index ", l_idx, center_indices)
    return near_cent

def original_coordinates(shape):
    ori_coord = {}
    for z in range(shape[0]):
        for y in range(shape[1]):
            for x in range(shape[2]):
                ori_coord[z * shape[1] * shape[2] + y * shape[2] + x] = (z,y,x)
    return ori_coord


def get_phi_sub(phi, cz, cy, cx, shape, d):
    phix = phi[1, cy-d:cy+d+1, cx-d:cx+d+1]
    phiy = phi[0, cy-d:cy+d+1, cx-d:cx+d+1]
    return np.concatenate([phix.flatten(), phiy.flatten()])

# %%
# jacobian functions

def jacobian_det2D(phi_xy):
    deformation = np.zeros((3,1, *phi_xy.shape[-2:])    )
    deformation[2] = phi_xy[1]
    deformation[1] = phi_xy[0]
    return jacobian.sitk_jacobian_determinant(deformation)

def jdet_constraint2(phi_sub, phi, idx_sub, cx, cy, cz, submatrix_size, idx_adj, y_offset, sub_ori_coord, ori_shape, epsilon=1e-6):
    start = time.time()
    dist = submatrix_size//2
    pixels = submatrix_size*submatrix_size
    phi[1, cy-dist:cy+dist+1, cx-dist:cx+dist+1] = phi_sub[:pixels].reshape((submatrix_size, submatrix_size))
    phi[0, cy-dist:cy+dist+1, cx-dist:cx+dist+1] = phi_sub[pixels:].reshape((submatrix_size, submatrix_size))

    phi = np.concatenate([phi[1].flatten(), phi[0].flatten()])
    z,y,x = sub_ori_coord[idx_sub]
    z = z
    y = y+cy-dist
    x = x+cx-dist 

    idx = laplacian.get_laplacian_index(z,y,x, ori_shape)


    left_idx, right_idx, up_idx, down_idx = idx_adj[idx]
    
    if left_idx is None:  # Left edge
        dxx = (phi[right_idx] - phi[idx]) / 2
        dyx = (phi[right_idx + y_offset] - phi[idx + y_offset]) / 2
    elif right_idx is None:  # Right edge
        dxx = (phi[idx] - phi[left_idx]) / 2
        dyx = (phi[idx + y_offset] - phi[left_idx + y_offset]) / 2
    else: 
        dxx = (phi[right_idx] - phi[left_idx]) / 2
        dyx = (phi[right_idx + y_offset] - phi[left_idx + y_offset]) / 2
    
    if up_idx is None:  # Top edge
        dyy = (phi[down_idx + y_offset] - phi[idx + y_offset]) / 2
        dxy = (phi[down_idx] - phi[idx]) / 2
    elif down_idx is None:  # Bottom edge
        dyy = (phi[idx + y_offset] - phi[up_idx + y_offset]) / 2
        dxy = (phi[idx] - phi[up_idx]) / 2
    else:
        dyy = (phi[down_idx + y_offset] - phi[up_idx + y_offset]) / 2
        dxy = (phi[down_idx] - phi[up_idx]) / 2
    
    end = time.time()
    # print(f'Jdet computed in {end-start}s')
    # print(f'jdet2 for {z,y,x} - {dxx, dyy, dxy, dyx}')
    return ((dxx + 1) * (dyy + 1)) - (dxy * dyx) - epsilon

def jdet_constraint3(phi, cx, cy, cz, submatrix_size, ori_shape, epsilon=1e-6):
    constraints = []
    dist = submatrix_size//2
    for zi in range(1):
        for yi in range(cy-dist, cy+dist+1):
            for xi in range(cx-dist, cx+dist+1):
                constraints += [{'type': 'ineq', 'fun': lambda phi1: compute_jdet_for_pixel(phi1, phi, dist, zi, yi, xi, cz, cy, cx, submatrix_size, ori_shape, epsilon)}]

    return constraints


def compute_jdet_for_pixel(phi1, phi, dist, zi, yi, xi, cz, cy, cx, submatrix_size, ori_shape, epsilon=1e-6):
    # see if there is a way out of reshaping the submatrix too
    
    start = time.time()
    pixels = submatrix_size*submatrix_size
    phi_sub = np.zeros((2, submatrix_size, submatrix_size))
    phi_sub[1] = phi1[:pixels].reshape((submatrix_size, submatrix_size))
    phi_sub[0] = phi1[pixels:].reshape((submatrix_size, submatrix_size))
    
    left = xi-1
    right = xi+1
    top = yi-1
    bottom = yi+1
    
    xi_sub = xi-cx+dist
    left_sub = left-cx+dist
    right_sub = right-cx+dist

    yi_sub = yi-cy+dist
    top_sub = top-cy+dist
    bottom_sub = bottom-cy+dist

    # print(f'boundaries: {cx-dist, left, right, cx+dist, ori_shape[-1], cy-dist, top, bottom, cy+dist, ori_shape[-2]}')
    if left < cx-dist: # left edge of sub
        if left < 0: # leftmost edge
            dxx = (phi_sub[1, yi_sub, right_sub] - phi_sub[1, yi_sub, xi_sub]) / 2
            dyx = (phi_sub[0, yi_sub, right_sub] - phi_sub[0, yi_sub, xi_sub]) / 2
        else:
            dxx = (phi_sub[1, yi_sub, right_sub] - phi[1, yi, left]) / 2
            dyx = (phi_sub[0, yi_sub, right_sub] - phi[0, yi, left]) / 2
    else:
        if right > cx+dist: # right edge of sub
            if right > ori_shape[-1]-1: # rightmost edge
                dxx = (phi_sub[1, yi_sub, xi_sub] - phi_sub[1, yi_sub, left_sub]) / 2
                dyx = (phi_sub[0, yi_sub, xi_sub] - phi_sub[0, yi_sub, left_sub]) / 2
            else:
                # print(f'{yi, right, left_sub}')
                dxx = (phi[1, yi, right] - phi_sub[1, yi_sub, left_sub]) / 2
                dyx = (phi[0, yi, right] - phi_sub[0, yi_sub, left_sub]) / 2
        else: # inside the submatrix
            dxx = (phi_sub[1, yi_sub, right_sub] - phi_sub[1, yi_sub, left_sub]) / 2
            dyx = (phi_sub[0, yi_sub, right_sub] - phi_sub[0, yi_sub, left_sub]) / 2

    if top < cy-dist: # top edge of sub
        if top < 0: # topmost edge
            dxy = (phi_sub[1, bottom_sub, xi_sub] - phi_sub[1, yi_sub, xi_sub]) / 2
            dyy = (phi_sub[0, bottom_sub, xi_sub] - phi_sub[0, yi_sub, xi_sub]) / 2
        else:
            dxy = (phi_sub[1, bottom_sub, xi_sub] - phi[1, top, xi]) / 2
            dyy = (phi_sub[0, bottom_sub, xi_sub] - phi[0, top, xi]) / 2
    else:
        if bottom > cy+dist: # bottom edge of sub
            if bottom > ori_shape[-2]-1: # bottom most edge
                dxy = (phi_sub[1, yi_sub, xi_sub] - phi_sub[1, top_sub, xi_sub]) / 2
                dyy = (phi_sub[0, yi_sub, xi_sub] - phi_sub[0, top_sub, xi_sub]) / 2
            else:
                dxy = (phi[1, bottom, xi] - phi_sub[1, top_sub, xi_sub]) / 2
                dyy = (phi[0, bottom, xi] - phi_sub[0, top_sub, xi_sub]) / 2
        else: # inside the submatrix
            dxy = (phi_sub[1, bottom_sub, xi_sub] - phi_sub[1, top_sub, xi_sub]) / 2
            dyy = (phi_sub[0, bottom_sub, xi_sub] - phi_sub[0, top_sub, xi_sub]) / 2
    end = time.time()

    # print(f'Jdet3 computed in {end-start}s')
    # print(f'jdet3 for {zi, yi_sub, xi_sub} - - {dxx, dyy, dxy, dyx}')
    return ((dxx + 1) * (dyy + 1)) - (dxy * dyx) - epsilon

# %%
def iterative_with_jacobians(deformation_i, methodName='SLSQP'):
    '''perform SLSQP on submatrices iteratively'''
    slice_shape = (1, *deformation_i.shape[-2:])

    # this phi will be updated iteratively
    phi = np.zeros((2, *deformation_i.shape[-2:]))
    phi[1] = deformation_i[-1]
    phi[0] = deformation_i[-2]
    print(f'deformation_i shape: {deformation_i.shape}, phi_init shape: {phi.shape}')
    phi_init = phi.copy()

    # set threshold for Jacobian and store results
    threshold = 0.0
    jacobians = []
    indi_times = []
    tot_start = time.time()

    # collect indices with -ve Jacobians into a list in a sorted fashion
    J_init = jacobian_det2D(phi)
    jacobians.append(J_init)
    J_init = J_init.flatten()
    neg_jacobian_indices = np.where(J_init <= threshold)[0]
    neg_jacobian_indices = neg_jacobian_indices[np.argsort(J_init[neg_jacobian_indices])].tolist()
    print(f'init: Negative Jacobians found at {neg_jacobian_indices}')

    # set values to use inside the while loop
    idx_adj = idx_adjacency(slice_shape)
    y_offset = len(J_init)//2
    # find the nearest center of a 5x5 matrix around each pixel
    submatrix_size = 5
    near_cent = nearest_center(slice_shape, submatrix_size//2)
    ori_coord = original_coordinates(slice_shape)


    sub_shape = (1,submatrix_size, submatrix_size)
    sub_ori_coord = original_coordinates(sub_shape)
    _, A_sub, b_sub = laplacian.compute3DLaplacianFromShape(sub_shape, np.empty((0,3)), np.empty((0,3)))

    visited = {}
    max_visits = 3
    ind = 0

    
    # perform optimisation for each index with negative Jacobian
    while ind < len(neg_jacobian_indices) and ind < 50:
        neg_index  = neg_jacobian_indices[ind]
        ind += 1
        # if the negative values has already been fixed, skip it
        jdet_value = jacobian_det2D(phi).flatten()[neg_index]
        if (jdet_value > threshold):
            print(f'Iter {ind}: jacobian at index {neg_index} is +ve. skip.')
            continue

        # check number of visits to this index and increase submatrix size if necessary
        visits = visited.get(neg_index, 0) + 1
        visited[neg_index] = visits

        # increase submatrix size if not sufficient
        if (visits > max_visits and submatrix_size + 2 <= min(slice_shape[1:])):
            # increase subshape and everything that depends on it
            submatrix_size+=2
            max_visits += 1
            print(f'Submatrix size is {submatrix_size} from index {neg_index}')
            near_cent = nearest_center(slice_shape, submatrix_size//2)
            ori_coord = original_coordinates(slice_shape)
            sub_shape = (1,submatrix_size, submatrix_size)
            sub_ori_coord = original_coordinates(sub_shape)
            _, A_sub, b_sub = laplacian.compute3DLaplacianFromShape(sub_shape, np.empty((0,3)), np.empty((0,3)))
        
        z,y,x = ori_coord[neg_index]
        cz, cy, cx = near_cent[neg_index]

        print(f'Iter {ind}: Analysing index {neg_index}: Original coord: {x,y,z}, nearest: {cx, cy, cz}, jdet: {jdet_value}')

        # get constraints for optimisation
        # constraints = []
        # for i_sub in range(len(b_sub)//2):
        #     constraints += [{'type': 'ineq', 'fun': lambda phi1, i=i_sub: jdet_constraint2(phi1, phi.copy(), i, cx, cy, cz, submatrix_size, idx_adj, y_offset, sub_ori_coord, slice_shape, 0.05)}]

        constraints = jdet_constraint3(phi, cx, cy, cz, submatrix_size, slice_shape, 0.05)

        op_start = time.time()

        # in objective, should i use latest phi or the very initial phi_init to penalise?
        # it is running when initial pt is new phi AND objective uses new phi!
        phi_init_sub = get_phi_sub(phi_init, cz, cy, cx, slice_shape, submatrix_size//2)
        phi_sub = get_phi_sub(phi, cz, cy, cx, slice_shape, submatrix_size//2)

        result = minimize(lambda phi1: objectiveLapl2(phi1, phi_init_sub, A_sub, b_sub), phi_sub, constraints=constraints, options={'maxiter': 1000, 'disp': True}, method=methodName)
        
        op_end = time.time()

        print(f'Optimisation for index {neg_index} completed in {op_end-op_start}s')

        indi_times.append(op_end-op_start)
        
        if result.success:
            print(f'OP result error for index {neg_index}: {result.fun}')
        else:
            print("Optimisation failed: ", result.message)

        # substitute values from computed deformation into original phi
        # b_ was XYd, so phi_x is the first half
        phi_x_res = result.x[:len(result.x) // 2].reshape(sub_shape[-2:])
        phi_y_res = result.x[len(result.x) // 2:].reshape(sub_shape[-2:])

        center_distance = submatrix_size//2
        
        phi[1, cy-center_distance:cy+center_distance+1, cx-center_distance:cx+center_distance+1] = phi_x_res
        phi[0, cy-center_distance:cy+center_distance+1, cx-center_distance:cx+center_distance+1] = phi_y_res
        
        # compute jacobian and add to list
        J = jacobian_det2D(phi)
        jacobians.append(J)

        # check for -ve jacobians in modified deformation
        J = J.flatten()
        neg_j_iter = np.where(J <= threshold)[0]
        neg_j_iter = neg_j_iter[np.argsort(J[neg_j_iter])]

        print(f'Iter {ind} end: {len(neg_j_iter)} -ve jacs now at {neg_j_iter} : SITK: {J[neg_j_iter]}')

        # add new negative jacobian indices to list
        for new_neg in neg_j_iter:
            if new_neg not in neg_jacobian_indices[ind:]:
                neg_jacobian_indices.append(new_neg)


    # compute errors
    phi_flat = np.concatenate([phi[1].flatten(), phi[0].flatten()])
    phi_init_flat = np.concatenate([phi_init[1].flatten(), phi_init[0].flatten()])

    _, A_, b_ = laplacian.compute3DLaplacianFromShape(slice_shape, np.empty((0,3)), np.empty((0,3)))
    init_error = objective2(phi_init_flat, phi_init_flat, A_, b_)
    fin_error = objective2(phi_flat, phi_init_flat, A_, b_)
    deviation = np.sqrt(np.sum((phi_flat - phi_init_flat)**2))

    tot_end = time.time()
    print(f'Total time taken for iterative SLSQP : {tot_end - tot_start} split as {indi_times}')
    print(f'Initial error: {init_error}, final error: {fin_error}, deviation: {deviation}')
    
    
    return phi, jacobians

# %%
# # Testing Jacobian computations
# msample = np.array([
#     [0, 2, 0],
#     [0, 3, 1],
#     [0, 10, 5],
#     [0, 13, 1],
#     [0, 2, 39],
#     [0, 3, 38],
#     [0, 10, 35],
#     [0, 13, 39],
# ])
# fsample = np.array([
#     [0, 2, 4],
#     [0, 3, 2],
#     [0, 10, 3],
#     [0, 11, 6],
#     [0, 2, 30],
#     [0, 3, 36],
#     [0, 10, 37],
#     [0, 11, 34]
# ])

# fixed_sample = np.zeros((1, 10, 10))

# deformation_i, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_sample, msample, fsample)
# phi = np.zeros((2, *deformation_i.shape[-2:]))
# phi[1] = deformation_i[-1]
# phi[0] = deformation_i[-2]
# phi2 = phi.copy()

# # get constraints for optimisation
# cz = 0
# cy = 5
# cx = 5
# slice_shape = fixed_sample.shape
# submatrix_size = 5
# y_offset = slice_shape[1]*slice_shape[2]

# idx_adj = idx_adjacency(slice_shape)
# phi1 = get_phi_sub(phi, cz, cy, cx, slice_shape, submatrix_size//2)

# sub_shape = (1,submatrix_size, submatrix_size)
# sub_ori_coord = original_coordinates(sub_shape)
# constraints = []

# start = time.time()
# for i_sub in range(25):
#     print(jdet_constraint2(phi1, phi, i_sub, cx, cy, cz, submatrix_size, idx_adj, y_offset, sub_ori_coord, slice_shape, 1e-6))
# start2 = time.time()

# print("==========================================")

# dist = submatrix_size//2
# for zi in range(1):
#     for yi in range(cy-dist, cy+dist+1):
#         for xi in range(cx-dist, cx+dist+1):
#             print(compute_jdet_for_pixel(phi1, phi2, dist, zi, yi, xi, cz, cy, cx, submatrix_size, slice_shape, 1e-6))

# end = time.time()
# print(f'Time taken: {start2-start}s and {end-start2}s')

# %% [markdown]
# ## preprocessing and plotting methods

# %%
def plot_deformations(msample, fsample, deformation_i, phi_corrected, figsize=(10,10)):
    jacobian_initial = jacobian_det2D(deformation_i[1:])
    jacobian_final = jacobian_det2D(phi_corrected)

    # print("JACOBIAN SHAPES", jacobian_initial.shape, jacobian_final.shape)

    # Create DataFrame
    data = {
        ("x-def", "min"): [np.min(deformation_i[2,0]), np.min(phi_corrected[1])],
        ("x-def", "max"): [np.max(deformation_i[2,0]), np.max(phi_corrected[1])],
        ("y-def", "min"): [np.min(deformation_i[1,0]), np.min(phi_corrected[0])],
        ("y-def", "max"): [np.max(deformation_i[1,0]), np.max(phi_corrected[0])],
        ("jacobian", "min"): [np.min(jacobian_initial), np.min(jacobian_final)],
        ("jacobian", "max"): [np.max(jacobian_initial), np.max(jacobian_final)]
    }

    row_names = ["initial", "final"]
    df = pd.DataFrame(data, index=row_names)

    # Print table
    print(df)


    # plot initial vs final Jacobian
    norm = mcolors.TwoSlopeNorm(vmin=min(jacobian_initial.min(), jacobian_final.min(), -1), vcenter=0, vmax=max(jacobian_initial.max(), jacobian_final.max(), 1))


    fig, axs = plt.subplots(nrows=2, ncols=2, figsize=figsize)

    # jacobians are of shape (1,5,5). Use index [0] for 2D plots
    im0 = axs[0,0].imshow(jacobian_initial[0], cmap='seismic', norm=norm, interpolation='nearest')
    im1 = axs[0,1].imshow(jacobian_final[0], cmap='seismic', norm=norm, interpolation='nearest')

    for i in range(len(msample)):  # Draw lines connecting the points
        axs[0,0].annotate(
            '', 
            xy=(fsample[i][2], fsample[i][1]), 
            xytext=(msample[i][2], msample[i][1]), 
            arrowprops=dict(facecolor='black', shrink=0.045, headwidth=8, headlength=10, width=3)
        )
    
    # Create a grid of points
    x, y = np.meshgrid(range(deformation_i.shape[3]), range(deformation_i.shape[2]), indexing='xy')
    print(f'meshgrid shape for plot: {x.shape}')
    
    axs[0,0].set_title('Initial J det')
    axs[0,0].scatter(msample[:, 2], msample[:, 1], c='g', label='Moving')
    axs[0,0].scatter(fsample[:, 2], fsample[:, 1], c='violet', label='Fixed')
    axs[0,0].legend()

    axs[0,1].set_title('final J det')

    axs[1,0].set_title('Initial deformation')
    axs[1,0].quiver(x, y, -deformation_i[2,0], deformation_i[1,0])

    axs[1,1].set_title('final deformation')
    axs[1,1].quiver(x, y, -phi_corrected[1], phi_corrected[0])

    for i in range(2):
        axs[1,i].invert_yaxis()
    
    #fig.subplots_adjust(right=0.8)
    cax = fig.add_axes([0.95, 0.5, 0.02, 0.4])
    fig.colorbar(im1, cax=cax)

# %%
def plot_jacobians_iteratively(jacobians, msample, fsample, methodName='SLSQP'):
    # assume jacobians is a list of numpy arrays of shape (1, 5, 5)
    # assume msample and fsample are (N, 3) arrays

    num_jacobians = len(jacobians)
    ncols = min(2, num_jacobians)  # wrap at 2 columns
    nrows = (num_jacobians + ncols - 1) // ncols  # ceiling division

    # Compute color normalization
    all_vals = [j[0] for j in jacobians]  # extract 2D arrays from (1,5,5)
    vmin = min(j.min() for j in all_vals)
    vmax = max(j.max() for j in all_vals)
    norm = mcolors.TwoSlopeNorm(vmin=min(vmin, -1), vcenter=0, vmax=max(vmax, 1))

    # Create subplots
    fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(4 * ncols, 4 * nrows))
    axs = axs.flatten()

    for i, jac in enumerate(jacobians):
        im = axs[i].imshow(jac[0], cmap='seismic', norm=norm, interpolation='nearest')
        num_negs = np.sum(jac <= 0)
        axs[i].set_title(f'Jacobian #{i}, {num_negs} -ves' if i > 0 else f'Initial J det: {num_negs} -ves')

        if i == 0:
            axs[i].scatter(msample[:, 2], msample[:, 1], c='g', label='Moving', s=10)
            axs[i].scatter(fsample[:, 2], fsample[:, 1], c='violet', label='Fixed', s=10)
            axs[i].legend()

    for i in range(len(msample)):  # Draw lines connecting the points
        axs[0].annotate(
            '', 
            xy=(fsample[i][2], fsample[i][1]), 
            xytext=(msample[i][2], msample[i][1]), 
            arrowprops=dict(facecolor='black', shrink=0.1, headwidth=3, headlength=5, width=1)
        )

    # Hide any extra axes
    for j in range(len(jacobians), len(axs)):
        axs[j].axis('off')

    # Add colorbar
    # cax = fig.add_axes([0.92, 0.15, 0.015, 0.7])
    # fig.colorbar(im, cax=cax)
    fig.colorbar(im, ax=axs, orientation='vertical', fraction=0.046, pad=0.04)

    plt.tight_layout(rect=[0, 0, 0.9, 1])
    plt.show()

def run_lapl_and_correction(fixed_sample, msample, fsample, methodName='SLSQP'):
    '''plot each Jacobian matrix'''
    deformation_i, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_sample, msample, fsample)
    print(f'deformation shape: {deformation_i.shape}')
    phi_corrected, jacobians = iterative_with_jacobians(deformation_i, methodName)
    plot_jacobians_iteratively(jacobians, msample, fsample, methodName='SLSQP')
    plot_deformations(msample, fsample, deformation_i, phi_corrected, figsize=(10,10))

# %% [markdown]
# ## Some more testcases

# %%
msample = np.array([
    [0, 2, 0],
    [0, 3, 1],
    [0, 10, 5],
    [0, 13, 1],
    [0, 2, 39],
    [0, 3, 38],
    [0, 10, 35],
    [0, 13, 39],
])
fsample = np.array([
    [0, 2, 4],
    [0, 3, 2],
    [0, 10, 3],
    [0, 11, 6],
    [0, 2, 30],
    [0, 3, 36],
    [0, 10, 37],
    [0, 11, 34]
])

fixed_sample = np.zeros((1, 20, 40))

run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [5, 46, 16, 33, 14, 15, 86, 85, 34, 56]
# Iter 1: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -1.8710779020733441
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935444090699e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 5 completed in 0.043740034103393555s
# OP result error for index 5: 5.587935444090699e-07
# Iter 1 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010932 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 2: Analysing index 46: Original coord: (6, 1, 0), nearest: (6, 2, 0), jdet: -1.1815120714365825
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.76308010239869e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 46 completed in 0.007741212844848633s
# OP result error for index 46: 2.76308010239869e-06
# Iter 2 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010932 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 3: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -1.0701093237281853
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935444362202e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 16 completed in 0.04078483581542969s
# OP result error for index 16: 5.587935444362202e-07
# Iter 3 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010932 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 4: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 2, 0), jdet: -0.7310338436625633
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935413771291e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 33 completed in 0.040985107421875s
# OP result error for index 33: 5.587935413771291e-07
# Iter 4 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010932 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 5: Analysing index 14: Original coord: (14, 0, 0), nearest: (14, 2, 0), jdet: -0.4999508425155943
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.540942136977135e-06
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.014945030212402344s
# OP result error for index 14: 8.540942136977135e-06
# Iter 5 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010934 -0.73103384 -0.49995059 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 6: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -0.48991491079579935
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.814895883496415e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 15 completed in 0.019131898880004883s
# OP result error for index 15: 2.814895883496415e-05
# Iter 6 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.0701091  -0.73103384 -0.49995156 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657848]
# Iter 7: Analysing index 86: Original coord: (6, 2, 0), nearest: (6, 2, 0), jdet: -0.19687125025320804
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.043856163115385e-07
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 86 completed in 0.03480195999145508s
# OP result error for index 86: 8.043856163115385e-07
# Iter 7 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.0701091  -0.73103384 -0.49995156 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657848]
# Iter 8: Analysing index 85: Original coord: (5, 2, 0), nearest: (5, 2, 0), jdet: -0.1304958582507586
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4289866751634913e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 85 completed in 0.007887840270996094s
# OP result error for index 85: 3.4289866751634913e-07
# Iter 8 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.0701091  -0.73103384 -0.49995156 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657848]
# Iter 9: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.04804801378466883
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630799525897357e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 34 completed in 0.007647991180419922s
# OP result error for index 34: 2.7630799525897357e-06
# Iter 9 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.0701091  -0.73103384 -0.49995156 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657848]
# Iter 10: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -0.04657848449417501
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6944303533536487e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 56 completed in 0.014828205108642578s
# OP result error for index 56: 1.6944303533536487e-05
# Iter 10 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010958 -0.73103384 -0.49995098 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657858]
# Iter 11: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -1.8710779020733472
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.440804590913064e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 5 completed in 0.0077970027923583984s
# OP result error for index 5: 3.440804590913064e-07
# Iter 11 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010958 -0.73103384 -0.49995098 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657858]
# Iter 12: Analysing index 46: Original coord: (6, 1, 0), nearest: (6, 2, 0), jdet: -1.1815120714365772
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5605625351279872e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 46 completed in 0.007760047912597656s
# OP result error for index 46: 1.5605625351279872e-06
# Iter 12 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010958 -0.73103384 -0.49995098 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657858]
# Iter 13: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -1.0701095794120357
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016232976856332682
#             Iterations: 4
#             Function evaluations: 233
#             Gradient evaluations: 4
# Optimisation for index 16 completed in 0.0289762020111084s
# OP result error for index 16: 0.00016232976856332682
# Iter 13 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07011036 -0.73103384 -0.49994866 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657873]
# Iter 14: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 2, 0), jdet: -0.7310338436625643
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0358296416946465e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 33 completed in 0.015207290649414062s
# OP result error for index 33: 3.0358296416946465e-05
# Iter 14 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07011036 -0.73103384 -0.49994866 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657873]
# Iter 15: Analysing index 14: Original coord: (14, 0, 0), nearest: (14, 2, 0), jdet: -0.49994865753525874
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7897498543479125e-05
#             Iterations: 4
#             Function evaluations: 230
#             Gradient evaluations: 4
# Optimisation for index 14 completed in 0.028767108917236328s
# OP result error for index 14: 1.7897498543479125e-05
# Iter 15 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010937 -0.73103384 -0.49995033 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Iter 16: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -0.4899149107957995
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.09363995578619e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 15 completed in 0.015285968780517578s
# OP result error for index 15: 4.09363995578619e-05
# Iter 16 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010886 -0.73103384 -0.49995159 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657844]
# Iter 17: Analysing index 86: Original coord: (6, 2, 0), nearest: (6, 2, 0), jdet: -0.19687125025323302
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3601124904713064e-07
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 86 completed in 0.04244399070739746s
# OP result error for index 86: 4.3601124904713064e-07
# Iter 17 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010886 -0.73103384 -0.49995159 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657844]
# Iter 18: Analysing index 85: Original coord: (5, 2, 0), nearest: (5, 2, 0), jdet: -0.13049585825074173
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.151181846869872e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 85 completed in 0.015002965927124023s
# OP result error for index 85: 3.151181846869872e-05
# Iter 18 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010886 -0.73103384 -0.49995159 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657844]
# Iter 19: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.04804801378466887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.799646136589049e-06
#             Iterations: 5
#             Function evaluations: 286
#             Gradient evaluations: 5
# Optimisation for index 34 completed in 0.03660106658935547s
# OP result error for index 34: 8.799646136589049e-06
# Iter 19 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010886 -0.73103384 -0.49995159 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657844]
# Iter 20: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -0.0465784370742654
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6291895406982402e-05
#             Iterations: 8
#             Function evaluations: 458
#             Gradient evaluations: 8
# Optimisation for index 56 completed in 0.058342933654785156s
# OP result error for index 56: 2.6291895406982402e-05
# Iter 20 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010946 -0.73103384 -0.49995085 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 21: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -1.8710779020733015
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.276617635774794e-06
#             Iterations: 5
#             Function evaluations: 286
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.03685283660888672s
# OP result error for index 5: 7.276617635774794e-06
# Iter 21 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010946 -0.73103384 -0.49995085 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 22: Analysing index 46: Original coord: (6, 1, 0), nearest: (6, 2, 0), jdet: -1.1815120714366505
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.036603187224383e-06
#             Iterations: 7
#             Function evaluations: 391
#             Gradient evaluations: 7
# Optimisation for index 46 completed in 0.0534820556640625s
# OP result error for index 46: 7.036603187224383e-06
# Iter 22 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010946 -0.73103384 -0.49995085 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 23: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -1.0701094601890009
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.863150716697239e-05
#             Iterations: 3
#             Function evaluations: 183
#             Gradient evaluations: 3
# Optimisation for index 16 completed in 0.023173093795776367s
# OP result error for index 16: 3.863150716697239e-05
# Iter 23 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010891 -0.73103384 -0.49995152 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657845]
# Iter 24: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 2, 0), jdet: -0.7310338436625633
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.2833371316142264e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 33 completed in 0.017945051193237305s
# OP result error for index 33: 4.2833371316142264e-05
# Iter 24 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010891 -0.73103384 -0.49995152 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657845]
# Iter 25: Analysing index 14: Original coord: (14, 0, 0), nearest: (14, 2, 0), jdet: -0.49995152394046183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.407935063670519e-06
#             Iterations: 6
#             Function evaluations: 338
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.04318594932556152s
# OP result error for index 14: 1.407935063670519e-06
# Iter 25 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010914 -0.73103384 -0.49995078 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657849]
# Iter 26: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -0.48991491079579963
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.162202428761214e-05
#             Iterations: 2
#             Function evaluations: 118
#             Gradient evaluations: 2
# Optimisation for index 15 completed in 0.015048980712890625s
# OP result error for index 15: 4.162202428761214e-05
# Iter 26 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010914 -0.73103384 -0.49995201 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657849]
# Iter 27: Analysing index 86: Original coord: (6, 2, 0), nearest: (6, 2, 0), jdet: -0.1968712502532332
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7946129855141766e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 86 completed in 0.015229940414428711s
# OP result error for index 86: 2.7946129855141766e-05
# Iter 27 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010914 -0.73103384 -0.49995201 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657849]
# Iter 28: Analysing index 85: Original coord: (5, 2, 0), nearest: (5, 2, 0), jdet: -0.13049585825074234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.974754034449116e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 85 completed in 0.007922887802124023s
# OP result error for index 85: 2.974754034449116e-05
# Iter 28 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010914 -0.73103384 -0.49995201 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657849]
# Iter 29: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.04804801378466888
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4952585861304102e-05
#             Iterations: 2
#             Function evaluations: 121
#             Gradient evaluations: 2
# Optimisation for index 34 completed in 0.015211105346679688s
# OP result error for index 34: 2.4952585861304102e-05
# Iter 29 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010914 -0.73103384 -0.49995201 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657849]
# Iter 30: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -0.0465784908200336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.626939128491881e-06
#             Iterations: 6
#             Function evaluations: 339
#             Gradient evaluations: 6
# Optimisation for index 56 completed in 0.04301095008850098s
# OP result error for index 56: 5.626939128491881e-06
# Iter 30 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010937 -0.73103384 -0.49995132 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Submatrix size is 7 from index 5
# Iter 31: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 3, 0), jdet: -1.8710779020733015
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005285553578391763
#             Iterations: 4
#             Function evaluations: 427
#             Gradient evaluations: 4
# Optimisation for index 5 completed in 0.10185909271240234s
# OP result error for index 5: 0.0005285553578391763
# Iter 31 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010937 -0.73103384 -0.49995132 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Iter 32: Analysing index 46: Original coord: (6, 1, 0), nearest: (6, 3, 0), jdet: -1.18151207143665
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.400759652780964e-05
#             Iterations: 5
#             Function evaluations: 535
#             Gradient evaluations: 5
# Optimisation for index 46 completed in 0.13079190254211426s
# OP result error for index 46: 3.400759652780964e-05
# Iter 32 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010937 -0.73103384 -0.49995132 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Iter 33: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 3, 0), jdet: -1.0701093714225427
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4549226817481263e-05
#             Iterations: 11
#             Function evaluations: 1154
#             Gradient evaluations: 11
# Optimisation for index 16 completed in 0.2772090435028076s
# OP result error for index 16: 4.4549226817481263e-05
# Iter 33 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010938 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Iter 34: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 3, 0), jdet: -0.7310338436625629
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005115785430924412
#             Iterations: 5
#             Function evaluations: 536
#             Gradient evaluations: 5
# Optimisation for index 33 completed in 0.13787412643432617s
# OP result error for index 33: 0.0005115785430924412
# Iter 34 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010938 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657854]
# Iter 35: Analysing index 14: Original coord: (14, 0, 0), nearest: (14, 3, 0), jdet: -0.49995084003913975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.560469347476042e-05
#             Iterations: 2
#             Function evaluations: 214
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.05091714859008789s
# OP result error for index 14: 8.560469347476042e-05
# Iter 35 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010889 -0.73103384 -0.49995084 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657844]
# Iter 36: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 3, 0), jdet: -0.4899149107958002
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.003874942418436e-05
#             Iterations: 7
#             Function evaluations: 741
#             Gradient evaluations: 7
# Optimisation for index 15 completed in 0.18319225311279297s
# OP result error for index 15: 3.003874942418436e-05
# Iter 36 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010947 -0.73103384 -0.49995083 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 37: Analysing index 86: Original coord: (6, 2, 0), nearest: (6, 3, 0), jdet: -0.19687125025323313
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3554192312421214e-05
#             Iterations: 10
#             Function evaluations: 1051
#             Gradient evaluations: 10
# Optimisation for index 86 completed in 0.2683560848236084s
# OP result error for index 86: 1.3554192312421214e-05
# Iter 37 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010947 -0.73103384 -0.49995083 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 38: Analysing index 85: Original coord: (5, 2, 0), nearest: (5, 3, 0), jdet: -0.13049585825074272
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.870545448493074e-05
#             Iterations: 6
#             Function evaluations: 638
#             Gradient evaluations: 6
# Optimisation for index 85 completed in 0.15137195587158203s
# OP result error for index 85: 5.870545448493074e-05
# Iter 38 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010947 -0.73103384 -0.49995083 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 39: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 3, 0), jdet: -0.048048013784668865
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00033046482199097343
#             Iterations: 8
#             Function evaluations: 850
#             Gradient evaluations: 8
# Optimisation for index 34 completed in 0.2028651237487793s
# OP result error for index 34: 0.00033046482199097343
# Iter 39 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010947 -0.73103384 -0.49995083 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657855]
# Iter 40: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 3, 0), jdet: -0.04657855463833785
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6044889653791617e-05
#             Iterations: 2
#             Function evaluations: 217
#             Gradient evaluations: 2
# Optimisation for index 56 completed in 0.05101799964904785s
# OP result error for index 56: 4.6044889653791617e-05
# Iter 40 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010927 -0.73103384 -0.49995109 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657852]
# Submatrix size is 9 from index 5
# Iter 41: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -1.8710779020733024
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00023874832432570572
#             Iterations: 8
#             Function evaluations: 1364
#             Gradient evaluations: 8
# Optimisation for index 5 completed in 0.5469942092895508s
# OP result error for index 5: 0.00023874832432570572
# Iter 41 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010927 -0.73103384 -0.49995109 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657852]
# Iter 42: Analysing index 46: Original coord: (6, 1, 0), nearest: (6, 4, 0), jdet: -1.1815120714366505
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0008821271505194604
#             Iterations: 7
#             Function evaluations: 1201
#             Gradient evaluations: 7
# Optimisation for index 46 completed in 0.485260009765625s
# OP result error for index 46: 0.0008821271505194604
# Iter 42 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010927 -0.73103384 -0.49995109 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657852]
# Iter 43: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 4, 0), jdet: -1.0701092653882314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012542606735237714
#             Iterations: 5
#             Function evaluations: 858
#             Gradient evaluations: 5
# Optimisation for index 16 completed in 0.346005916595459s
# OP result error for index 16: 0.00012542606735237714
# Iter 43 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010927 -0.73103384 -0.49995109 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657852]
# Iter 44: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 4, 0), jdet: -0.7310338436625644
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.776786954940204e-05
#             Iterations: 7
#             Function evaluations: 1198
#             Gradient evaluations: 7
# Optimisation for index 33 completed in 0.6374967098236084s
# OP result error for index 33: 7.776786954940204e-05
# Iter 44 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010927 -0.73103384 -0.49995109 -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657852]
# Iter 45: Analysing index 14: Original coord: (14, 0, 0), nearest: (14, 4, 0), jdet: -0.4999510921748924
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.621730153408258e-05
#             Iterations: 6
#             Function evaluations: 1027
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.41106104850769043s
# OP result error for index 14: 4.621730153408258e-05
# Iter 45 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 46: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 4, 0), jdet: -0.4899149107968789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.194197249331032e-05
#             Iterations: 8
#             Function evaluations: 1363
#             Gradient evaluations: 8
# Optimisation for index 15 completed in 0.5500259399414062s
# OP result error for index 15: 8.194197249331032e-05
# Iter 46 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 47: Analysing index 86: Original coord: (6, 2, 0), nearest: (6, 4, 0), jdet: -0.1968712502532324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.060756999485802e-05
#             Iterations: 9
#             Function evaluations: 1535
#             Gradient evaluations: 9
# Optimisation for index 86 completed in 0.6170670986175537s
# OP result error for index 86: 5.060756999485802e-05
# Iter 47 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 48: Analysing index 85: Original coord: (5, 2, 0), nearest: (5, 4, 0), jdet: -0.13049585825074358
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013335477541390786
#             Iterations: 5
#             Function evaluations: 861
#             Gradient evaluations: 5
# Optimisation for index 85 completed in 0.3440277576446533s
# OP result error for index 85: 0.00013335477541390786
# Iter 48 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 49: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 4, 0), jdet: -0.048048013784668865
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013746155886015156
#             Iterations: 4
#             Function evaluations: 692
#             Gradient evaluations: 4
# Optimisation for index 34 completed in 0.27812719345092773s
# OP result error for index 34: 0.00013746155886015156
# Iter 49 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Iter 50: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 4, 0), jdet: -0.0465785318956303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.282731790555377e-05
#             Iterations: 6
#             Function evaluations: 1027
#             Gradient evaluations: 6
# Optimisation for index 56 completed in 0.41913509368896484s
# OP result error for index 56: 5.282731790555377e-05
# Iter 50 end: 10 -ve jacs now at [ 5 46 16 33 14 15 86 85 34 56] : SITK: [-1.8710779  -1.18151207 -1.07010935 -0.73103384 -0.4999508  -0.48991491 -0.19687125 -0.13049586 -0.04804801 -0.04657853]
# Total time taken for iterative SLSQP : 7.1784162521362305 split as [0.043740034103393555, 0.007741212844848633, 0.04078483581542969, 0.040985107421875, 0.014945030212402344, 0.019131898880004883, 0.03480195999145508, 0.007887840270996094, 0.007647991180419922, 0.014828205108642578, 0.0077970027923583984, 0.007760047912597656, 0.0289762020111084, 0.015207290649414062, 0.028767108917236328, 0.015285968780517578, 0.04244399070739746, 0.015002965927124023, 0.03660106658935547, 0.058342933654785156, 0.03685283660888672, 0.0534820556640625, 0.023173093795776367, 0.017945051193237305, 0.04318594932556152, 0.015048980712890625, 0.015229940414428711, 0.007922887802124023, 0.015211105346679688, 0.04301095008850098, 0.10185909271240234, 0.13079190254211426, 0.2772090435028076, 0.13787412643432617, 0.05091714859008789, 0.18319225311279297, 0.2683560848236084, 0.15137195587158203, 0.2028651237487793, 0.05101799964904785, 0.5469942092895508, 0.485260009765625, 0.346005916595459, 0.6374967098236084, 0.41106104850769043, 0.5500259399414062, 0.6170670986175537, 0.3440277576446533, 0.27812719345092773, 0.41913509368896484]
# Initial error: 23.232918289195432, final error: 23.23294372717951, deviation: 2.522510155451737e-05
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#             x-def                   y-def            jacobian
#               min       max           min       max       min       max
# initial -5.001665  9.002997  0.000000e+00  1.998337 -1.871078  2.938822
# final   -5.001665  9.002998 -1.326985e-07  1.998337 -1.871078  2.938822
# meshgrid shape for plot: (20, 40)

# %%
msample = np.array([
    [0, 5, 10],
    [0, 5, 30],
])
fsample = np.array([
    [0, 15, 30],
    [0, 15, 10],
])

fixed_sample = np.zeros((1, 20, 40))

run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [26, 44, 27, 28, 67, 43, 66, 68]
# Iter 1: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.7830091042695875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447692871e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.044393062591552734s
# OP result error for index 26: 5.587935447692871e-07
# Iter 1 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133386  -0.23828473 -0.15263588 -0.1436525  -0.02841756]
# Iter 2: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435725
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447692871e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 44 completed in 0.04394888877868652s
# OP result error for index 44: 5.587935447692871e-07
# Iter 2 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133386  -0.23828473 -0.15263588 -0.1436525  -0.02841756]
# Iter 3: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964765
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.763080109602356e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 27 completed in 0.008297920227050781s
# OP result error for index 27: 2.763080109602356e-06
# Iter 3 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133387  -0.23828473 -0.15263588 -0.1436525  -0.02841769]
# Iter 4: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.41333870015255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0874526923387862e-06
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.0360870361328125s
# OP result error for index 28: 1.0874526923387862e-06
# Iter 4 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333865 -0.23828473 -0.15263588 -0.14365256 -0.02841762]
# Iter 5: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2741898691714937e-06
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 67 completed in 0.04227495193481445s
# OP result error for index 67: 1.2741898691714937e-06
# Iter 5 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333862 -0.23828473 -0.15263588 -0.14365256 -0.02841759]
# Iter 6: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630801042732855e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 43 completed in 0.009174108505249023s
# OP result error for index 43: 2.7630801042732855e-06
# Iter 6 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333862 -0.23828473 -0.15263588 -0.14365256 -0.02841759]
# Iter 7: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.14365256272460225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9896688924502257e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.015417814254760742s
# OP result error for index 66: 2.9896688924502257e-05
# Iter 7 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300749 -1.45771465 -1.17127135 -0.4133391  -0.23828473 -0.15263588 -0.14365011 -0.02841822]
# Iter 8: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.02841822207692301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.395228157567544e-06
#             Iterations: 6
#             Function evaluations: 339
#             Gradient evaluations: 6
# Optimisation for index 68 completed in 0.04354500770568848s
# OP result error for index 68: 5.395228157567544e-06
# Iter 8 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300845 -1.45771465 -1.17127135 -0.41333848 -0.23828473 -0.15263588 -0.14365152 -0.02841741]
# Iter 9: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.783008445789783
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.848517240889748e-06
#             Iterations: 6
#             Function evaluations: 339
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.043378353118896484s
# OP result error for index 26: 3.848517240889748e-06
# Iter 9 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300899 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365233 -0.02841757]
# Iter 10: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435734
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0358296424282116e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.014990091323852539s
# OP result error for index 44: 3.0358296424282116e-05
# Iter 10 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300899 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365233 -0.02841757]
# Iter 11: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964765
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3612436825490875e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 27 completed in 0.015092849731445312s
# OP result error for index 27: 4.3612436825490875e-05
# Iter 11 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830111  -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365544 -0.02841757]
# Iter 12: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.41333861087336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9813774702347473e-06
#             Iterations: 5
#             Function evaluations: 277
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.0356600284576416s
# OP result error for index 28: 2.9813774702347473e-06
# Iter 12 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830101  -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365397 -0.02841757]
# Iter 13: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001305760701599823
#             Iterations: 4
#             Function evaluations: 235
#             Gradient evaluations: 4
# Optimisation for index 67 completed in 0.04037809371948242s
# OP result error for index 67: 0.0001305760701599823
# Iter 13 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300589 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14364773 -0.02841757]
# Iter 14: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.920399300914255e-06
#             Iterations: 7
#             Function evaluations: 379
#             Gradient evaluations: 7
# Optimisation for index 43 completed in 0.048645973205566406s
# OP result error for index 43: 1.920399300914255e-06
# Iter 14 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300589 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14364773 -0.02841757]
# Iter 15: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.14364773182221216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.624166056618975e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.01517486572265625s
# OP result error for index 66: 7.624166056618975e-05
# Iter 15 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300881 -1.45771465 -1.17127135 -0.41333561 -0.23828473 -0.15263588 -0.14365206 -0.02841362]
# Iter 16: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.028413619493493664
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7778058391270122e-05
#             Iterations: 3
#             Function evaluations: 184
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.022943973541259766s
# OP result error for index 68: 2.7778058391270122e-05
# Iter 16 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300702 -1.45771465 -1.17127135 -0.4133389  -0.23828473 -0.15263588 -0.14364941 -0.02841796]
# Iter 17: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.783007020526228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.376080350088074e-05
#             Iterations: 7
#             Function evaluations: 405
#             Gradient evaluations: 7
# Optimisation for index 26 completed in 0.051122188568115234s
# OP result error for index 26: 4.376080350088074e-05
# Iter 17 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300602 -1.45771465 -1.17127135 -0.41333929 -0.23828473 -0.15263588 -0.14364793 -0.02841848]
# Iter 18: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435734
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.19766144136247e-07
#             Iterations: 9
#             Function evaluations: 482
#             Gradient evaluations: 9
# Optimisation for index 44 completed in 0.06875395774841309s
# OP result error for index 44: 9.19766144136247e-07
# Iter 18 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300602 -1.45771465 -1.17127135 -0.41333929 -0.23828473 -0.15263588 -0.14364793 -0.02841848]
# Iter 19: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.855471224755718e-06
#             Iterations: 7
#             Function evaluations: 405
#             Gradient evaluations: 7
# Optimisation for index 27 completed in 0.05131697654724121s
# OP result error for index 27: 8.855471224755718e-06
# Iter 19 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300944 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365299 -0.02841754]
# Iter 20: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.4133385849618263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7579432197176743e-06
#             Iterations: 7
#             Function evaluations: 396
#             Gradient evaluations: 7
# Optimisation for index 28 completed in 0.05107307434082031s
# OP result error for index 28: 3.7579432197176743e-06
# Iter 20 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 21: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.461923296350534e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 67 completed in 0.015372037887573242s
# OP result error for index 67: 4.461923296350534e-05
# Iter 21 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 22: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771502
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.366429646855522e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 43 completed in 0.0076677799224853516s
# OP result error for index 43: 8.366429646855522e-07
# Iter 22 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 23: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.1436526443744791
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014389535407666187
#             Iterations: 8
#             Function evaluations: 457
#             Gradient evaluations: 8
# Optimisation for index 66 completed in 0.05793118476867676s
# OP result error for index 66: 0.00014389535407666187
# Iter 23 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830146  -1.45771465 -1.17127246 -0.41333726 -0.2382853  -0.15263588 -0.14366109 -0.02841565]
# Iter 24: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.028415652388528
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.738247631510319e-05
#             Iterations: 3
#             Function evaluations: 184
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.03269195556640625s
# OP result error for index 68: 6.738247631510319e-05
# Iter 24 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300986 -1.45771465 -1.17127119 -0.41333886 -0.2382853  -0.15263588 -0.14365383 -0.02841776]
# Submatrix size is 7 from index 26
# Iter 25: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 3, 0), jdet: -2.783009856358327
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00018563541011307194
#             Iterations: 6
#             Function evaluations: 645
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.15480494499206543s
# OP result error for index 26: 0.00018563541011307194
# Iter 25 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301051 -1.45771465 -1.17127119 -0.41333938 -0.23828589 -0.15263588 -0.14365507 -0.02841829]
# Iter 26: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 3, 0), jdet: -1.4577146507435244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0799863119359543e-06
#             Iterations: 5
#             Function evaluations: 508
#             Gradient evaluations: 5
# Optimisation for index 44 completed in 0.12627315521240234s
# OP result error for index 44: 1.0799863119359543e-06
# Iter 26 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301051 -1.45771465 -1.17127119 -0.41333938 -0.23828589 -0.15263588 -0.14365507 -0.02841829]
# Iter 27: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 3, 0), jdet: -1.1712711876682294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.301198220335039e-05
#             Iterations: 5
#             Function evaluations: 535
#             Gradient evaluations: 5
# Optimisation for index 27 completed in 0.12678098678588867s
# OP result error for index 27: 9.301198220335039e-05
# Iter 27 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300972 -1.45771465 -1.17127119 -0.41333875 -0.23828518 -0.15263588 -0.14365358 -0.02841765]
# Iter 28: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 3, 0), jdet: -0.41333875320402197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001447497443329837
#             Iterations: 5
#             Function evaluations: 534
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.13325023651123047s
# OP result error for index 28: 0.0001447497443329837
# Iter 28 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300997 -1.45771465 -1.17127119 -0.41333895 -0.2382854  -0.15263588 -0.14365405 -0.02841785]
# Iter 29: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 3, 0), jdet: -0.23828540127108078
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00029483011823838723
#             Iterations: 6
#             Function evaluations: 642
#             Gradient evaluations: 6
# Optimisation for index 67 completed in 0.15151119232177734s
# OP result error for index 67: 0.00029483011823838723
# Iter 29 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 30: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 3, 0), jdet: -0.15263587893766248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.7920550002043e-05
#             Iterations: 2
#             Function evaluations: 216
#             Gradient evaluations: 2
# Optimisation for index 43 completed in 0.05460405349731445s
# OP result error for index 43: 6.7920550002043e-05
# Iter 30 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 31: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 3, 0), jdet: -0.14365359812928583
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001853640469713369
#             Iterations: 2
#             Function evaluations: 213
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.05500006675720215s
# OP result error for index 66: 0.0001853640469713369
# Iter 31 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 32: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 3, 0), jdet: -0.028415463701414262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.968338713684517e-05
#             Iterations: 6
#             Function evaluations: 643
#             Gradient evaluations: 6
# Optimisation for index 68 completed in 0.17308902740478516s
# OP result error for index 68: 4.968338713684517e-05
# Iter 32 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300845 -1.45771465 -1.17127142 -0.41333926 -0.23828476 -0.15263588 -0.14365154 -0.02841842]
# Submatrix size is 9 from index 26
# Iter 33: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 4, 0), jdet: -2.7830084451160038
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.623574486581575e-05
#             Iterations: 5
#             Function evaluations: 854
#             Gradient evaluations: 5
# Optimisation for index 26 completed in 0.3636939525604248s
# OP result error for index 26: 7.623574486581575e-05
# Iter 33 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300977 -1.45771465 -1.17127197 -0.41333843 -0.23828476 -0.15263588 -0.1436536  -0.02841733]
# Iter 34: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -1.4577146507435252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010422256908526606
#             Iterations: 2
#             Function evaluations: 342
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.1378319263458252s
# OP result error for index 44: 0.00010422256908526606
# Iter 34 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300977 -1.45771465 -1.17127197 -0.41333843 -0.23828476 -0.15263588 -0.1436536  -0.02841733]
# Iter 35: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 4, 0), jdet: -1.171271971768923
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005185833078167335
#             Iterations: 7
#             Function evaluations: 1192
#             Gradient evaluations: 7
# Optimisation for index 27 completed in 0.49266600608825684s
# OP result error for index 27: 0.0005185833078167335
# Iter 35 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300417 -1.45771465 -1.17127132 -0.41333593 -0.23828474 -0.15263588 -0.14364518 -0.02841403]
# Iter 36: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 4, 0), jdet: -0.4133359280424118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003565322700600504
#             Iterations: 4
#             Function evaluations: 687
#             Gradient evaluations: 4
# Optimisation for index 28 completed in 0.28832101821899414s
# OP result error for index 28: 0.0003565322700600504
# Iter 36 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300417 -1.45771465 -1.17127132 -0.41334234 -0.23828474 -0.15263588 -0.14364518 -0.02842249]
# Iter 37: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 4, 0), jdet: -0.23828474248527354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000240655202087936
#             Iterations: 4
#             Function evaluations: 693
#             Gradient evaluations: 4
# Optimisation for index 67 completed in 0.31331515312194824s
# OP result error for index 67: 0.000240655202087936
# Iter 37 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301088 -1.45771465 -1.17127132 -0.41333619 -0.23828474 -0.15263588 -0.14365513 -0.02841438]
# Iter 38: Analysing index 43: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.15263587893766248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6042770227819858e-05
#             Iterations: 7
#             Function evaluations: 1182
#             Gradient evaluations: 7
# Optimisation for index 43 completed in 0.4835200309753418s
# OP result error for index 43: 1.6042770227819858e-05
# Iter 38 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301088 -1.45771465 -1.17127132 -0.41333619 -0.23828474 -0.15263588 -0.14365513 -0.02841438]
# Iter 39: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 4, 0), jdet: -0.14365513003323993
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.004867587458776e-05
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 66 completed in 0.34418511390686035s
# OP result error for index 66: 9.004867587458776e-05
# Iter 39 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127132 -0.41333825 -0.23828474 -0.15263588 -0.14365266 -0.02841709]
# Iter 40: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 4, 0), jdet: -0.02841709211467084
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016180859386505375
#             Iterations: 3
#             Function evaluations: 519
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.20907115936279297s
# OP result error for index 68: 0.00016180859386505375
# Iter 40 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127132 -0.41333999 -0.23828474 -0.15263588 -0.14365266 -0.02841939]
# Submatrix size is 11 from index 26
# Iter 41: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 5, 0), jdet: -2.7830092131457276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0007485560129141255
#             Iterations: 9
#             Function evaluations: 2256
#             Gradient evaluations: 9
# Optimisation for index 26 completed in 1.3763179779052734s
# OP result error for index 26: 0.0007485560129141255
# Iter 41 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300485 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14364619 -0.02841638]
# Iter 42: Analysing index 44: Original coord: (4, 1, 0), nearest: (5, 5, 0), jdet: -1.4577146507435226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021533316758581833
#             Iterations: 2
#             Function evaluations: 501
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.3037607669830322s
# OP result error for index 44: 0.00021533316758581833
# Iter 42 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300485 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14364619 -0.02841638]
# Iter 43: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 5, 0), jdet: -1.1712713235449415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005232495104556811
#             Iterations: 2
#             Function evaluations: 506
#             Gradient evaluations: 2
# Optimisation for index 27 completed in 0.3050401210784912s
# OP result error for index 27: 0.0005232495104556811
# Iter 43 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301561 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14366213 -0.02841638]
# Iter 44: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 5, 0), jdet: -0.4133377061662385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005293929275396181
#             Iterations: 6
#             Function evaluations: 1508
#             Gradient evaluations: 6
# Optimisation for index 28 completed in 0.9162108898162842s
# OP result error for index 28: 0.0005293929275396181
# Iter 44 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301162 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365622 -0.02841795]
# Iter 45: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 5, 0), jdet: -0.23828474248527354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00028825932282838806
#             Iterations: 3
#             Function evaluations: 757
#             Gradient evaluations: 3
# Optimisation for index 67 completed in 0.45863795280456543s
# OP result error for index 67: 0.00028825932282838806
# Iter 45 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830065  -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14364863 -0.02841795]
# Iter 46: Analysing index 43: Original coord: (3, 1, 0), nearest: (5, 5, 0), jdet: -0.15263587927482225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8762432084050715e-05
#             Iterations: 6
#             Function evaluations: 1499
#             Gradient evaluations: 6
# Optimisation for index 43 completed in 0.9175047874450684s
# OP result error for index 43: 2.8762432084050715e-05
# Iter 46 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830065  -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14364863 -0.02841795]
# Iter 47: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 5, 0), jdet: -0.1436486344148518
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010902819191738189
#             Iterations: 6
#             Function evaluations: 1505
#             Gradient evaluations: 6
# Optimisation for index 66 completed in 0.942875862121582s
# OP result error for index 66: 0.00010902819191738189
# Iter 47 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Iter 48: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 5, 0), jdet: -0.028417947723913886
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019313510833773861
#             Iterations: 3
#             Function evaluations: 760
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.4591050148010254s
# OP result error for index 68: 0.00019313510833773861
# Iter 48 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Submatrix size is 13 from index 26
# Iter 49: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 6, 0), jdet: -2.783008361379013
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019217370337898387
#             Iterations: 3
#             Function evaluations: 1044
#             Gradient evaluations: 3
# Optimisation for index 26 completed in 0.9078841209411621s
# OP result error for index 26: 0.00019217370337898387
# Iter 49 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Iter 50: Analysing index 44: Original coord: (4, 1, 0), nearest: (6, 6, 0), jdet: -1.4577146510855747
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.859299394745833e-05
#             Iterations: 7
#             Function evaluations: 2404
#             Gradient evaluations: 7
# Optimisation for index 44 completed in 2.1106760501861572s
# OP result error for index 44: 6.859299394745833e-05
# Iter 50 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Total time taken for iterative SLSQP : 13.408469915390015 split as [0.044393062591552734, 0.04394888877868652, 0.008297920227050781, 0.0360870361328125, 0.04227495193481445, 0.009174108505249023, 0.015417814254760742, 0.04354500770568848, 0.043378353118896484, 0.014990091323852539, 0.015092849731445312, 0.0356600284576416, 0.04037809371948242, 0.048645973205566406, 0.01517486572265625, 0.022943973541259766, 0.051122188568115234, 0.06875395774841309, 0.05131697654724121, 0.05107307434082031, 0.015372037887573242, 0.0076677799224853516, 0.05793118476867676, 0.03269195556640625, 0.15480494499206543, 0.12627315521240234, 0.12678098678588867, 0.13325023651123047, 0.15151119232177734, 0.05460405349731445, 0.05500006675720215, 0.17308902740478516, 0.3636939525604248, 0.1378319263458252, 0.49266600608825684, 0.28832101821899414, 0.31331515312194824, 0.4835200309753418, 0.34418511390686035, 0.20907115936279297, 1.3763179779052734, 0.3037607669830322, 0.3050401210784912, 0.9162108898162842, 0.45863795280456543, 0.9175047874450684, 0.942875862121582, 0.4591050148010254, 0.9078841209411621, 2.1106760501861572]
# Initial error: 22.87771808660633, final error: 22.87773128150679, deviation: 1.3791915100011423e-05
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#              x-def                 y-def            jacobian
#                min        max        min       max       min       max
# initial -19.988363  19.988363 -10.036366 -9.027486 -2.783009  5.709197
# final   -19.988363  19.988363 -10.036366 -9.027486 -2.783008  5.709197
# meshgrid shape for plot: (20, 40)

# %%
msample = np.array([
    [0, 5, 10],
    [0, 15, 10],
])
fsample = np.array([
    [0, 15, 30],
    [0, 5, 30],
])

fixed_sample = np.zeros((1, 20, 40))

run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [75, 34, 74, 35, 115]
# Iter 1: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 2, 0), jdet: -0.8898328406385954
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447692871e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 75 completed in 0.04515194892883301s
# OP result error for index 75: 5.587935447692871e-07
# Iter 1 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 2: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.4517428584792985
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630801469058497e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 34 completed in 0.008358955383300781s
# OP result error for index 34: 2.7630801469058497e-06
# Iter 2 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 3: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 2, 0), jdet: -0.31111124617747643
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.043855990180759e-07
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 74 completed in 0.03736400604248047s
# OP result error for index 74: 8.043855990180759e-07
# Iter 3 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 4: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -0.2935783734142872
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.428986712350479e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 35 completed in 0.008061885833740234s
# OP result error for index 35: 3.428986712350479e-07
# Iter 4 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 5: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 2, 0), jdet: -0.08714557615053295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.44080441472272e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 115 completed in 0.008028984069824219s
# OP result error for index 115: 3.44080441472272e-07
# Iter 5 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 6: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 2, 0), jdet: -0.8898328406385962
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4512759938820636e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 75 completed in 0.00793313980102539s
# OP result error for index 75: 3.4512759938820636e-07
# Iter 6 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 7: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.45174285847929524
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6160230940087672e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 34 completed in 0.008005857467651367s
# OP result error for index 34: 1.6160230940087672e-06
# Iter 7 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 8: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 2, 0), jdet: -0.3111112461774813
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.952493160319648e-06
#             Iterations: 5
#             Function evaluations: 276
#             Gradient evaluations: 5
# Optimisation for index 74 completed in 0.03986191749572754s
# OP result error for index 74: 3.952493160319648e-06
# Iter 8 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 9: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -0.29357837341429804
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.943587136439163e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 35 completed in 0.015430927276611328s
# OP result error for index 35: 2.943587136439163e-05
# Iter 9 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 10: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 2, 0), jdet: -0.08714557615053975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9401057253686247e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 115 completed in 0.007948160171508789s
# OP result error for index 115: 2.9401057253686247e-05
# Iter 10 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 11: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 2, 0), jdet: -0.8898328406385808
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.942092842861399e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 75 completed in 0.007932901382446289s
# OP result error for index 75: 2.942092842861399e-05
# Iter 11 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 12: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -0.4517428584793514
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9641457936158133e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 34 completed in 0.007947921752929688s
# OP result error for index 34: 2.9641457936158133e-05
# Iter 12 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 13: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 2, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9283806376234622e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 74 completed in 0.007843971252441406s
# OP result error for index 74: 2.9283806376234622e-05
# Iter 13 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 14: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -0.2935783734142973
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9106365908582177e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 35 completed in 0.007915973663330078s
# OP result error for index 35: 2.9106365908582177e-05
# Iter 14 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 15: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 2, 0), jdet: -0.08714557615053975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9589315319711318e-05
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 115 completed in 0.007861852645874023s
# OP result error for index 115: 2.9589315319711318e-05
# Iter 15 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 7 from index 75
# Iter 16: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 3, 0), jdet: -0.8898328406385796
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.442378144746243e-05
#             Iterations: 6
#             Function evaluations: 633
#             Gradient evaluations: 6
# Optimisation for index 75 completed in 0.16122198104858398s
# OP result error for index 75: 8.442378144746243e-05
# Iter 16 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 17: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 3, 0), jdet: -0.4517428584793511
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.080782525559215e-05
#             Iterations: 3
#             Function evaluations: 327
#             Gradient evaluations: 3
# Optimisation for index 34 completed in 0.07751774787902832s
# OP result error for index 34: 7.080782525559215e-05
# Iter 17 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 18: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 3, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.064287926328845e-05
#             Iterations: 10
#             Function evaluations: 1065
#             Gradient evaluations: 10
# Optimisation for index 74 completed in 0.26059770584106445s
# OP result error for index 74: 2.064287926328845e-05
# Iter 18 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 19: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 3, 0), jdet: -0.29357837341429815
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.679461712830957e-05
#             Iterations: 3
#             Function evaluations: 327
#             Gradient evaluations: 3
# Optimisation for index 35 completed in 0.07712841033935547s
# OP result error for index 35: 4.679461712830957e-05
# Iter 19 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 20: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 3, 0), jdet: -0.08714557615053975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.150710081241016e-05
#             Iterations: 2
#             Function evaluations: 217
#             Gradient evaluations: 2
# Optimisation for index 115 completed in 0.05145597457885742s
# OP result error for index 115: 4.150710081241016e-05
# Iter 20 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 9 from index 75
# Iter 21: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 4, 0), jdet: -0.8898328406385813
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.06510141756533e-05
#             Iterations: 8
#             Function evaluations: 1346
#             Gradient evaluations: 8
# Optimisation for index 75 completed in 0.5483829975128174s
# OP result error for index 75: 3.06510141756533e-05
# Iter 21 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 22: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 4, 0), jdet: -0.4517428584793514
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0010506092111679521
#             Iterations: 4
#             Function evaluations: 682
#             Gradient evaluations: 4
# Optimisation for index 34 completed in 0.27704787254333496s
# OP result error for index 34: 0.0010506092111679521
# Iter 22 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 23: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 4, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00041099110050124565
#             Iterations: 5
#             Function evaluations: 846
#             Gradient evaluations: 5
# Optimisation for index 74 completed in 0.34285593032836914s
# OP result error for index 74: 0.00041099110050124565
# Iter 23 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 24: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 4, 0), jdet: -0.293578373414294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0006635035659154909
#             Iterations: 5
#             Function evaluations: 852
#             Gradient evaluations: 5
# Optimisation for index 35 completed in 0.3440372943878174s
# OP result error for index 35: 0.0006635035659154909
# Iter 24 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 25: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 4, 0), jdet: -0.08714557615053975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016704521873345257
#             Iterations: 6
#             Function evaluations: 1028
#             Gradient evaluations: 6
# Optimisation for index 115 completed in 0.418179988861084s
# OP result error for index 115: 0.00016704521873345257
# Iter 25 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 11 from index 75
# Iter 26: Analysing index 75: Original coord: (35, 1, 0), nearest: (34, 5, 0), jdet: -0.8898328406385788
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.7159445300047906e-05
#             Iterations: 9
#             Function evaluations: 2246
#             Gradient evaluations: 9
# Optimisation for index 75 completed in 1.408715009689331s
# OP result error for index 75: 5.7159445300047906e-05
# Iter 26 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 27: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 5, 0), jdet: -0.45174285847935075
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0008952255537768572
#             Iterations: 6
#             Function evaluations: 1506
#             Gradient evaluations: 6
# Optimisation for index 34 completed in 0.923227071762085s
# OP result error for index 34: 0.0008952255537768572
# Iter 27 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 28: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 5, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00042193433167403427
#             Iterations: 4
#             Function evaluations: 1010
#             Gradient evaluations: 4
# Optimisation for index 74 completed in 0.6179070472717285s
# OP result error for index 74: 0.00042193433167403427
# Iter 28 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 29: Analysing index 35: Original coord: (35, 0, 0), nearest: (34, 5, 0), jdet: -0.29357837341429194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.232156655894272e-05
#             Iterations: 4
#             Function evaluations: 1013
#             Gradient evaluations: 4
# Optimisation for index 35 completed in 0.6176879405975342s
# OP result error for index 35: 6.232156655894272e-05
# Iter 29 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 30: Analysing index 115: Original coord: (35, 2, 0), nearest: (34, 5, 0), jdet: -0.08714557615053962
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002981683402309976
#             Iterations: 5
#             Function evaluations: 1253
#             Gradient evaluations: 5
# Optimisation for index 115 completed in 0.7696640491485596s
# OP result error for index 115: 0.0002981683402309976
# Iter 30 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 13 from index 75
# Iter 31: Analysing index 75: Original coord: (35, 1, 0), nearest: (33, 6, 0), jdet: -0.8898328406385797
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00020210522232466666
#             Iterations: 5
#             Function evaluations: 1743
#             Gradient evaluations: 5
# Optimisation for index 75 completed in 1.5366458892822266s
# OP result error for index 75: 0.00020210522232466666
# Iter 31 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 32: Analysing index 34: Original coord: (34, 0, 0), nearest: (33, 6, 0), jdet: -0.45174285847935086
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0021908029336423773
#             Iterations: 6
#             Function evaluations: 2084
#             Gradient evaluations: 6
# Optimisation for index 34 completed in 1.863084077835083s
# OP result error for index 34: 0.0021908029336423773
# Iter 32 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 33: Analysing index 74: Original coord: (34, 1, 0), nearest: (33, 6, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00025604226073472347
#             Iterations: 7
#             Function evaluations: 2431
#             Gradient evaluations: 7
# Optimisation for index 74 completed in 2.1784732341766357s
# OP result error for index 74: 0.00025604226073472347
# Iter 33 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 34: Analysing index 35: Original coord: (35, 0, 0), nearest: (33, 6, 0), jdet: -0.2935783734142967
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0004261205182749528
#             Iterations: 2
#             Function evaluations: 699
#             Gradient evaluations: 2
# Optimisation for index 35 completed in 0.64174485206604s
# OP result error for index 35: 0.0004261205182749528
# Iter 34 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 35: Analysing index 115: Original coord: (35, 2, 0), nearest: (33, 6, 0), jdet: -0.0871455761505399
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002934137716914531
#             Iterations: 3
#             Function evaluations: 1045
#             Gradient evaluations: 3
# Optimisation for index 115 completed in 0.9609420299530029s
# OP result error for index 115: 0.0002934137716914531
# Iter 35 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 15 from index 75
# Iter 36: Analysing index 75: Original coord: (35, 1, 0), nearest: (32, 7, 0), jdet: -0.88983284063858
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00207991832396881
#             Iterations: 7
#             Function evaluations: 3214
#             Gradient evaluations: 7
# Optimisation for index 75 completed in 4.129448175430298s
# OP result error for index 75: 0.00207991832396881
# Iter 36 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 37: Analysing index 34: Original coord: (34, 0, 0), nearest: (32, 7, 0), jdet: -0.4517428584793511
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0009125481493839072
#             Iterations: 8
#             Function evaluations: 3664
#             Gradient evaluations: 8
# Optimisation for index 34 completed in 4.639369249343872s
# OP result error for index 34: 0.0009125481493839072
# Iter 37 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 38: Analysing index 74: Original coord: (34, 1, 0), nearest: (32, 7, 0), jdet: -0.3111112461774811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012633888300150886
#             Iterations: 7
#             Function evaluations: 3213
#             Gradient evaluations: 7
# Optimisation for index 74 completed in 4.000909090042114s
# OP result error for index 74: 0.00012633888300150886
# Iter 38 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 39: Analysing index 35: Original coord: (35, 0, 0), nearest: (32, 7, 0), jdet: -0.29357837341429577
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005462376937535041
#             Iterations: 8
#             Function evaluations: 3670
#             Gradient evaluations: 8
# Optimisation for index 35 completed in 4.613374948501587s
# OP result error for index 35: 0.0005462376937535041
# Iter 39 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 40: Analysing index 115: Original coord: (35, 2, 0), nearest: (32, 7, 0), jdet: -0.08714557615053954
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013488124810012714
#             Iterations: 7
#             Function evaluations: 3215
#             Gradient evaluations: 7
# Optimisation for index 115 completed in 4.034132957458496s
# OP result error for index 115: 0.00013488124810012714
# Iter 40 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 17 from index 75
# Iter 41: Analysing index 75: Original coord: (35, 1, 0), nearest: (31, 8, 0), jdet: -0.8898328406385825
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.002672392487286679
#             Iterations: 6
#             Function evaluations: 3523
#             Gradient evaluations: 6
# Optimisation for index 75 completed in 6.009000062942505s
# OP result error for index 75: 0.002672392487286679
# Iter 41 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 42: Analysing index 34: Original coord: (34, 0, 0), nearest: (31, 8, 0), jdet: -0.45174285847935164
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0006245822097414866
#             Iterations: 3
#             Function evaluations: 1766
#             Gradient evaluations: 3
# Optimisation for index 34 completed in 3.0307540893554688s
# OP result error for index 34: 0.0006245822097414866
# Iter 42 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 43: Analysing index 74: Original coord: (34, 1, 0), nearest: (31, 8, 0), jdet: -0.31111124617748137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005672625414359089
#             Iterations: 3
#             Function evaluations: 1767
#             Gradient evaluations: 3
# Optimisation for index 74 completed in 3.0427682399749756s
# OP result error for index 74: 0.0005672625414359089
# Iter 43 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 44: Analysing index 35: Original coord: (35, 0, 0), nearest: (31, 8, 0), jdet: -0.29357837341429716
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003114270440169875
#             Iterations: 4
#             Function evaluations: 2357
#             Gradient evaluations: 4
# Optimisation for index 35 completed in 4.0095930099487305s
# OP result error for index 35: 0.0003114270440169875
# Iter 44 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 45: Analysing index 115: Original coord: (35, 2, 0), nearest: (31, 8, 0), jdet: -0.08714557615054035
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003902871083768522
#             Iterations: 10
#             Function evaluations: 5859
#             Gradient evaluations: 10
# Optimisation for index 115 completed in 10.07561182975769s
# OP result error for index 115: 0.0003902871083768522
# Iter 45 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Submatrix size is 19 from index 75
# Iter 46: Analysing index 75: Original coord: (35, 1, 0), nearest: (30, 9, 0), jdet: -0.8898328406385805
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00061563989782909
#             Iterations: 8
#             Function evaluations: 5854
#             Gradient evaluations: 8
# Optimisation for index 75 completed in 14.029695272445679s
# OP result error for index 75: 0.00061563989782909
# Iter 46 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 47: Analysing index 34: Original coord: (34, 0, 0), nearest: (30, 9, 0), jdet: -0.4517428584793469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003312298811983805
#             Iterations: 10
#             Function evaluations: 7319
#             Gradient evaluations: 10
# Optimisation for index 34 completed in 16.51602005958557s
# OP result error for index 34: 0.0003312298811983805
# Iter 47 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 48: Analysing index 74: Original coord: (34, 1, 0), nearest: (30, 9, 0), jdet: -0.31111124617747843
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0010899985074785679
#             Iterations: 7
#             Function evaluations: 5119
#             Gradient evaluations: 7
# Optimisation for index 74 completed in 11.543617010116577s
# OP result error for index 74: 0.0010899985074785679
# Iter 48 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 49: Analysing index 35: Original coord: (35, 0, 0), nearest: (30, 9, 0), jdet: -0.2935783734129932
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00031370053718571267
#             Iterations: 9
#             Function evaluations: 6574
#             Gradient evaluations: 9
# Optimisation for index 35 completed in 14.894381046295166s
# OP result error for index 35: 0.00031370053718571267
# Iter 49 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Iter 50: Analysing index 115: Original coord: (35, 2, 0), nearest: (30, 9, 0), jdet: -0.08714557614929551
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003520320436422031
#             Iterations: 8
#             Function evaluations: 5840
#             Gradient evaluations: 8
# Optimisation for index 115 completed in 13.502531051635742s
# OP result error for index 115: 0.0003520320436422031
# Iter 50 end: 5 -ve jacs now at [ 75  34  74  35 115] : SITK: [-0.88983284 -0.45174286 -0.31111125 -0.29357837 -0.08714558]
# Total time taken for iterative SLSQP : 132.78927397727966 split as [0.04515194892883301, 0.008358955383300781, 0.03736400604248047, 0.008061885833740234, 0.008028984069824219, 0.00793313980102539, 0.008005857467651367, 0.03986191749572754, 0.015430927276611328, 0.007948160171508789, 0.007932901382446289, 0.007947921752929688, 0.007843971252441406, 0.007915973663330078, 0.007861852645874023, 0.16122198104858398, 0.07751774787902832, 0.26059770584106445, 0.07712841033935547, 0.05145597457885742, 0.5483829975128174, 0.27704787254333496, 0.34285593032836914, 0.3440372943878174, 0.418179988861084, 1.408715009689331, 0.923227071762085, 0.6179070472717285, 0.6176879405975342, 0.7696640491485596, 1.5366458892822266, 1.863084077835083, 2.1784732341766357, 0.64174485206604, 0.9609420299530029, 4.129448175430298, 4.639369249343872, 4.000909090042114, 4.613374948501587, 4.034132957458496, 6.009000062942505, 3.0307540893554688, 3.0427682399749756, 4.0095930099487305, 10.07561182975769, 14.029695272445679, 16.51602005958557, 11.543617010116577, 14.894381046295166, 13.502531051635742]
# Initial error: 10.886336460206222, final error: 10.886388655350233, deviation: 5.221149779349197e-05
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#              x-def                y-def             jacobian
#                min       max        min        max       min       max
# initial -19.995184 -15.34107 -10.002204  10.002204 -0.889833  2.691176
# final   -19.995184 -15.34107 -10.002204  10.002205 -0.889833  2.691176
# meshgrid shape for plot: (20, 40)

# %%
msample = np.array([
    [0, 5, 10],
    [0, 5, 30],
])
fsample = np.array([
    [0, 15, 30],
    [0, 15, 10],
])

fixed_sample = np.zeros((1, 20, 40))

run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [26, 44, 27, 28, 67, 43, 66, 68]
# Iter 1: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.7830091042695875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447692871e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.0447390079498291s
# OP result error for index 26: 5.587935447692871e-07
# Iter 1 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133386  -0.23828473 -0.15263588 -0.1436525  -0.02841756]
# Iter 2: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435725
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447692871e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 44 completed in 0.04411911964416504s
# OP result error for index 44: 5.587935447692871e-07
# Iter 2 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133386  -0.23828473 -0.15263588 -0.1436525  -0.02841756]
# Iter 3: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964765
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.763080109602356e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 27 completed in 0.008177757263183594s
# OP result error for index 27: 2.763080109602356e-06
# Iter 3 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830091  -1.45771465 -1.17127135 -0.4133387  -0.23828473 -0.15263588 -0.1436525  -0.02841769]
# Iter 4: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.41333870015255
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0874526923387862e-06
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.03492307662963867s
# OP result error for index 28: 1.0874526923387862e-06
# Iter 4 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333865 -0.23828473 -0.15263588 -0.14365256 -0.02841762]
# Iter 5: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2741898691714937e-06
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 67 completed in 0.03860974311828613s
# OP result error for index 67: 1.2741898691714937e-06
# Iter 5 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333862 -0.23828473 -0.15263588 -0.14365256 -0.02841759]
# Iter 6: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630801042732855e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 43 completed in 0.007925987243652344s
# OP result error for index 43: 2.7630801042732855e-06
# Iter 6 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300915 -1.45771465 -1.17127135 -0.41333862 -0.23828473 -0.15263588 -0.14365256 -0.02841759]
# Iter 7: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.14365256272460225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9896688924502257e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.015156984329223633s
# OP result error for index 66: 2.9896688924502257e-05
# Iter 7 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300749 -1.45771465 -1.17127135 -0.4133391  -0.23828473 -0.15263588 -0.14365011 -0.02841822]
# Iter 8: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.02841822207692301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.395228157567544e-06
#             Iterations: 6
#             Function evaluations: 339
#             Gradient evaluations: 6
# Optimisation for index 68 completed in 0.04359292984008789s
# OP result error for index 68: 5.395228157567544e-06
# Iter 8 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300845 -1.45771465 -1.17127135 -0.41333848 -0.23828473 -0.15263588 -0.14365152 -0.02841741]
# Iter 9: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.783008445789783
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.848517240889748e-06
#             Iterations: 6
#             Function evaluations: 339
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.04345226287841797s
# OP result error for index 26: 3.848517240889748e-06
# Iter 9 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300899 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365233 -0.02841757]
# Iter 10: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435734
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0358296424282116e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.015343904495239258s
# OP result error for index 44: 3.0358296424282116e-05
# Iter 10 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300899 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365233 -0.02841757]
# Iter 11: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964765
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3612436825490875e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 27 completed in 0.015356063842773438s
# OP result error for index 27: 4.3612436825490875e-05
# Iter 11 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830111  -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365544 -0.02841757]
# Iter 12: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.41333861087336
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9813774702347473e-06
#             Iterations: 5
#             Function evaluations: 277
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.035806894302368164s
# OP result error for index 28: 2.9813774702347473e-06
# Iter 12 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830101  -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14365397 -0.02841757]
# Iter 13: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001305760701599823
#             Iterations: 4
#             Function evaluations: 235
#             Gradient evaluations: 4
# Optimisation for index 67 completed in 0.03356742858886719s
# OP result error for index 67: 0.0001305760701599823
# Iter 13 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300589 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14364773 -0.02841757]
# Iter 14: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.920399300914255e-06
#             Iterations: 7
#             Function evaluations: 379
#             Gradient evaluations: 7
# Optimisation for index 43 completed in 0.04941201210021973s
# OP result error for index 43: 1.920399300914255e-06
# Iter 14 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300589 -1.45771465 -1.17127135 -0.41333861 -0.23828473 -0.15263588 -0.14364773 -0.02841757]
# Iter 15: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.14364773182221216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.624166056618975e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.015479803085327148s
# OP result error for index 66: 7.624166056618975e-05
# Iter 15 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300881 -1.45771465 -1.17127135 -0.41333561 -0.23828473 -0.15263588 -0.14365206 -0.02841362]
# Iter 16: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.028413619493493664
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7778058391270122e-05
#             Iterations: 3
#             Function evaluations: 184
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.023235082626342773s
# OP result error for index 68: 2.7778058391270122e-05
# Iter 16 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300702 -1.45771465 -1.17127135 -0.4133389  -0.23828473 -0.15263588 -0.14364941 -0.02841796]
# Iter 17: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -2.783007020526228
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.376080350088074e-05
#             Iterations: 7
#             Function evaluations: 405
#             Gradient evaluations: 7
# Optimisation for index 26 completed in 0.051660776138305664s
# OP result error for index 26: 4.376080350088074e-05
# Iter 17 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300602 -1.45771465 -1.17127135 -0.41333929 -0.23828473 -0.15263588 -0.14364793 -0.02841848]
# Iter 18: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -1.4577146507435734
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.19766144136247e-07
#             Iterations: 9
#             Function evaluations: 482
#             Gradient evaluations: 9
# Optimisation for index 44 completed in 0.06597304344177246s
# OP result error for index 44: 9.19766144136247e-07
# Iter 18 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300602 -1.45771465 -1.17127135 -0.41333929 -0.23828473 -0.15263588 -0.14364793 -0.02841848]
# Iter 19: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 2, 0), jdet: -1.1712713532964756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.855471224755718e-06
#             Iterations: 7
#             Function evaluations: 405
#             Gradient evaluations: 7
# Optimisation for index 27 completed in 0.051709890365600586s
# OP result error for index 27: 8.855471224755718e-06
# Iter 19 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300944 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365299 -0.02841754]
# Iter 20: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 2, 0), jdet: -0.4133385849618263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7579432197176743e-06
#             Iterations: 7
#             Function evaluations: 396
#             Gradient evaluations: 7
# Optimisation for index 28 completed in 0.05083012580871582s
# OP result error for index 28: 3.7579432197176743e-06
# Iter 20 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 21: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 2, 0), jdet: -0.2382847316452758
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.461923296350534e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 67 completed in 0.015596151351928711s
# OP result error for index 67: 4.461923296350534e-05
# Iter 21 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 22: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.15263587893771502
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.366429646855522e-07
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 43 completed in 0.008157968521118164s
# OP result error for index 43: 8.366429646855522e-07
# Iter 22 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127135 -0.41333858 -0.23828473 -0.15263588 -0.14365264 -0.02841754]
# Iter 23: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -0.1436526443744791
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014389535407666187
#             Iterations: 8
#             Function evaluations: 457
#             Gradient evaluations: 8
# Optimisation for index 66 completed in 0.058785200119018555s
# OP result error for index 66: 0.00014389535407666187
# Iter 23 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830146  -1.45771465 -1.17127246 -0.41333726 -0.2382853  -0.15263588 -0.14366109 -0.02841565]
# Iter 24: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 2, 0), jdet: -0.028415652388528
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.738247631510319e-05
#             Iterations: 3
#             Function evaluations: 184
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.024745941162109375s
# OP result error for index 68: 6.738247631510319e-05
# Iter 24 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300986 -1.45771465 -1.17127119 -0.41333886 -0.2382853  -0.15263588 -0.14365383 -0.02841776]
# Submatrix size is 7 from index 26
# Iter 25: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 3, 0), jdet: -2.783009856358327
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00018563541011307194
#             Iterations: 6
#             Function evaluations: 645
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.15412688255310059s
# OP result error for index 26: 0.00018563541011307194
# Iter 25 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301051 -1.45771465 -1.17127119 -0.41333938 -0.23828589 -0.15263588 -0.14365507 -0.02841829]
# Iter 26: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 3, 0), jdet: -1.4577146507435244
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0799863119359543e-06
#             Iterations: 5
#             Function evaluations: 508
#             Gradient evaluations: 5
# Optimisation for index 44 completed in 0.13210487365722656s
# OP result error for index 44: 1.0799863119359543e-06
# Iter 26 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301051 -1.45771465 -1.17127119 -0.41333938 -0.23828589 -0.15263588 -0.14365507 -0.02841829]
# Iter 27: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 3, 0), jdet: -1.1712711876682294
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.301198220335039e-05
#             Iterations: 5
#             Function evaluations: 535
#             Gradient evaluations: 5
# Optimisation for index 27 completed in 0.12795209884643555s
# OP result error for index 27: 9.301198220335039e-05
# Iter 27 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300972 -1.45771465 -1.17127119 -0.41333875 -0.23828518 -0.15263588 -0.14365358 -0.02841765]
# Iter 28: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 3, 0), jdet: -0.41333875320402197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001447497443329837
#             Iterations: 5
#             Function evaluations: 534
#             Gradient evaluations: 5
# Optimisation for index 28 completed in 0.13447904586791992s
# OP result error for index 28: 0.0001447497443329837
# Iter 28 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300997 -1.45771465 -1.17127119 -0.41333895 -0.2382854  -0.15263588 -0.14365405 -0.02841785]
# Iter 29: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 3, 0), jdet: -0.23828540127108078
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00029483011823838723
#             Iterations: 6
#             Function evaluations: 642
#             Gradient evaluations: 6
# Optimisation for index 67 completed in 0.15290594100952148s
# OP result error for index 67: 0.00029483011823838723
# Iter 29 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 30: Analysing index 43: Original coord: (3, 1, 0), nearest: (3, 3, 0), jdet: -0.15263587893766248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.7920550002043e-05
#             Iterations: 2
#             Function evaluations: 216
#             Gradient evaluations: 2
# Optimisation for index 43 completed in 0.05560493469238281s
# OP result error for index 43: 6.7920550002043e-05
# Iter 30 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 31: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 3, 0), jdet: -0.14365359812928583
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001853640469713369
#             Iterations: 2
#             Function evaluations: 213
#             Gradient evaluations: 2
# Optimisation for index 66 completed in 0.05150794982910156s
# OP result error for index 66: 0.0001853640469713369
# Iter 31 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301042 -1.45771465 -1.17127158 -0.41333663 -0.23828276 -0.15263588 -0.1436536  -0.02841546]
# Iter 32: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 3, 0), jdet: -0.028415463701414262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.968338713684517e-05
#             Iterations: 6
#             Function evaluations: 643
#             Gradient evaluations: 6
# Optimisation for index 68 completed in 0.1592390537261963s
# OP result error for index 68: 4.968338713684517e-05
# Iter 32 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300845 -1.45771465 -1.17127142 -0.41333926 -0.23828476 -0.15263588 -0.14365154 -0.02841842]
# Submatrix size is 9 from index 26
# Iter 33: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 4, 0), jdet: -2.7830084451160038
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.623574486581575e-05
#             Iterations: 5
#             Function evaluations: 854
#             Gradient evaluations: 5
# Optimisation for index 26 completed in 0.34836888313293457s
# OP result error for index 26: 7.623574486581575e-05
# Iter 33 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300977 -1.45771465 -1.17127197 -0.41333843 -0.23828476 -0.15263588 -0.1436536  -0.02841733]
# Iter 34: Analysing index 44: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -1.4577146507435252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010422256908526606
#             Iterations: 2
#             Function evaluations: 342
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.16730308532714844s
# OP result error for index 44: 0.00010422256908526606
# Iter 34 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300977 -1.45771465 -1.17127197 -0.41333843 -0.23828476 -0.15263588 -0.1436536  -0.02841733]
# Iter 35: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 4, 0), jdet: -1.171271971768923
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005185833078167335
#             Iterations: 7
#             Function evaluations: 1192
#             Gradient evaluations: 7
# Optimisation for index 27 completed in 0.4846949577331543s
# OP result error for index 27: 0.0005185833078167335
# Iter 35 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300417 -1.45771465 -1.17127132 -0.41333593 -0.23828474 -0.15263588 -0.14364518 -0.02841403]
# Iter 36: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 4, 0), jdet: -0.4133359280424118
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003565322700600504
#             Iterations: 4
#             Function evaluations: 687
#             Gradient evaluations: 4
# Optimisation for index 28 completed in 0.27947020530700684s
# OP result error for index 28: 0.0003565322700600504
# Iter 36 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300417 -1.45771465 -1.17127132 -0.41334234 -0.23828474 -0.15263588 -0.14364518 -0.02842249]
# Iter 37: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 4, 0), jdet: -0.23828474248527354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000240655202087936
#             Iterations: 4
#             Function evaluations: 693
#             Gradient evaluations: 4
# Optimisation for index 67 completed in 0.27985310554504395s
# OP result error for index 67: 0.000240655202087936
# Iter 37 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301088 -1.45771465 -1.17127132 -0.41333619 -0.23828474 -0.15263588 -0.14365513 -0.02841438]
# Iter 38: Analysing index 43: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.15263587893766248
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6042770227819858e-05
#             Iterations: 7
#             Function evaluations: 1182
#             Gradient evaluations: 7
# Optimisation for index 43 completed in 0.48055386543273926s
# OP result error for index 43: 1.6042770227819858e-05
# Iter 38 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301088 -1.45771465 -1.17127132 -0.41333619 -0.23828474 -0.15263588 -0.14365513 -0.02841438]
# Iter 39: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 4, 0), jdet: -0.14365513003323993
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.004867587458776e-05
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 66 completed in 0.34945082664489746s
# OP result error for index 66: 9.004867587458776e-05
# Iter 39 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127132 -0.41333825 -0.23828474 -0.15263588 -0.14365266 -0.02841709]
# Iter 40: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 4, 0), jdet: -0.02841709211467084
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016180859386505375
#             Iterations: 3
#             Function evaluations: 519
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.21018505096435547s
# OP result error for index 68: 0.00016180859386505375
# Iter 40 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300921 -1.45771465 -1.17127132 -0.41333999 -0.23828474 -0.15263588 -0.14365266 -0.02841939]
# Submatrix size is 11 from index 26
# Iter 41: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 5, 0), jdet: -2.7830092131457276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0007485560129141255
#             Iterations: 9
#             Function evaluations: 2256
#             Gradient evaluations: 9
# Optimisation for index 26 completed in 1.4170079231262207s
# OP result error for index 26: 0.0007485560129141255
# Iter 41 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300485 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14364619 -0.02841638]
# Iter 42: Analysing index 44: Original coord: (4, 1, 0), nearest: (5, 5, 0), jdet: -1.4577146507435226
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021533316758581833
#             Iterations: 2
#             Function evaluations: 501
#             Gradient evaluations: 2
# Optimisation for index 44 completed in 0.31041383743286133s
# OP result error for index 44: 0.00021533316758581833
# Iter 42 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300485 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14364619 -0.02841638]
# Iter 43: Analysing index 27: Original coord: (27, 0, 0), nearest: (27, 5, 0), jdet: -1.1712713235449415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005232495104556811
#             Iterations: 2
#             Function evaluations: 506
#             Gradient evaluations: 2
# Optimisation for index 27 completed in 0.309276819229126s
# OP result error for index 27: 0.0005232495104556811
# Iter 43 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301561 -1.45771465 -1.17127132 -0.41333771 -0.23828474 -0.15263588 -0.14366213 -0.02841638]
# Iter 44: Analysing index 28: Original coord: (28, 0, 0), nearest: (28, 5, 0), jdet: -0.4133377061662385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005293929275396181
#             Iterations: 6
#             Function evaluations: 1508
#             Gradient evaluations: 6
# Optimisation for index 28 completed in 0.9276771545410156s
# OP result error for index 28: 0.0005293929275396181
# Iter 44 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78301162 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365622 -0.02841795]
# Iter 45: Analysing index 67: Original coord: (27, 1, 0), nearest: (27, 5, 0), jdet: -0.23828474248527354
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00028825932282838806
#             Iterations: 3
#             Function evaluations: 757
#             Gradient evaluations: 3
# Optimisation for index 67 completed in 0.46071815490722656s
# OP result error for index 67: 0.00028825932282838806
# Iter 45 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830065  -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14364863 -0.02841795]
# Iter 46: Analysing index 43: Original coord: (3, 1, 0), nearest: (5, 5, 0), jdet: -0.15263587927482225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8762432084050715e-05
#             Iterations: 6
#             Function evaluations: 1499
#             Gradient evaluations: 6
# Optimisation for index 43 completed in 0.9221901893615723s
# OP result error for index 43: 2.8762432084050715e-05
# Iter 46 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.7830065  -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14364863 -0.02841795]
# Iter 47: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 5, 0), jdet: -0.1436486344148518
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010902819191738189
#             Iterations: 6
#             Function evaluations: 1505
#             Gradient evaluations: 6
# Optimisation for index 66 completed in 0.926102876663208s
# OP result error for index 66: 0.00010902819191738189
# Iter 47 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Iter 48: Analysing index 68: Original coord: (28, 1, 0), nearest: (28, 5, 0), jdet: -0.028417947723913886
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019313510833773861
#             Iterations: 3
#             Function evaluations: 760
#             Gradient evaluations: 3
# Optimisation for index 68 completed in 0.4662048816680908s
# OP result error for index 68: 0.00019313510833773861
# Iter 48 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Submatrix size is 13 from index 26
# Iter 49: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 6, 0), jdet: -2.783008361379013
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019217370337898387
#             Iterations: 3
#             Function evaluations: 1044
#             Gradient evaluations: 3
# Optimisation for index 26 completed in 0.9173910617828369s
# OP result error for index 26: 0.00019217370337898387
# Iter 49 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Iter 50: Analysing index 44: Original coord: (4, 1, 0), nearest: (6, 6, 0), jdet: -1.4577146510855747
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.859299394745833e-05
#             Iterations: 7
#             Function evaluations: 2404
#             Gradient evaluations: 7
# Optimisation for index 44 completed in 2.3414158821105957s
# OP result error for index 44: 6.859299394745833e-05
# Iter 50 end: 8 -ve jacs now at [26 44 27 28 67 43 66 68] : SITK: [-2.78300836 -1.45771465 -1.17127132 -0.4133389  -0.23828474 -0.15263588 -0.14365139 -0.02841795]
# Total time taken for iterative SLSQP : 13.66615915298462 split as [0.0447390079498291, 0.04411911964416504, 0.008177757263183594, 0.03492307662963867, 0.03860974311828613, 0.007925987243652344, 0.015156984329223633, 0.04359292984008789, 0.04345226287841797, 0.015343904495239258, 0.015356063842773438, 0.035806894302368164, 0.03356742858886719, 0.04941201210021973, 0.015479803085327148, 0.023235082626342773, 0.051660776138305664, 0.06597304344177246, 0.051709890365600586, 0.05083012580871582, 0.015596151351928711, 0.008157968521118164, 0.058785200119018555, 0.024745941162109375, 0.15412688255310059, 0.13210487365722656, 0.12795209884643555, 0.13447904586791992, 0.15290594100952148, 0.05560493469238281, 0.05150794982910156, 0.1592390537261963, 0.34836888313293457, 0.16730308532714844, 0.4846949577331543, 0.27947020530700684, 0.27985310554504395, 0.48055386543273926, 0.34945082664489746, 0.21018505096435547, 1.4170079231262207, 0.31041383743286133, 0.309276819229126, 0.9276771545410156, 0.46071815490722656, 0.9221901893615723, 0.926102876663208, 0.4662048816680908, 0.9173910617828369, 2.3414158821105957]
# Initial error: 22.87771808660633, final error: 22.87773128150679, deviation: 1.3791915100011423e-05
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#              x-def                 y-def            jacobian
#                min        max        min       max       min       max
# initial -19.988363  19.988363 -10.036366 -9.027486 -2.783009  5.709197
# final   -19.988363  19.988363 -10.036366 -9.027486 -2.783008  5.709197
# meshgrid shape for plot: (20, 40)

# %%
msample = np.array([
    [0, 2, 10],
    [0, 3, 5],
    [0, 6, 4],
    [0, 11, 5],
    [0, 15, 7],
    [0, 19, 12],
    [0, 15, 15],
    [0, 13, 22],
    [0, 19, 22],
    [0, 19, 27],
    [0, 15, 30],
    [0, 12, 33],
    [0, 10, 38],
    [0, 4, 37],
    [0, 6, 30],
    [0, 1, 33],
    [0, 5, 26],
    [0, 2, 23],
    [0, 1, 19],
    [0, 2, 14],
])
fsample = np.array([
    [0, 1, 7],
    [0, 5, 11],
    [0, 6, 1],
    [0, 15, 1],
    [0, 12, 2],
    [0, 16, 14],
    [0, 18, 17],
    [0, 15, 20],
    [0, 16, 24],
    [0, 19, 27],
    [0, 18, 34],
    [0, 17, 40],
    [0, 10, 35],
    [0, 6, 35],
    [0, 2, 34],
    [0, 3, 30],
    [0, 2, 26],
    [0, 2, 23],
    [0, 3, 20],
    [0, 2, 14],
])

fixed_sample = np.zeros((1, 20, 40))

run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [56, 36, 16, 17, 15, 35, 76, 55, 51, 9, 54, 50, 95, 10, 96, 49, 57]
# Iter 1: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -2.8894616462248934
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935444088221e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 56 completed in 0.04490971565246582s
# OP result error for index 56: 5.587935444088221e-07
# Iter 1 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680635 -1.92851593 -1.58841655 -1.55154387 -1.43149542 -0.86862691 -0.68957833 -0.45135254 -0.23619275 -0.20708392 -0.18852464 -0.17304736 -0.1478319  -0.03228745]
# Iter 2: Analysing index 36: Original coord: (36, 0, 0), nearest: (36, 2, 0), jdet: -2.657307117420434
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935457754267e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 36 completed in 0.04443812370300293s
# OP result error for index 36: 5.587935457754267e-07
# Iter 2 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680635 -1.92851593 -1.58841655 -1.55154387 -1.43149542 -0.86862691 -0.68957833 -0.45135254 -0.23619275 -0.20708392 -0.18852464 -0.17304736 -0.1478319  -0.03228745]
# Iter 3: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -2.210717525557954
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3698392772951646e-08
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 16 completed in 0.008248090744018555s
# OP result error for index 16: 5.3698392772951646e-08
# Iter 3 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680635 -1.92851593 -1.58841655 -1.55154387 -1.43149542 -0.86862691 -0.68957833 -0.45135253 -0.23619275 -0.20708392 -0.18852464 -0.17304736 -0.1478319  -0.03228745]
# Iter 4: Analysing index 17: Original coord: (17, 0, 0), nearest: (17, 2, 0), jdet: -2.176806352030626
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.264859159112847e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 17 completed in 0.041818857192993164s
# OP result error for index 17: 5.264859159112847e-07
# Iter 4 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680635 -1.92851594 -1.58841655 -1.55154387 -1.43149542 -0.86862691 -0.68957833 -0.45135254 -0.23619275 -0.20708392 -0.18852464 -0.17304736 -0.1478319  -0.03228745]
# Iter 5: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -1.9285159367096014
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.281539682970558e-06
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 15 completed in 0.015316963195800781s
# OP result error for index 15: 7.281539682970558e-06
# Iter 5 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.1768064  -1.92851571 -1.58841655 -1.55154387 -1.43149518 -0.86862691 -0.68957833 -0.4513522  -0.23619275 -0.20708372 -0.18852464 -0.17304736 -0.1478319  -0.03228748]
# Iter 6: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -1.588416548934187
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630801576264408e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 35 completed in 0.013866901397705078s
# OP result error for index 35: 2.7630801576264408e-06
# Iter 6 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.1768064  -1.92851571 -1.58841655 -1.55154387 -1.43149518 -0.86862691 -0.68957833 -0.4513522  -0.23619275 -0.20708372 -0.18852464 -0.17304736 -0.1478319  -0.03228748]
# Iter 7: Analysing index 76: Original coord: (36, 1, 0), nearest: (36, 2, 0), jdet: -1.5515438719659027
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.035829638987908e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 76 completed in 0.015369892120361328s
# OP result error for index 76: 3.035829638987908e-05
# Iter 7 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.1768064  -1.92851571 -1.58841655 -1.55154387 -1.43149518 -0.86862691 -0.68957833 -0.4513522  -0.23619275 -0.20708372 -0.18852464 -0.17304736 -0.1478319  -0.03228748]
# Iter 8: Analysing index 55: Original coord: (15, 1, 0), nearest: (15, 2, 0), jdet: -1.4314951796676672
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1976261692884334e-05
#             Iterations: 7
#             Function evaluations: 392
#             Gradient evaluations: 7
# Optimisation for index 55 completed in 0.05053997039794922s
# OP result error for index 55: 1.1976261692884334e-05
# Iter 8 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680614 -1.92851618 -1.58841655 -1.55154387 -1.43149569 -0.86862691 -0.68957833 -0.45135291 -0.23619275 -0.20708415 -0.18852464 -0.17304736 -0.1478319  -0.03228731]
# Iter 9: Analysing index 51: Original coord: (11, 1, 0), nearest: (11, 2, 0), jdet: -0.8686269075520325
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.467086913820945e-06
#             Iterations: 5
#             Function evaluations: 277
#             Gradient evaluations: 5
# Optimisation for index 51 completed in 0.03570413589477539s
# OP result error for index 51: 4.467086913820945e-06
# Iter 9 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680614 -1.92851618 -1.58841655 -1.55154387 -1.43149569 -0.86862691 -0.68957839 -0.4513528  -0.23619275 -0.20708415 -0.18852464 -0.17304736 -0.14783196 -0.03228731]
# Iter 10: Analysing index 9: Original coord: (9, 0, 0), nearest: (9, 2, 0), jdet: -0.6895783933382932
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.787226718013772e-06
#             Iterations: 6
#             Function evaluations: 329
#             Gradient evaluations: 6
# Optimisation for index 9 completed in 0.04267597198486328s
# OP result error for index 9: 3.787226718013772e-06
# Iter 10 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946165 -2.65730712 -2.21071753 -2.17680614 -1.92851618 -1.58841655 -1.55154387 -1.43149569 -0.86862693 -0.68957834 -0.4513528  -0.23619275 -0.20708415 -0.18852464 -0.17304736 -0.14783191 -0.03228731]
# Iter 11: Analysing index 54: Original coord: (14, 1, 0), nearest: (14, 2, 0), jdet: -0.45135279947792584
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.608350323199421e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 54 completed in 0.01544499397277832s
# OP result error for index 54: 3.608350323199421e-05
# Iter 11 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946223 -2.65730712 -2.21071812 -2.17680684 -1.928515   -1.58841655 -1.55154387 -1.43149439 -0.86862645 -0.68957834 -0.45135269 -0.23619275 -0.20708307 -0.18852464 -0.17304777 -0.14783191 -0.03228777]
# Iter 12: Analysing index 50: Original coord: (10, 1, 0), nearest: (10, 2, 0), jdet: -0.23619275283173724
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.960986854267609e-06
#             Iterations: 11
#             Function evaluations: 613
#             Gradient evaluations: 11
# Optimisation for index 50 completed in 0.09111618995666504s
# OP result error for index 50: 4.960986854267609e-06
# Iter 12 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946223 -2.65730712 -2.21071812 -2.17680684 -1.928515   -1.58841655 -1.55154387 -1.43149439 -0.868627   -0.68957834 -0.45135269 -0.23619275 -0.20708307 -0.18852464 -0.17304777 -0.1478319  -0.03228777]
# Iter 13: Analysing index 95: Original coord: (15, 2, 0), nearest: (15, 2, 0), jdet: -0.2070830740294065
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0085048941098694e-05
#             Iterations: 5
#             Function evaluations: 282
#             Gradient evaluations: 5
# Optimisation for index 95 completed in 0.03634309768676758s
# OP result error for index 95: 1.0085048941098694e-05
# Iter 13 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680616 -1.92851615 -1.58841655 -1.55154387 -1.43149566 -0.868627   -0.68957834 -0.45135269 -0.23619275 -0.20708412 -0.18852464 -0.17304738 -0.1478319  -0.03228732]
# Iter 14: Analysing index 10: Original coord: (10, 0, 0), nearest: (10, 2, 0), jdet: -0.18852463880627235
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2609021598180125e-05
#             Iterations: 2
#             Function evaluations: 122
#             Gradient evaluations: 2
# Optimisation for index 10 completed in 0.015508890151977539s
# OP result error for index 10: 3.2609021598180125e-05
# Iter 14 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680616 -1.92851615 -1.58841655 -1.55154387 -1.43149566 -0.868627   -0.68957782 -0.45135269 -0.23619275 -0.20708412 -0.18852464 -0.17304738 -0.14783134 -0.03228732]
# Iter 15: Analysing index 96: Original coord: (16, 2, 0), nearest: (16, 2, 0), jdet: -0.17304738217177074
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4786251791940646e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 96 completed in 0.015230894088745117s
# OP result error for index 96: 2.4786251791940646e-05
# Iter 15 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680678 -1.92851507 -1.58841655 -1.55154387 -1.43149447 -0.868627   -0.68957782 -0.45135186 -0.23619275 -0.20708314 -0.18852464 -0.17304738 -0.14783134 -0.03228773]
# Iter 16: Analysing index 49: Original coord: (9, 1, 0), nearest: (9, 2, 0), jdet: -0.14783133610386617
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.485752285418745e-06
#             Iterations: 10
#             Function evaluations: 552
#             Gradient evaluations: 10
# Optimisation for index 49 completed in 0.07114911079406738s
# OP result error for index 49: 5.485752285418745e-06
# Iter 16 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680678 -1.92851507 -1.58841655 -1.55154387 -1.43149447 -0.8686265  -0.68957829 -0.45135186 -0.23619275 -0.20708314 -0.18852464 -0.17304738 -0.14783185 -0.03228773]
# Iter 17: Analysing index 57: Original coord: (17, 1, 0), nearest: (17, 2, 0), jdet: -0.032287727555315636
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0992841328306164e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 57 completed in 0.01516103744506836s
# OP result error for index 57: 2.0992841328306164e-05
# Iter 17 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680678 -1.92851565 -1.58841655 -1.55154387 -1.43149511 -0.8686265  -0.68957829 -0.45135274 -0.23619275 -0.20708366 -0.18852464 -0.17304738 -0.14783185 -0.03228773]
# Iter 18: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -2.8894616792639787
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.1853145124114305e-05
#             Iterations: 11
#             Function evaluations: 634
#             Gradient evaluations: 11
# Optimisation for index 56 completed in 0.08972001075744629s
# OP result error for index 56: 4.1853145124114305e-05
# Iter 18 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680627 -1.92851589 -1.58841655 -1.55154387 -1.43149538 -0.8686265  -0.68957829 -0.45135269 -0.23619275 -0.20708388 -0.18852464 -0.17304738 -0.14783185 -0.03228739]
# Iter 19: Analysing index 36: Original coord: (36, 0, 0), nearest: (36, 2, 0), jdet: -2.6573071174204372
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0549132549799176e-06
#             Iterations: 7
#             Function evaluations: 379
#             Gradient evaluations: 7
# Optimisation for index 36 completed in 0.04955482482910156s
# OP result error for index 36: 2.0549132549799176e-06
# Iter 19 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680627 -1.92851589 -1.58841655 -1.55154387 -1.43149538 -0.8686265  -0.68957829 -0.45135269 -0.23619275 -0.20708388 -0.18852464 -0.17304738 -0.14783185 -0.03228739]
# Iter 20: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -2.210717559511932
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.829194001853187e-05
#             Iterations: 4
#             Function evaluations: 245
#             Gradient evaluations: 4
# Optimisation for index 16 completed in 0.03075408935546875s
# OP result error for index 16: 4.829194001853187e-05
# Iter 20 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680627 -1.92851589 -1.58841655 -1.55154387 -1.43149538 -0.8686265  -0.68957829 -0.45135146 -0.23619275 -0.20708388 -0.18852464 -0.17304738 -0.14783185 -0.03228739]
# Iter 21: Analysing index 17: Original coord: (17, 0, 0), nearest: (17, 2, 0), jdet: -2.176806269801943
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5217782744369015e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 17 completed in 0.015490055084228516s
# OP result error for index 17: 2.5217782744369015e-05
# Iter 21 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680627 -1.92851672 -1.58841655 -1.55154387 -1.43149629 -0.8686265  -0.68957829 -0.45135272 -0.23619275 -0.20708463 -0.18852464 -0.17304738 -0.14783185 -0.03228739]
# Iter 22: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -1.9285167182805227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.466972073239091e-05
#             Iterations: 5
#             Function evaluations: 286
#             Gradient evaluations: 5
# Optimisation for index 15 completed in 0.03660917282104492s
# OP result error for index 15: 5.466972073239091e-05
# Iter 22 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.1768071  -1.92851472 -1.58841655 -1.55154387 -1.43149408 -0.8686265  -0.68957829 -0.45135272 -0.23619275 -0.20708282 -0.18852464 -0.17304738 -0.14783185 -0.03228794]
# Iter 23: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -1.5884165489342017
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4349458881506016e-06
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 35 completed in 0.03498506546020508s
# OP result error for index 35: 1.4349458881506016e-06
# Iter 23 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.1768071  -1.92851472 -1.58841655 -1.55154387 -1.43149408 -0.8686265  -0.68957829 -0.45135272 -0.23619275 -0.20708282 -0.18852464 -0.17304738 -0.14783185 -0.03228794]
# Iter 24: Analysing index 76: Original coord: (36, 1, 0), nearest: (36, 2, 0), jdet: -1.5515438719659018
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1602949932659756e-06
#             Iterations: 9
#             Function evaluations: 484
#             Gradient evaluations: 9
# Optimisation for index 76 completed in 0.06812310218811035s
# OP result error for index 76: 1.1602949932659756e-06
# Iter 24 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.1768071  -1.92851472 -1.58841655 -1.55154387 -1.43149408 -0.8686265  -0.68957829 -0.45135272 -0.23619275 -0.20708282 -0.18852464 -0.17304738 -0.14783185 -0.03228794]
# Iter 25: Analysing index 55: Original coord: (15, 1, 0), nearest: (15, 2, 0), jdet: -1.431494079727697
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.583844844251841e-05
#             Iterations: 4
#             Function evaluations: 234
#             Gradient evaluations: 4
# Optimisation for index 55 completed in 0.029880762100219727s
# OP result error for index 55: 1.583844844251841e-05
# Iter 25 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680658 -1.9285156  -1.58841655 -1.55154387 -1.43149505 -0.8686265  -0.68957829 -0.45135272 -0.23619275 -0.20708362 -0.18852464 -0.17304738 -0.14783185 -0.0322876 ]
# Iter 26: Analysing index 51: Original coord: (11, 1, 0), nearest: (11, 2, 0), jdet: -0.8686265010400205
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016263781194634456
#             Iterations: 4
#             Function evaluations: 232
#             Gradient evaluations: 4
# Optimisation for index 51 completed in 0.029581069946289062s
# OP result error for index 51: 0.00016263781194634456
# Iter 26 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680658 -1.9285156  -1.58841655 -1.55154387 -1.43149505 -0.86862472 -0.68958049 -0.45135654 -0.23619275 -0.20708362 -0.18852464 -0.17304738 -0.14783425 -0.0322876 ]
# Iter 27: Analysing index 9: Original coord: (9, 0, 0), nearest: (9, 2, 0), jdet: -0.6895804939549504
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.034500139464886e-06
#             Iterations: 8
#             Function evaluations: 452
#             Gradient evaluations: 8
# Optimisation for index 9 completed in 0.05820512771606445s
# OP result error for index 9: 7.034500139464886e-06
# Iter 27 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946168 -2.65730712 -2.21071756 -2.17680658 -1.9285156  -1.58841655 -1.55154387 -1.43149505 -0.8686268  -0.6895784  -0.45135654 -0.23619275 -0.20708362 -0.18852464 -0.17304738 -0.14783197 -0.0322876 ]
# Iter 28: Analysing index 54: Original coord: (14, 1, 0), nearest: (14, 2, 0), jdet: -0.451356538246786
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.338731525907094e-06
#             Iterations: 7
#             Function evaluations: 410
#             Gradient evaluations: 7
# Optimisation for index 54 completed in 0.0519719123840332s
# OP result error for index 54: 9.338731525907094e-06
# Iter 28 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680651 -1.92851571 -1.58841655 -1.55154387 -1.43149518 -0.86862685 -0.6895784  -0.45135251 -0.23619275 -0.20708372 -0.18852464 -0.17304736 -0.14783197 -0.03228755]
# Iter 29: Analysing index 50: Original coord: (10, 1, 0), nearest: (10, 2, 0), jdet: -0.23619275283173735
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4872916695764411e-05
#             Iterations: 3
#             Function evaluations: 182
#             Gradient evaluations: 3
# Optimisation for index 50 completed in 0.023012161254882812s
# OP result error for index 50: 1.4872916695764411e-05
# Iter 29 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680651 -1.92851571 -1.58841655 -1.55154387 -1.43149518 -0.86862714 -0.68957808 -0.45135251 -0.23619275 -0.20708372 -0.18852464 -0.17304736 -0.14783162 -0.03228755]
# Iter 30: Analysing index 95: Original coord: (15, 2, 0), nearest: (15, 2, 0), jdet: -0.20708372278685808
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.724940823409424e-05
#             Iterations: 2
#             Function evaluations: 118
#             Gradient evaluations: 2
# Optimisation for index 95 completed in 0.015229940414428711s
# OP result error for index 95: 3.724940823409424e-05
# Iter 30 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680574 -1.92851702 -1.58841655 -1.55154387 -1.43149662 -0.86862714 -0.68957808 -0.45135338 -0.23619275 -0.20708491 -0.18852464 -0.17304736 -0.14783162 -0.03228704]
# Iter 31: Analysing index 10: Original coord: (10, 0, 0), nearest: (10, 2, 0), jdet: -0.18852463880627457
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.020818223764191e-05
#             Iterations: 3
#             Function evaluations: 179
#             Gradient evaluations: 3
# Optimisation for index 10 completed in 0.0227658748626709s
# OP result error for index 10: 1.020818223764191e-05
# Iter 31 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680574 -1.92851702 -1.58841655 -1.55154387 -1.43149662 -0.86862682 -0.68957843 -0.45135338 -0.23619275 -0.20708491 -0.18852464 -0.17304736 -0.147832   -0.03228704]
# Iter 32: Analysing index 96: Original coord: (16, 2, 0), nearest: (16, 2, 0), jdet: -0.17304735837507004
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001450508937531266
#             Iterations: 6
#             Function evaluations: 344
#             Gradient evaluations: 6
# Optimisation for index 96 completed in 0.043992042541503906s
# OP result error for index 96: 0.0001450508937531266
# Iter 32 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680546 -1.9285134  -1.58841655 -1.55154387 -1.43149263 -0.86862682 -0.68957843 -0.45134878 -0.23619275 -0.20708163 -0.18852464 -0.17304674 -0.147832   -0.03228685]
# Iter 33: Analysing index 49: Original coord: (9, 1, 0), nearest: (9, 2, 0), jdet: -0.14783199941944078
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3038989370706716e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 49 completed in 0.015590906143188477s
# OP result error for index 49: 4.3038989370706716e-05
# Iter 33 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680546 -1.9285134  -1.58841655 -1.55154387 -1.43149263 -0.86862629 -0.68957843 -0.45134878 -0.23619275 -0.20708163 -0.18852464 -0.17304674 -0.147832   -0.03228685]
# Iter 34: Analysing index 57: Original coord: (17, 1, 0), nearest: (17, 2, 0), jdet: -0.032286853041454885
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.489401329915809e-05
#             Iterations: 7
#             Function evaluations: 403
#             Gradient evaluations: 7
# Optimisation for index 57 completed in 0.05130505561828613s
# OP result error for index 57: 1.489401329915809e-05
# Iter 34 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680654 -1.92851575 -1.58841655 -1.55154387 -1.43149522 -0.86862629 -0.68957843 -0.45135235 -0.23619275 -0.20708375 -0.18852464 -0.17304736 -0.147832   -0.03228757]
# Iter 35: Analysing index 56: Original coord: (16, 1, 0), nearest: (16, 2, 0), jdet: -2.8894616210027477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.214081602146779e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 56 completed in 0.015547990798950195s
# OP result error for index 56: 4.214081602146779e-05
# Iter 35 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680499 -1.92851707 -1.58841655 -1.55154387 -1.43149667 -0.86862629 -0.68957843 -0.45135335 -0.23619275 -0.20708495 -0.18852464 -0.17304736 -0.147832   -0.03228654]
# Iter 36: Analysing index 36: Original coord: (36, 0, 0), nearest: (36, 2, 0), jdet: -2.6573071174204363
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.003000286333103e-05
#             Iterations: 2
#             Function evaluations: 120
#             Gradient evaluations: 2
# Optimisation for index 36 completed in 0.015247821807861328s
# OP result error for index 36: 4.003000286333103e-05
# Iter 36 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680499 -1.92851707 -1.58841655 -1.55154387 -1.43149667 -0.86862629 -0.68957843 -0.45135335 -0.23619275 -0.20708495 -0.18852464 -0.17304736 -0.147832   -0.03228654]
# Iter 37: Analysing index 16: Original coord: (16, 0, 0), nearest: (16, 2, 0), jdet: -2.2107174996373558
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.403569895318021e-06
#             Iterations: 5
#             Function evaluations: 285
#             Gradient evaluations: 5
# Optimisation for index 16 completed in 0.05550384521484375s
# OP result error for index 16: 5.403569895318021e-06
# Iter 37 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680646 -1.92851582 -1.58841655 -1.55154387 -1.4314953  -0.86862629 -0.68957843 -0.4513524  -0.23619275 -0.20708382 -0.18852464 -0.17304735 -0.147832   -0.03228751]
# Iter 38: Analysing index 17: Original coord: (17, 0, 0), nearest: (17, 2, 0), jdet: -2.1768064553686215
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.870308249833035e-06
#             Iterations: 7
#             Function evaluations: 397
#             Gradient evaluations: 7
# Optimisation for index 17 completed in 0.05079007148742676s
# OP result error for index 17: 7.870308249833035e-06
# Iter 38 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680616 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862629 -0.68957843 -0.4513526  -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.147832   -0.03228732]
# Iter 39: Analysing index 15: Original coord: (15, 0, 0), nearest: (15, 2, 0), jdet: -1.9285159480865024
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.115931762460458e-05
#             Iterations: 7
#             Function evaluations: 406
#             Gradient evaluations: 7
# Optimisation for index 15 completed in 0.05175614356994629s
# OP result error for index 15: 6.115931762460458e-05
# Iter 39 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680724 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862629 -0.68957843 -0.4513526  -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.147832   -0.03228804]
# Iter 40: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -1.5884165489342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.9830964052960105e-06
#             Iterations: 5
#             Function evaluations: 286
#             Gradient evaluations: 5
# Optimisation for index 35 completed in 0.036550045013427734s
# OP result error for index 35: 3.9830964052960105e-06
# Iter 40 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680724 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862629 -0.68957843 -0.4513526  -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.147832   -0.03228804]
# Iter 41: Analysing index 76: Original coord: (36, 1, 0), nearest: (36, 2, 0), jdet: -1.5515438719659014
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.203065405294221e-05
#             Iterations: 2
#             Function evaluations: 118
#             Gradient evaluations: 2
# Optimisation for index 76 completed in 0.01517486572265625s
# OP result error for index 76: 4.203065405294221e-05
# Iter 41 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680724 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862629 -0.68957843 -0.4513526  -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.147832   -0.03228804]
# Iter 42: Analysing index 55: Original coord: (15, 1, 0), nearest: (15, 2, 0), jdet: -1.4314954369855586
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2955037605474655e-06
#             Iterations: 5
#             Function evaluations: 288
#             Gradient evaluations: 5
# Optimisation for index 55 completed in 0.03682589530944824s
# OP result error for index 55: 3.2955037605474655e-06
# Iter 42 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680628 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862629 -0.68957843 -0.4513526  -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.147832   -0.0322874 ]
# Iter 43: Analysing index 51: Original coord: (11, 1, 0), nearest: (11, 2, 0), jdet: -0.8686262880295841
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7515297942888768e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 51 completed in 0.024524927139282227s
# OP result error for index 51: 2.7515297942888768e-05
# Iter 43 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680628 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.8686275  -0.68957777 -0.45135146 -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.14783129 -0.0322874 ]
# Iter 44: Analysing index 9: Original coord: (9, 0, 0), nearest: (9, 2, 0), jdet: -0.6895777707692513
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.358987134715057e-06
#             Iterations: 9
#             Function evaluations: 507
#             Gradient evaluations: 9
# Optimisation for index 9 completed in 0.06541776657104492s
# OP result error for index 9: 9.358987134715057e-06
# Iter 44 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946162 -2.65730712 -2.2107175  -2.17680628 -1.92851595 -1.58841655 -1.55154387 -1.43149544 -0.86862742 -0.68957827 -0.45135146 -0.23619275 -0.20708393 -0.18852464 -0.17304735 -0.14783183 -0.0322874 ]
# Iter 45: Analysing index 54: Original coord: (14, 1, 0), nearest: (14, 2, 0), jdet: -0.4513514615087265
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.188589234693548e-05
#             Iterations: 3
#             Function evaluations: 181
#             Gradient evaluations: 3
# Optimisation for index 54 completed in 0.022884845733642578s
# OP result error for index 54: 2.188589234693548e-05
# Iter 45 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946223 -2.65730712 -2.21071813 -2.17680701 -1.92851538 -1.58841655 -1.55154387 -1.43149481 -0.86862691 -0.68957827 -0.45135175 -0.23619275 -0.20708342 -0.18852464 -0.17304747 -0.14783183 -0.03228788]
# Iter 46: Analysing index 50: Original coord: (10, 1, 0), nearest: (10, 2, 0), jdet: -0.2361927528346543
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.468425871118845e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 50 completed in 0.015587806701660156s
# OP result error for index 50: 4.468425871118845e-05
# Iter 46 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946223 -2.65730712 -2.21071813 -2.17680701 -1.92851538 -1.58841655 -1.55154387 -1.43149481 -0.86862691 -0.6895794  -0.45135175 -0.23619275 -0.20708342 -0.18852464 -0.17304747 -0.14783305 -0.03228788]
# Iter 47: Analysing index 95: Original coord: (15, 2, 0), nearest: (15, 2, 0), jdet: -0.20708342057037765
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.44589608907199e-05
#             Iterations: 10
#             Function evaluations: 573
#             Gradient evaluations: 10
# Optimisation for index 95 completed in 0.07360291481018066s
# OP result error for index 95: 5.44589608907199e-05
# Iter 47 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946099 -2.65730712 -2.21071686 -2.17680666 -1.92851664 -1.58841655 -1.55154387 -1.4314962  -0.86862691 -0.6895794  -0.45135366 -0.23619275 -0.20708456 -0.18852464 -0.17304673 -0.14783305 -0.03228765]
# Iter 48: Analysing index 10: Original coord: (10, 0, 0), nearest: (10, 2, 0), jdet: -0.18852463880585202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3953068443905634e-06
#             Iterations: 5
#             Function evaluations: 277
#             Gradient evaluations: 5
# Optimisation for index 10 completed in 0.04343914985656738s
# OP result error for index 10: 1.3953068443905634e-06
# Iter 48 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946099 -2.65730712 -2.21071686 -2.17680666 -1.92851664 -1.58841655 -1.55154387 -1.4314962  -0.86862691 -0.68957836 -0.45135366 -0.23619275 -0.20708456 -0.18852464 -0.17304673 -0.14783192 -0.03228765]
# Iter 49: Analysing index 96: Original coord: (16, 2, 0), nearest: (16, 2, 0), jdet: -0.1730467327358197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3547527663528784e-05
#             Iterations: 5
#             Function evaluations: 294
#             Gradient evaluations: 5
# Optimisation for index 96 completed in 0.037938833236694336s
# OP result error for index 96: 1.3547527663528784e-05
# Iter 49 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946186 -2.65730712 -2.21071774 -2.17680626 -1.92851576 -1.58841655 -1.55154387 -1.43149523 -0.86862691 -0.68957836 -0.45135406 -0.23619275 -0.20708377 -0.18852464 -0.17304748 -0.14783192 -0.03228739]
# Iter 50: Analysing index 49: Original coord: (9, 1, 0), nearest: (9, 2, 0), jdet: -0.14783192308974508
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013262760357786481
#             Iterations: 5
#             Function evaluations: 288
#             Gradient evaluations: 5
# Optimisation for index 49 completed in 0.03682088851928711s
# OP result error for index 49: 0.00013262760357786481
# Iter 50 end: 17 -ve jacs now at [56 36 16 17 15 35 76 55 51  9 54 50 95 10 96 49 57] : SITK: [-2.88946186 -2.65730712 -2.21071774 -2.17680626 -1.92851576 -1.58841655 -1.55154387 -1.43149523 -0.86862874 -0.68957836 -0.45135406 -0.23619275 -0.20708377 -0.18852464 -0.17304748 -0.14783192 -0.03228739]
# Total time taken for iterative SLSQP : 1.9891431331634521 split as [0.04490971565246582, 0.04443812370300293, 0.008248090744018555, 0.041818857192993164, 0.015316963195800781, 0.013866901397705078, 0.015369892120361328, 0.05053997039794922, 0.03570413589477539, 0.04267597198486328, 0.01544499397277832, 0.09111618995666504, 0.03634309768676758, 0.015508890151977539, 0.015230894088745117, 0.07114911079406738, 0.01516103744506836, 0.08972001075744629, 0.04955482482910156, 0.03075408935546875, 0.015490055084228516, 0.03660917282104492, 0.03498506546020508, 0.06812310218811035, 0.029880762100219727, 0.029581069946289062, 0.05820512771606445, 0.0519719123840332, 0.023012161254882812, 0.015229940414428711, 0.0227658748626709, 0.043992042541503906, 0.015590906143188477, 0.05130505561828613, 0.015547990798950195, 0.015247821807861328, 0.05550384521484375, 0.05079007148742676, 0.05175614356994629, 0.036550045013427734, 0.01517486572265625, 0.03682589530944824, 0.024524927139282227, 0.06541776657104492, 0.022884845733642578, 0.015587806701660156, 0.07360291481018066, 0.04343914985656738, 0.037938833236694336, 0.03682088851928711]
# Initial error: 37.83499507499322, final error: 37.835020892417, deviation: 2.3579974160023897e-05
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#             x-def               y-def            jacobian
#               min       max       min       max       min       max
# initial -6.999329  4.999521 -4.999517  3.999614 -2.889462  3.665345
# final   -6.999330  4.999521 -4.999517  3.999613 -2.889462  3.665344
# meshgrid shape for plot: (20, 40)

# %% [markdown]
# ## Testcases

# %%
msample = np.array([
    [0, 1, 0],
    [0, 2, 3],
])
fsample = np.array([
    [0, 1, 3],
    [0, 2, 0],
])

fixed_sample = np.zeros((1, 10, 10)) # depth, rows, cols

run_lapl_and_correction(fixed_sample, msample, fsample)

# takes 15 mins and does not conclude on full 20x40 constraints
# 1.5mins on 10x10 constraints
# reduce constraints
# (10,5) - 50 vs 5 - 3.9s vs 0.15s
# (5,5) - 25 vs 5 - 0.35s vs 0.0645s
# (10, 10) - 100 vs 5 - 50s vs 0.46s
# (20, 20) - 400 vs 5 - waited for full one to run for 20min vs 1.5min

# 20x40 with 5 random constraints - 10.5 mins
# 20x40 run over the full thing - 174 min does not finish
# Out:
# deformation shape: (3, 1, 10, 10)
# deformation_i shape: (3, 1, 10, 10), phi_init shape: (2, 10, 10)
# init: Negative Jacobians found at [3, 13, 2]
# Iter 1: Analysing index 3: Original coord: (3, 0, 0), nearest: (3, 2, 0), jdet: -1.9997038720119469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935452968964e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 3 completed in 0.044621944427490234s
# OP result error for index 3: 5.587935452968964e-07
# Iter 1 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 2: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.22246732665877378
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.369840478419061e-08
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 13 completed in 0.008317947387695312s
# OP result error for index 13: 5.369840478419061e-08
# Iter 2 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 3: Analysing index 2: Original coord: (2, 0, 0), nearest: (2, 2, 0), jdet: -0.009535490366422514
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.264858004089248e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 2 completed in 0.04413008689880371s
# OP result error for index 2: 5.264858004089248e-07
# Iter 3 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 4: Analysing index 3: Original coord: (3, 0, 0), nearest: (3, 2, 0), jdet: -1.9997038720115956
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4973951448240163e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 3 completed in 0.00806117057800293s
# OP result error for index 3: 1.4973951448240163e-06
# Iter 4 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 5: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.22246732665877963
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.554696931184542e-07
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.03517580032348633s
# OP result error for index 13: 8.554696931184542e-07
# Iter 5 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 6: Analysing index 2: Original coord: (2, 0, 0), nearest: (2, 2, 0), jdet: -0.009535490369482345
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.838243549959413e-08
#             Iterations: 1
#             Function evaluations: 61
#             Gradient evaluations: 1
# Optimisation for index 2 completed in 0.007782936096191406s
# OP result error for index 2: 5.838243549959413e-08
# Iter 6 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970387 -0.22246733 -0.00953549]
# Iter 7: Analysing index 3: Original coord: (3, 0, 0), nearest: (3, 2, 0), jdet: -1.9997038720029194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.251622217083592e-05
#             Iterations: 2
#             Function evaluations: 118
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.020801067352294922s
# OP result error for index 3: 3.251622217083592e-05
# Iter 7 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 8: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.22246732667133534
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.339396695814248e-06
#             Iterations: 9
#             Function evaluations: 482
#             Gradient evaluations: 9
# Optimisation for index 13 completed in 0.06345295906066895s
# OP result error for index 13: 1.339396695814248e-06
# Iter 8 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 9: Analysing index 2: Original coord: (2, 0, 0), nearest: (2, 2, 0), jdet: -0.009535496446786949
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6066295809727987e-07
#             Iterations: 5
#             Function evaluations: 268
#             Gradient evaluations: 5
# Optimisation for index 2 completed in 0.034852027893066406s
# OP result error for index 2: 2.6066295809727987e-07
# Iter 9 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Submatrix size is 7 from index 3
# Iter 10: Analysing index 3: Original coord: (3, 0, 0), nearest: (3, 3, 0), jdet: -1.9997038791011148
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.152307740588231e-05
#             Iterations: 2
#             Function evaluations: 215
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.05195307731628418s
# OP result error for index 3: 8.152307740588231e-05
# Iter 10 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 11: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 3, 0), jdet: -0.22246732667121655
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.076359191931598e-06
#             Iterations: 6
#             Function evaluations: 625
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.1650390625s
# OP result error for index 13: 4.076359191931598e-06
# Iter 11 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 12: Analysing index 2: Original coord: (2, 0, 0), nearest: (3, 3, 0), jdet: -0.009535496446787323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.06735633289879e-06
#             Iterations: 5
#             Function evaluations: 516
#             Gradient evaluations: 5
# Optimisation for index 2 completed in 0.12515902519226074s
# OP result error for index 2: 7.06735633289879e-06
# Iter 12 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Submatrix size is 9 from index 3
# Iter 13: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.999703879101115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2340398748163381e-05
#             Iterations: 5
#             Function evaluations: 837
#             Gradient evaluations: 5
# Optimisation for index 3 completed in 0.34287190437316895s
# OP result error for index 3: 1.2340398748163381e-05
# Iter 13 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 14: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.2224673266712166
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9454935683128736e-05
#             Iterations: 5
#             Function evaluations: 846
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3473968505859375s
# OP result error for index 13: 1.9454935683128736e-05
# Iter 14 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 15: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535496446786675
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001502984590710508
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 2 completed in 0.13918471336364746s
# OP result error for index 2: 0.0001502984590710508
# Iter 15 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 16: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997038791011146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.825745894450816e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.1422278881072998s
# OP result error for index 3: 6.825745894450816e-05
# Iter 16 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 17: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246732667121596
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019771981429081222
#             Iterations: 7
#             Function evaluations: 1182
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.48081517219543457s
# OP result error for index 13: 0.00019771981429081222
# Iter 17 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 18: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535496446787953
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.048312678546387e-05
#             Iterations: 8
#             Function evaluations: 1358
#             Gradient evaluations: 8
# Optimisation for index 2 completed in 0.5510618686676025s
# OP result error for index 2: 3.048312678546387e-05
# Iter 18 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 19: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997038791011144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013568998903911876
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.13987517356872559s
# OP result error for index 3: 0.00013568998903911876
# Iter 19 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 20: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246732667121596
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7373926574562985e-06
#             Iterations: 6
#             Function evaluations: 1000
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4113149642944336s
# OP result error for index 13: 2.7373926574562985e-06
# Iter 20 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 21: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535496446787904
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.12031023897438e-05
#             Iterations: 2
#             Function evaluations: 345
#             Gradient evaluations: 2
# Optimisation for index 2 completed in 0.13857293128967285s
# OP result error for index 2: 7.12031023897438e-05
# Iter 21 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 22: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997038791011144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.3446788358374056e-05
#             Iterations: 9
#             Function evaluations: 1527
#             Gradient evaluations: 9
# Optimisation for index 3 completed in 0.6221151351928711s
# OP result error for index 3: 4.3446788358374056e-05
# Iter 22 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 23: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246732667121594
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015002366702505753
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.1390392780303955s
# OP result error for index 13: 0.00015002366702505753
# Iter 23 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 24: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535496446788168
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6511494068491616e-05
#             Iterations: 7
#             Function evaluations: 1189
#             Gradient evaluations: 7
# Optimisation for index 2 completed in 0.5095911026000977s
# OP result error for index 2: 1.6511494068491616e-05
# Iter 24 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970388 -0.22246733 -0.0095355 ]
# Iter 25: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997038791011146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013886907487245412
#             Iterations: 7
#             Function evaluations: 1184
#             Gradient evaluations: 7
# Optimisation for index 3 completed in 0.4856698513031006s
# OP result error for index 3: 0.00013886907487245412
# Iter 25 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970385 -0.22246733 -0.00953547]
# Iter 26: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.2224673266712162
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00042172987475960224
#             Iterations: 6
#             Function evaluations: 1026
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.41896986961364746s
# OP result error for index 13: 0.00042172987475960224
# Iter 26 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970544 -0.22246731 -0.00953682]
# Iter 27: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009536819001145379
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.382284137117475e-05
#             Iterations: 8
#             Function evaluations: 1354
#             Gradient evaluations: 8
# Optimisation for index 2 completed in 0.5554289817810059s
# OP result error for index 2: 3.382284137117475e-05
# Iter 27 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.9997041  -0.22246731 -0.00953567]
# Iter 28: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997041003466147
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012629291573737538
#             Iterations: 2
#             Function evaluations: 343
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.13791394233703613s
# OP result error for index 3: 0.00012629291573737538
# Iter 28 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.9997031  -0.22246731 -0.00953481]
# Iter 29: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246730762507994
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6692509044225995e-05
#             Iterations: 4
#             Function evaluations: 682
#             Gradient evaluations: 4
# Optimisation for index 13 completed in 0.27891993522644043s
# OP result error for index 13: 3.6692509044225995e-05
# Iter 29 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970373 -0.22246732 -0.00953536]
# Iter 30: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535358790791634
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002541477721182282
#             Iterations: 4
#             Function evaluations: 679
#             Gradient evaluations: 4
# Optimisation for index 2 completed in 0.2779858112335205s
# OP result error for index 2: 0.0002541477721182282
# Iter 30 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970246 -0.22246732 -0.00953426]
# Iter 31: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997024579182827
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.310483425160903e-05
#             Iterations: 9
#             Function evaluations: 1534
#             Gradient evaluations: 9
# Optimisation for index 3 completed in 0.6226019859313965s
# OP result error for index 3: 3.310483425160903e-05
# Iter 31 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970452 -0.22246732 -0.00953603]
# Iter 32: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246731629456395
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015640761236416676
#             Iterations: 3
#             Function evaluations: 514
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.20886492729187012s
# OP result error for index 13: 0.00015640761236416676
# Iter 32 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970288 -0.22246732 -0.00953463]
# Iter 33: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.00953463021692886
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7312200420369845e-05
#             Iterations: 3
#             Function evaluations: 510
#             Gradient evaluations: 3
# Optimisation for index 2 completed in 0.20679497718811035s
# OP result error for index 2: 4.7312200420369845e-05
# Iter 33 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970356 -0.22246732 -0.00953521]
# Iter 34: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997035609751197
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00095753211115062
#             Iterations: 8
#             Function evaluations: 1353
#             Gradient evaluations: 8
# Optimisation for index 3 completed in 0.5496439933776855s
# OP result error for index 3: 0.00095753211115062
# Iter 34 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970391 -0.22246732 -0.00953551]
# Iter 35: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246731631414565
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00043447033625566107
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3486449718475342s
# OP result error for index 13: 0.00043447033625566107
# Iter 35 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99969717 -0.22247164 -0.00952596]
# Iter 36: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009525955890904811
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.725648288603314e-05
#             Iterations: 5
#             Function evaluations: 853
#             Gradient evaluations: 5
# Optimisation for index 2 completed in 0.3469407558441162s
# OP result error for index 2: 6.725648288603314e-05
# Iter 36 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970201 -0.2224675  -0.00953378]
# Iter 37: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.99970200584907
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011098234898093459
#             Iterations: 3
#             Function evaluations: 520
#             Gradient evaluations: 3
# Optimisation for index 3 completed in 0.21219992637634277s
# OP result error for index 3: 0.00011098234898093459
# Iter 37 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970421 -0.22246749 -0.00953581]
# Iter 38: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246749036498298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0004176995047767201
#             Iterations: 6
#             Function evaluations: 1017
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4155290126800537s
# OP result error for index 13: 0.0004176995047767201
# Iter 38 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970205 -0.22246865 -0.00953349]
# Iter 39: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009533492353479986
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.553508956123237e-05
#             Iterations: 6
#             Function evaluations: 1028
#             Gradient evaluations: 6
# Optimisation for index 2 completed in 0.42041921615600586s
# OP result error for index 2: 6.553508956123237e-05
# Iter 39 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970269 -0.22246708 -0.0095345 ]
# Iter 40: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.999702687626666
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010584829180401551
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 3 completed in 0.13984894752502441s
# OP result error for index 3: 0.00010584829180401551
# Iter 40 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970504 -0.22246713 -0.00953673]
# Iter 41: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.2224671332331991
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.982550815291808e-05
#             Iterations: 9
#             Function evaluations: 1517
#             Gradient evaluations: 9
# Optimisation for index 13 completed in 0.6207990646362305s
# OP result error for index 13: 7.982550815291808e-05
# Iter 41 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970219 -0.22246719 -0.0095344 ]
# Iter 42: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009534401443237682
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011936818551829925
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 2 completed in 0.1390979290008545s
# OP result error for index 2: 0.00011936818551829925
# Iter 42 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970571 -0.22246738 -0.00953704]
# Iter 43: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.999705714785271
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.353242796295248e-05
#             Iterations: 3
#             Function evaluations: 510
#             Gradient evaluations: 3
# Optimisation for index 3 completed in 0.20807981491088867s
# OP result error for index 3: 2.353242796295248e-05
# Iter 43 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970447 -0.22246736 -0.00953589]
# Iter 44: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246736284245014
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00036392233148996496
#             Iterations: 4
#             Function evaluations: 678
#             Gradient evaluations: 4
# Optimisation for index 13 completed in 0.2753560543060303s
# OP result error for index 13: 0.00036392233148996496
# Iter 44 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970789 -0.22246736 -0.00953934]
# Iter 45: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.0095393440377662
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.943671932100881e-05
#             Iterations: 6
#             Function evaluations: 1029
#             Gradient evaluations: 6
# Optimisation for index 2 completed in 0.4280848503112793s
# OP result error for index 2: 3.943671932100881e-05
# Iter 45 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.9997043  -0.22246734 -0.00953575]
# Iter 46: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.999704299581485
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001478465734888643
#             Iterations: 3
#             Function evaluations: 516
#             Gradient evaluations: 3
# Optimisation for index 3 completed in 0.2085411548614502s
# OP result error for index 3: 0.0001478465734888643
# Iter 46 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970224 -0.22246735 -0.00953382]
# Iter 47: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246735137621906
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.92642259553287e-05
#             Iterations: 6
#             Function evaluations: 1019
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.41573476791381836s
# OP result error for index 13: 5.92642259553287e-05
# Iter 47 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970501 -0.22246734 -0.00953553]
# Iter 48: Analysing index 2: Original coord: (2, 0, 0), nearest: (4, 4, 0), jdet: -0.009535531904843632
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.367482440026862e-05
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 2 completed in 0.21044087409973145s
# OP result error for index 2: 7.367482440026862e-05
# Iter 48 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99970272 -0.22246736 -0.00953392]
# Iter 49: Analysing index 3: Original coord: (3, 0, 0), nearest: (4, 4, 0), jdet: -1.9997027203007574
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0017017661307002665
#             Iterations: 6
#             Function evaluations: 1018
#             Gradient evaluations: 6
# Optimisation for index 3 completed in 0.4163472652435303s
# OP result error for index 3: 0.0017017661307002665
# Iter 49 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99971642 -0.22246616 -0.00954391]
# Iter 50: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.22246615977402867
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.001362662553195117
#             Iterations: 2
#             Function evaluations: 342
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.13841891288757324s
# OP result error for index 13: 0.001362662553195117
# Iter 50 end: 3 -ve jacs now at [ 3 13  2] : SITK: [-1.99971642 -0.22247014 -0.00954382]
# Total time taken for iterative SLSQP : 13.471743106842041 split as [0.044621944427490234, 0.008317947387695312, 0.04413008689880371, 0.00806117057800293, 0.03517580032348633, 0.007782936096191406, 0.020801067352294922, 0.06345295906066895, 0.034852027893066406, 0.05195307731628418, 0.1650390625, 0.12515902519226074, 0.34287190437316895, 0.3473968505859375, 0.13918471336364746, 0.1422278881072998, 0.48081517219543457, 0.5510618686676025, 0.13987517356872559, 0.4113149642944336, 0.13857293128967285, 0.6221151351928711, 0.1390392780303955, 0.5095911026000977, 0.4856698513031006, 0.41896986961364746, 0.5554289817810059, 0.13791394233703613, 0.27891993522644043, 0.2779858112335205, 0.6226019859313965, 0.20886492729187012, 0.20679497718811035, 0.5496439933776855, 0.3486449718475342, 0.3469407558441162, 0.21219992637634277, 0.4155290126800537, 0.42041921615600586, 0.13984894752502441, 0.6207990646362305, 0.1390979290008545, 0.20807981491088867, 0.2753560543060303, 0.4280848503112793, 0.2085411548614502, 0.41573476791381836, 0.21044087409973145, 0.4163472652435303, 0.13841891288757324]
# Initial error: 8.27032530912797, final error: 8.270447883958111, deviation: 0.00013425255648068495
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#             x-def               y-def            jacobian
#               min       max       min       max       min       max
# initial -2.999704  2.999704  0.000000  0.000000 -1.999704  1.852443
# final   -2.999707  2.999694 -0.000019  0.000019 -1.999716  1.852453
# meshgrid shape for plot: (10, 10)

# %%
msample = np.array([
    [0, 0, 0],
    [0, 4, 0],
])
fsample = np.array([
    [0, 3, 3],
    [0, 1, 3],
])

fixed_sample = np.zeros((1, 10, 10))
#test_grad(fixed_sample, msample, fsample)
#test_scipy(fixed_sample, msample, fsample)
run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 10, 10)
# deformation_i shape: (3, 1, 10, 10), phi_init shape: (2, 10, 10)
# init: Negative Jacobians found at [14]
# Iter 1: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -0.2157278167883259
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935415695897e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.04466581344604492s
# OP result error for index 14: 5.587935415695897e-07
# Iter 1 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 2: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -0.21572781678832567
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.36983493070603e-08
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 14 completed in 0.008442163467407227s
# OP result error for index 14: 5.36983493070603e-08
# Iter 2 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 3: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 2, 0), jdet: -0.21572781678832612
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.184075703859939e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.04471182823181152s
# OP result error for index 14: 5.184075703859939e-07
# Iter 3 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Submatrix size is 7 from index 14
# Iter 4: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 3, 0), jdet: -0.21572781678832612
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2369389684705893e-05
#             Iterations: 2
#             Function evaluations: 216
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.07203125953674316s
# OP result error for index 14: 2.2369389684705893e-05
# Iter 4 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Submatrix size is 9 from index 14
# Iter 5: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830902
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0259537464349837e-05
#             Iterations: 12
#             Function evaluations: 2026
#             Gradient evaluations: 12
# Optimisation for index 14 completed in 0.8304049968719482s
# OP result error for index 14: 2.0259537464349837e-05
# Iter 5 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 6: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830857
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015392419893665507
#             Iterations: 3
#             Function evaluations: 519
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.2109968662261963s
# OP result error for index 14: 0.00015392419893665507
# Iter 6 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 7: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157278167883088
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.881886166110966e-05
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13871002197265625s
# OP result error for index 14: 6.881886166110966e-05
# Iter 7 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 8: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830857
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011316278490458489
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.1423041820526123s
# OP result error for index 14: 0.00011316278490458489
# Iter 8 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 9: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830835
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2524000851737005e-05
#             Iterations: 6
#             Function evaluations: 1020
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.41483426094055176s
# OP result error for index 14: 3.2524000851737005e-05
# Iter 9 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 10: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830857
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003164665972951834
#             Iterations: 4
#             Function evaluations: 681
#             Gradient evaluations: 4
# Optimisation for index 14 completed in 0.2780768871307373s
# OP result error for index 14: 0.0003164665972951834
# Iter 10 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 11: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.215727816788308
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.342154742921193e-06
#             Iterations: 7
#             Function evaluations: 1185
#             Gradient evaluations: 7
# Optimisation for index 14 completed in 0.4833357334136963s
# OP result error for index 14: 7.342154742921193e-06
# Iter 11 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 12: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781678830824
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.558364038118964e-05
#             Iterations: 2
#             Function evaluations: 344
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.1382150650024414s
# OP result error for index 14: 7.558364038118964e-05
# Iter 12 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 13: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781679017305
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.561596660044131e-05
#             Iterations: 6
#             Function evaluations: 1012
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.4167470932006836s
# OP result error for index 14: 3.561596660044131e-05
# Iter 13 end: 1 -ve jacs now at [14] : SITK: [-0.21572782]
# Iter 14: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781679017283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001252125424553328
#             Iterations: 3
#             Function evaluations: 511
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.2077798843383789s
# OP result error for index 14: 0.0001252125424553328
# Iter 14 end: 1 -ve jacs now at [14] : SITK: [-0.21572781]
# Iter 15: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781362931137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.00991701426848e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13960981369018555s
# OP result error for index 14: 8.00991701426848e-05
# Iter 15 end: 1 -ve jacs now at [14] : SITK: [-0.21572781]
# Iter 16: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781362931137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00033307770798464073
#             Iterations: 4
#             Function evaluations: 683
#             Gradient evaluations: 4
# Optimisation for index 14 completed in 0.2780628204345703s
# OP result error for index 14: 0.00033307770798464073
# Iter 16 end: 1 -ve jacs now at [14] : SITK: [-0.21572781]
# Iter 17: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157278136293116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003629657633326209
#             Iterations: 3
#             Function evaluations: 516
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.20985007286071777s
# OP result error for index 14: 0.0003629657633326209
# Iter 17 end: 1 -ve jacs now at [14] : SITK: [-0.21572781]
# Iter 18: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781362931137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.909420695280481e-05
#             Iterations: 6
#             Function evaluations: 1023
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.4180872440338135s
# OP result error for index 14: 9.909420695280481e-05
# Iter 18 end: 1 -ve jacs now at [14] : SITK: [-0.21572781]
# Iter 19: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572781362931137
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.40564486144973e-05
#             Iterations: 7
#             Function evaluations: 1193
#             Gradient evaluations: 7
# Optimisation for index 14 completed in 0.48730015754699707s
# OP result error for index 14: 3.40564486144973e-05
# Iter 19 end: 1 -ve jacs now at [14] : SITK: [-0.21572783]
# Iter 20: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572782501249504
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.88401602380196e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.14043116569519043s
# OP result error for index 14: 6.88401602380196e-05
# Iter 20 end: 1 -ve jacs now at [14] : SITK: [-0.21572783]
# Iter 21: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572782501249504
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013019431563130162
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.14471912384033203s
# OP result error for index 14: 0.00013019431563130162
# Iter 21 end: 1 -ve jacs now at [14] : SITK: [-0.21572783]
# Iter 22: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572782501249504
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.232647586457666e-05
#             Iterations: 6
#             Function evaluations: 1025
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.4173462390899658s
# OP result error for index 14: 8.232647586457666e-05
# Iter 22 end: 1 -ve jacs now at [14] : SITK: [-0.21572783]
# Iter 23: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572782501249482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.918185996320335e-05
#             Iterations: 3
#             Function evaluations: 518
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.23771405220031738s
# OP result error for index 14: 9.918185996320335e-05
# Iter 23 end: 1 -ve jacs now at [14] : SITK: [-0.21572813]
# Iter 24: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572813038928437
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003578098691293932
#             Iterations: 6
#             Function evaluations: 1018
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.41548609733581543s
# OP result error for index 14: 0.0003578098691293932
# Iter 24 end: 1 -ve jacs now at [14] : SITK: [-0.21572746]
# Iter 25: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572746357981096
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00042354312855745913
#             Iterations: 5
#             Function evaluations: 856
#             Gradient evaluations: 5
# Optimisation for index 14 completed in 0.34888601303100586s
# OP result error for index 14: 0.00042354312855745913
# Iter 25 end: 1 -ve jacs now at [14] : SITK: [-0.21572993]
# Iter 26: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572992773092323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.728185915105133e-05
#             Iterations: 6
#             Function evaluations: 1024
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.41605234146118164s
# OP result error for index 14: 8.728185915105133e-05
# Iter 26 end: 1 -ve jacs now at [14] : SITK: [-0.21572801]
# Iter 27: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572800585828744
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010087740800732159
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13904309272766113s
# OP result error for index 14: 0.00010087740800732159
# Iter 27 end: 1 -ve jacs now at [14] : SITK: [-0.21572801]
# Iter 28: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572800585828744
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00017664713234366494
#             Iterations: 9
#             Function evaluations: 1509
#             Gradient evaluations: 9
# Optimisation for index 14 completed in 0.6162450313568115s
# OP result error for index 14: 0.00017664713234366494
# Iter 28 end: 1 -ve jacs now at [14] : SITK: [-0.21572852]
# Iter 29: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572852112776641
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016693248336551326
#             Iterations: 3
#             Function evaluations: 515
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.20894169807434082s
# OP result error for index 14: 0.00016693248336551326
# Iter 29 end: 1 -ve jacs now at [14] : SITK: [-0.21572765]
# Iter 30: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572765485150194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010658139177023834
#             Iterations: 5
#             Function evaluations: 857
#             Gradient evaluations: 5
# Optimisation for index 14 completed in 0.3485269546508789s
# OP result error for index 14: 0.00010658139177023834
# Iter 30 end: 1 -ve jacs now at [14] : SITK: [-0.21572788]
# Iter 31: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572788350961739
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00019690668846585914
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.21171975135803223s
# OP result error for index 14: 0.00019690668846585914
# Iter 31 end: 1 -ve jacs now at [14] : SITK: [-0.21572747]
# Iter 32: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572747418092253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.572482998907706e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.14023518562316895s
# OP result error for index 14: 4.572482998907706e-05
# Iter 32 end: 1 -ve jacs now at [14] : SITK: [-0.21572734]
# Iter 33: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572734216347528
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010709982925885889
#             Iterations: 6
#             Function evaluations: 1018
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.41598987579345703s
# OP result error for index 14: 0.00010709982925885889
# Iter 33 end: 1 -ve jacs now at [14] : SITK: [-0.21572791]
# Iter 34: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572790865609742
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001869737011677636
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 14 completed in 0.21032404899597168s
# OP result error for index 14: 0.0001869737011677636
# Iter 34 end: 1 -ve jacs now at [14] : SITK: [-0.21572741]
# Iter 35: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572740697805254
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.6428075023742695e-05
#             Iterations: 6
#             Function evaluations: 1020
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.4156208038330078s
# OP result error for index 14: 4.6428075023742695e-05
# Iter 35 end: 1 -ve jacs now at [14] : SITK: [-0.21572767]
# Iter 36: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572766984744615
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.648985416328948e-05
#             Iterations: 2
#             Function evaluations: 345
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13927006721496582s
# OP result error for index 14: 7.648985416328948e-05
# Iter 36 end: 1 -ve jacs now at [14] : SITK: [-0.21572767]
# Iter 37: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572766984744593
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00037059252180666503
#             Iterations: 10
#             Function evaluations: 1698
#             Gradient evaluations: 10
# Optimisation for index 14 completed in 0.6920180320739746s
# OP result error for index 14: 0.00037059252180666503
# Iter 37 end: 1 -ve jacs now at [14] : SITK: [-0.21572745]
# Iter 38: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572745043032826
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003122939302882873
#             Iterations: 9
#             Function evaluations: 1541
#             Gradient evaluations: 9
# Optimisation for index 14 completed in 0.6275818347930908s
# OP result error for index 14: 0.0003122939302882873
# Iter 38 end: 1 -ve jacs now at [14] : SITK: [-0.21572743]
# Iter 39: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572743174394512
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010156479317466847
#             Iterations: 7
#             Function evaluations: 1198
#             Gradient evaluations: 7
# Optimisation for index 14 completed in 0.48555612564086914s
# OP result error for index 14: 0.00010156479317466847
# Iter 39 end: 1 -ve jacs now at [14] : SITK: [-0.21572757]
# Iter 40: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157275717260447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.820465836713692e-05
#             Iterations: 9
#             Function evaluations: 1532
#             Gradient evaluations: 9
# Optimisation for index 14 completed in 0.6202070713043213s
# OP result error for index 14: 5.820465836713692e-05
# Iter 40 end: 1 -ve jacs now at [14] : SITK: [-0.21573014]
# Iter 41: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21573014271095556
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.200884216270807e-05
#             Iterations: 13
#             Function evaluations: 2203
#             Gradient evaluations: 13
# Optimisation for index 14 completed in 0.8937499523162842s
# OP result error for index 14: 2.200884216270807e-05
# Iter 41 end: 1 -ve jacs now at [14] : SITK: [-0.2157267]
# Iter 42: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572669953726906
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001415108630520561
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13889598846435547s
# OP result error for index 14: 0.0001415108630520561
# Iter 42 end: 1 -ve jacs now at [14] : SITK: [-0.21572807]
# Iter 43: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572807250743764
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4023354683064329e-05
#             Iterations: 5
#             Function evaluations: 845
#             Gradient evaluations: 5
# Optimisation for index 14 completed in 0.3447737693786621s
# OP result error for index 14: 1.4023354683064329e-05
# Iter 43 end: 1 -ve jacs now at [14] : SITK: [-0.21572789]
# Iter 44: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157278915668603
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.379825855490229e-06
#             Iterations: 6
#             Function evaluations: 1001
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.40804505348205566s
# OP result error for index 14: 9.379825855490229e-06
# Iter 44 end: 1 -ve jacs now at [14] : SITK: [-0.21572742]
# Iter 45: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572741514531252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001457346067221055
#             Iterations: 2
#             Function evaluations: 344
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.1382429599761963s
# OP result error for index 14: 0.0001457346067221055
# Iter 45 end: 1 -ve jacs now at [14] : SITK: [-0.21572823]
# Iter 46: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572823465055624
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2014899966789347e-06
#             Iterations: 5
#             Function evaluations: 837
#             Gradient evaluations: 5
# Optimisation for index 14 completed in 0.3436930179595947s
# OP result error for index 14: 2.2014899966789347e-06
# Iter 46 end: 1 -ve jacs now at [14] : SITK: [-0.2157278]
# Iter 47: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157278005476817
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011741635301867719
#             Iterations: 2
#             Function evaluations: 343
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.13817381858825684s
# OP result error for index 14: 0.00011741635301867719
# Iter 47 end: 1 -ve jacs now at [14] : SITK: [-0.2157277]
# Iter 48: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.2157276968140263
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.904189097404952e-06
#             Iterations: 6
#             Function evaluations: 1001
#             Gradient evaluations: 6
# Optimisation for index 14 completed in 0.408797025680542s
# OP result error for index 14: 8.904189097404952e-06
# Iter 48 end: 1 -ve jacs now at [14] : SITK: [-0.21572785]
# Iter 49: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572785426013225
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012961823867678034
#             Iterations: 2
#             Function evaluations: 344
#             Gradient evaluations: 2
# Optimisation for index 14 completed in 0.1384420394897461s
# OP result error for index 14: 0.00012961823867678034
# Iter 49 end: 1 -ve jacs now at [14] : SITK: [-0.2157291]
# Iter 50: Analysing index 14: Original coord: (4, 1, 0), nearest: (4, 4, 0), jdet: -0.21572910103020904
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.633350807054429e-05
#             Iterations: 5
#             Function evaluations: 845
#             Gradient evaluations: 5
# Optimisation for index 14 completed in 0.3444788455963135s
# OP result error for index 14: 1.633350807054429e-05
# Iter 50 end: 1 -ve jacs now at [14] : SITK: [-0.21572771]
# Total time taken for iterative SLSQP : 15.864739179611206 split as [0.04466581344604492, 0.008442163467407227, 0.04471182823181152, 0.07203125953674316, 0.8304049968719482, 0.2109968662261963, 0.13871002197265625, 0.1423041820526123, 0.41483426094055176, 0.2780768871307373, 0.4833357334136963, 0.1382150650024414, 0.4167470932006836, 0.2077798843383789, 0.13960981369018555, 0.2780628204345703, 0.20985007286071777, 0.4180872440338135, 0.48730015754699707, 0.14043116569519043, 0.14471912384033203, 0.4173462390899658, 0.23771405220031738, 0.41548609733581543, 0.34888601303100586, 0.41605234146118164, 0.13904309272766113, 0.6162450313568115, 0.20894169807434082, 0.3485269546508789, 0.21171975135803223, 0.14023518562316895, 0.41598987579345703, 0.21032404899597168, 0.4156208038330078, 0.13927006721496582, 0.6920180320739746, 0.6275818347930908, 0.48555612564086914, 0.6202070713043213, 0.8937499523162842, 0.13889598846435547, 0.3447737693786621, 0.40804505348205566, 0.1382429599761963, 0.3436930179595947, 0.13817381858825684, 0.408797025680542, 0.1384420394897461, 0.3444788455963135]
# Initial error: 8.301991792387227, final error: 8.301993433303588, deviation: 1.566333185723681e-06
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#             x-def              y-def            jacobian
#               min      max       min       max       min       max
# initial -3.006613 -2.97202 -2.999864  2.999864 -0.215728  2.197900
# final   -3.006613 -2.97202 -2.999864  2.999864 -0.215728  2.197901
# meshgrid shape for plot: (10, 10)

# %%
msample = np.array([
    [0, 1, 1],
    [0, 3, 3],
])
fsample = np.array([
    [0, 4, 1],
    [0, 0, 3],
])

fixed_sample = np.zeros((1, 10, 10))
#test_grad(fixed_sample, msample, fsample)
#test_scipy(fixed_sample, msample, fsample)
run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 10, 10)
# deformation_i shape: (3, 1, 10, 10), phi_init shape: (2, 10, 10)
# init: Negative Jacobians found at [13]
# Iter 1: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.18474404472656492
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935447995637e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.045359134674072266s
# OP result error for index 13: 5.587935447995637e-07
# Iter 1 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 2: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.18474404472656497
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.369839758904505e-08
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 13 completed in 0.008417129516601562s
# OP result error for index 13: 5.369839758904505e-08
# Iter 2 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 3: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 2, 0), jdet: -0.18474404472656503
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.184075389729086e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.04430794715881348s
# OP result error for index 13: 5.184075389729086e-07
# Iter 3 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Submatrix size is 7 from index 13
# Iter 4: Analysing index 13: Original coord: (3, 1, 0), nearest: (3, 3, 0), jdet: -0.1847440447265651
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.236938870655266e-05
#             Iterations: 2
#             Function evaluations: 216
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.05704689025878906s
# OP result error for index 13: 2.236938870655266e-05
# Iter 4 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Submatrix size is 9 from index 13
# Iter 5: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4797638089041109e-05
#             Iterations: 14
#             Function evaluations: 2362
#             Gradient evaluations: 14
# Optimisation for index 13 completed in 0.9598231315612793s
# OP result error for index 13: 1.4797638089041109e-05
# Iter 5 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 6: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654862
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.835536848292782e-05
#             Iterations: 3
#             Function evaluations: 514
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.20902466773986816s
# OP result error for index 13: 6.835536848292782e-05
# Iter 6 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 7: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654862
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.073602441617901e-05
#             Iterations: 10
#             Function evaluations: 1698
#             Gradient evaluations: 10
# Optimisation for index 13 completed in 0.6884973049163818s
# OP result error for index 13: 3.073602441617901e-05
# Iter 7 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 8: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654854
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.556142720744449e-05
#             Iterations: 10
#             Function evaluations: 1699
#             Gradient evaluations: 10
# Optimisation for index 13 completed in 0.6902167797088623s
# OP result error for index 13: 3.556142720744449e-05
# Iter 8 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 9: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447265484
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015021634875997527
#             Iterations: 5
#             Function evaluations: 863
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.34830594062805176s
# OP result error for index 13: 0.00015021634875997527
# Iter 9 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 10: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654818
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.080375512537744e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.1392960548400879s
# OP result error for index 13: 7.080375512537744e-05
# Iter 10 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 11: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654818
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011292725235280776
#             Iterations: 3
#             Function evaluations: 516
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.2089078426361084s
# OP result error for index 13: 0.00011292725235280776
# Iter 11 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 12: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654818
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.16590987301692e-06
#             Iterations: 6
#             Function evaluations: 1017
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4116792678833008s
# OP result error for index 13: 9.16590987301692e-06
# Iter 12 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 13: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654818
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5733571952708934e-05
#             Iterations: 7
#             Function evaluations: 1184
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.48134613037109375s
# OP result error for index 13: 3.5733571952708934e-05
# Iter 13 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 14: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654832
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014749539452489288
#             Iterations: 3
#             Function evaluations: 514
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.20811700820922852s
# OP result error for index 13: 0.00014749539452489288
# Iter 14 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 15: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472654832
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5338323653244884e-05
#             Iterations: 6
#             Function evaluations: 1017
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4133172035217285s
# OP result error for index 13: 2.5338323653244884e-05
# Iter 15 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 16: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718808
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013513884098095356
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.1379697322845459s
# OP result error for index 13: 0.00013513884098095356
# Iter 16 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 17: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718808
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001921623662504454
#             Iterations: 6
#             Function evaluations: 1019
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4151749610900879s
# OP result error for index 13: 0.0001921623662504454
# Iter 17 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 18: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718817
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0002212136785870326
#             Iterations: 3
#             Function evaluations: 515
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.2109391689300537s
# OP result error for index 13: 0.0002212136785870326
# Iter 18 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 19: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718817
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011722310420367053
#             Iterations: 5
#             Function evaluations: 856
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3518068790435791s
# OP result error for index 13: 0.00011722310420367053
# Iter 19 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 20: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447271882
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000159669438987459
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.21176600456237793s
# OP result error for index 13: 0.000159669438987459
# Iter 20 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 21: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718842
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.527651960805681e-05
#             Iterations: 7
#             Function evaluations: 1190
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.5250811576843262s
# OP result error for index 13: 3.527651960805681e-05
# Iter 21 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 22: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718842
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.89328091133058e-05
#             Iterations: 9
#             Function evaluations: 1529
#             Gradient evaluations: 9
# Optimisation for index 13 completed in 0.6298019886016846s
# OP result error for index 13: 9.89328091133058e-05
# Iter 22 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 23: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718858
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.995597314167481e-05
#             Iterations: 3
#             Function evaluations: 520
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.21300792694091797s
# OP result error for index 13: 9.995597314167481e-05
# Iter 23 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 24: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718858
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0006350763826950693
#             Iterations: 6
#             Function evaluations: 1015
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.42917299270629883s
# OP result error for index 13: 0.0006350763826950693
# Iter 24 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 25: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447271883
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014982012686686234
#             Iterations: 5
#             Function evaluations: 856
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.36238598823547363s
# OP result error for index 13: 0.00014982012686686234
# Iter 25 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 26: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718825
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.7111395811825756e-05
#             Iterations: 4
#             Function evaluations: 683
#             Gradient evaluations: 4
# Optimisation for index 13 completed in 0.3125622272491455s
# OP result error for index 13: 4.7111395811825756e-05
# Iter 26 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 27: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447271887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012383885462731234
#             Iterations: 2
#             Function evaluations: 342
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.14106202125549316s
# OP result error for index 13: 0.00012383885462731234
# Iter 27 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 28: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447271887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3373019675308717e-05
#             Iterations: 9
#             Function evaluations: 1511
#             Gradient evaluations: 9
# Optimisation for index 13 completed in 0.6198809146881104s
# OP result error for index 13: 1.3373019675308717e-05
# Iter 28 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 29: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718922
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001442045590090392
#             Iterations: 2
#             Function evaluations: 343
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.13772082328796387s
# OP result error for index 13: 0.0001442045590090392
# Iter 29 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 30: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.184744044727189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7595278956324823e-05
#             Iterations: 7
#             Function evaluations: 1180
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.4795219898223877s
# OP result error for index 13: 1.7595278956324823e-05
# Iter 30 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 31: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718897
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.522036561483072e-06
#             Iterations: 8
#             Function evaluations: 1349
#             Gradient evaluations: 8
# Optimisation for index 13 completed in 0.550673246383667s
# OP result error for index 13: 7.522036561483072e-06
# Iter 31 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 32: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.184744044727189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013989380160985357
#             Iterations: 2
#             Function evaluations: 345
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.13863706588745117s
# OP result error for index 13: 0.00013989380160985357
# Iter 32 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 33: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.184744044727189
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2108704004924411e-05
#             Iterations: 5
#             Function evaluations: 845
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.34536004066467285s
# OP result error for index 13: 1.2108704004924411e-05
# Iter 33 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 34: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718942
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014628917217963098
#             Iterations: 2
#             Function evaluations: 341
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.13847899436950684s
# OP result error for index 13: 0.00014628917217963098
# Iter 34 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 35: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718964
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3151205875681462e-05
#             Iterations: 5
#             Function evaluations: 845
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3450441360473633s
# OP result error for index 13: 1.3151205875681462e-05
# Iter 35 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 36: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404472718975
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.692344838622008e-05
#             Iterations: 9
#             Function evaluations: 1517
#             Gradient evaluations: 9
# Optimisation for index 13 completed in 0.6153028011322021s
# OP result error for index 13: 1.692344838622008e-05
# Iter 36 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 37: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440447271899
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3069741494148894e-05
#             Iterations: 13
#             Function evaluations: 2211
#             Gradient evaluations: 13
# Optimisation for index 13 completed in 0.8978910446166992s
# OP result error for index 13: 5.3069741494148894e-05
# Iter 37 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 38: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440442817696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001541403441263654
#             Iterations: 3
#             Function evaluations: 520
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.20966792106628418s
# OP result error for index 13: 0.0001541403441263654
# Iter 38 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 39: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428176983
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0004360418952436228
#             Iterations: 6
#             Function evaluations: 1017
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4125690460205078s
# OP result error for index 13: 0.0004360418952436228
# Iter 39 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 40: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428176977
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014408224680791104
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3460197448730469s
# OP result error for index 13: 0.00014408224680791104
# Iter 40 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 41: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428176938
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.66055484706527e-05
#             Iterations: 3
#             Function evaluations: 515
#             Gradient evaluations: 3
# Optimisation for index 13 completed in 0.21113014221191406s
# OP result error for index 13: 7.66055484706527e-05
# Iter 41 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 42: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428176938
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.490113379762472e-05
#             Iterations: 7
#             Function evaluations: 1192
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.4836540222167969s
# OP result error for index 13: 4.490113379762472e-05
# Iter 42 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 43: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440442817694
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001663848929446806
#             Iterations: 6
#             Function evaluations: 1028
#             Gradient evaluations: 6
# Optimisation for index 13 completed in 0.4151577949523926s
# OP result error for index 13: 0.0001663848929446806
# Iter 43 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 44: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428160232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9188278408293435e-05
#             Iterations: 7
#             Function evaluations: 1191
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.48319220542907715s
# OP result error for index 13: 1.9188278408293435e-05
# Iter 44 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 45: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428160207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4031961585185014e-05
#             Iterations: 7
#             Function evaluations: 1182
#             Gradient evaluations: 7
# Optimisation for index 13 completed in 0.49706292152404785s
# OP result error for index 13: 2.4031961585185014e-05
# Iter 45 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 46: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428160227
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0005878496211349985
#             Iterations: 4
#             Function evaluations: 682
#             Gradient evaluations: 4
# Optimisation for index 13 completed in 0.2908918857574463s
# OP result error for index 13: 0.0005878496211349985
# Iter 46 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 47: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440442816023
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00026684256577380096
#             Iterations: 2
#             Function evaluations: 341
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.1392378807067871s
# OP result error for index 13: 0.00026684256577380096
# Iter 47 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 48: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404428160207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0773840459384914e-05
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3549330234527588s
# OP result error for index 13: 2.0773840459384914e-05
# Iter 48 end: 1 -ve jacs now at [13] : SITK: [-0.18474404]
# Iter 49: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.18474404495323574
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010544679323548249
#             Iterations: 2
#             Function evaluations: 344
#             Gradient evaluations: 2
# Optimisation for index 13 completed in 0.14080810546875s
# OP result error for index 13: 0.00010544679323548249
# Iter 49 end: 1 -ve jacs now at [13] : SITK: [-0.18474401]
# Iter 50: Analysing index 13: Original coord: (3, 1, 0), nearest: (4, 4, 0), jdet: -0.1847440085608961
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8221290131346864e-05
#             Iterations: 5
#             Function evaluations: 843
#             Gradient evaluations: 5
# Optimisation for index 13 completed in 0.3495192527770996s
# OP result error for index 13: 3.8221290131346864e-05
# Iter 50 end: 1 -ve jacs now at [13] : SITK: [-0.18474401]
# Total time taken for iterative SLSQP : 17.67306900024414 split as [0.045359134674072266, 0.008417129516601562, 0.04430794715881348, 0.05704689025878906, 0.9598231315612793, 0.20902466773986816, 0.6884973049163818, 0.6902167797088623, 0.34830594062805176, 0.1392960548400879, 0.2089078426361084, 0.4116792678833008, 0.48134613037109375, 0.20811700820922852, 0.4133172035217285, 0.1379697322845459, 0.4151749610900879, 0.2109391689300537, 0.3518068790435791, 0.21176600456237793, 0.5250811576843262, 0.6298019886016846, 0.21300792694091797, 0.42917299270629883, 0.36238598823547363, 0.3125622272491455, 0.14106202125549316, 0.6198809146881104, 0.13772082328796387, 0.4795219898223877, 0.550673246383667, 0.13863706588745117, 0.34536004066467285, 0.13847899436950684, 0.3450441360473633, 0.6153028011322021, 0.8978910446166992, 0.20966792106628418, 0.4125690460205078, 0.3460197448730469, 0.21113014221191406, 0.4836540222167969, 0.4151577949523926, 0.48319220542907715, 0.49706292152404785, 0.2908918857574463, 0.1392378807067871, 0.3549330234527588, 0.14080810546875, 0.3495192527770996]
# Initial error: 8.301903173025687, final error: 8.301906939153382, deviation: 3.7437099839819976e-06
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#                 x-def                   y-def            jacobian
#                   min           max       min       max       min       max
# initial  0.000000e+00  0.000000e+00 -2.999864  2.999864 -0.184744  2.216894
# final   -6.862075e-07  6.813851e-07 -2.999865  2.999864 -0.184744  2.216894
# meshgrid shape for plot: (10, 10)

# %%
msample = np.array([
    [0, 2, 0],
    [0, 3, 1],
])
fsample = np.array([
    [0, 2, 4],
    [0, 3, 2],
])

fixed_sample = np.zeros((1, 10, 10))
#test_grad(fixed_sample, msample, fsample)
#test_scipy(fixed_sample, msample, fsample)
#red_test_scipy(fixed_sample, msample, fsample)
run_lapl_and_correction(fixed_sample, msample, fsample)
# Out:
# deformation shape: (3, 1, 10, 10)
# deformation_i shape: (3, 1, 10, 10), phi_init shape: (2, 10, 10)
# init: Negative Jacobians found at [5, 6]
# Iter 1: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -0.21700094391725067
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.58793540421785e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 5 completed in 0.045999765396118164s
# OP result error for index 5: 5.58793540421785e-07
# Iter 1 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 2: Analysing index 6: Original coord: (6, 0, 0), nearest: (6, 2, 0), jdet: -0.19366925432363252
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7630765794088007e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 6 completed in 0.00851893424987793s
# OP result error for index 6: 2.7630765794088007e-06
# Iter 2 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 3: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -0.21700094391830466
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.0358307599141108e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 5 completed in 0.016067981719970703s
# OP result error for index 5: 3.0358307599141108e-05
# Iter 3 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 4: Analysing index 6: Original coord: (6, 0, 0), nearest: (6, 2, 0), jdet: -0.19366925432584153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8906882551535474e-06
#             Iterations: 7
#             Function evaluations: 379
#             Gradient evaluations: 7
# Optimisation for index 6 completed in 0.05035400390625s
# OP result error for index 6: 1.8906882551535474e-06
# Iter 4 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 5: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 2, 0), jdet: -0.2170009439183046
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.283342740020879e-07
#             Iterations: 9
#             Function evaluations: 482
#             Gradient evaluations: 9
# Optimisation for index 5 completed in 0.06704211235046387s
# OP result error for index 5: 9.283342740020879e-07
# Iter 5 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 6: Analysing index 6: Original coord: (6, 0, 0), nearest: (6, 2, 0), jdet: -0.1936692543258417
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2678813552593945e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 6 completed in 0.008060216903686523s
# OP result error for index 6: 1.2678813552593945e-06
# Iter 6 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Submatrix size is 7 from index 5
# Iter 7: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 3, 0), jdet: -0.21700094390076868
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.828756701746765e-05
#             Iterations: 2
#             Function evaluations: 215
#             Gradient evaluations: 2
# Optimisation for index 5 completed in 0.05360889434814453s
# OP result error for index 5: 7.828756701746765e-05
# Iter 7 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 8: Analysing index 6: Original coord: (6, 0, 0), nearest: (6, 3, 0), jdet: -0.19366925429165566
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.509852042263887e-06
#             Iterations: 5
#             Function evaluations: 518
#             Gradient evaluations: 5
# Optimisation for index 6 completed in 0.13211274147033691s
# OP result error for index 6: 4.509852042263887e-06
# Iter 8 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Submatrix size is 9 from index 5
# Iter 9: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094390076852
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00027958585808898447
#             Iterations: 7
#             Function evaluations: 1189
#             Gradient evaluations: 7
# Optimisation for index 5 completed in 0.49010205268859863s
# OP result error for index 5: 0.00027958585808898447
# Iter 9 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 10: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936692542916554
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6727519011304906e-05
#             Iterations: 8
#             Function evaluations: 1363
#             Gradient evaluations: 8
# Optimisation for index 6 completed in 0.5678248405456543s
# OP result error for index 6: 1.6727519011304906e-05
# Iter 10 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 11: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094390076893
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.25475175893001e-05
#             Iterations: 4
#             Function evaluations: 690
#             Gradient evaluations: 4
# Optimisation for index 5 completed in 0.285534143447876s
# OP result error for index 5: 8.25475175893001e-05
# Iter 11 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 12: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366925429165585
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00010374240309824785
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 6 completed in 0.1435258388519287s
# OP result error for index 6: 0.00010374240309824785
# Iter 12 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 13: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094390076916
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.268781270787113e-05
#             Iterations: 8
#             Function evaluations: 1346
#             Gradient evaluations: 8
# Optimisation for index 5 completed in 0.5540730953216553s
# OP result error for index 5: 4.268781270787113e-05
# Iter 13 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 14: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366925429165602
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00014633652838474322
#             Iterations: 4
#             Function evaluations: 693
#             Gradient evaluations: 4
# Optimisation for index 6 completed in 0.28086209297180176s
# OP result error for index 6: 0.00014633652838474322
# Iter 14 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 15: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094390076913
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.244352189556819e-05
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.3485379219055176s
# OP result error for index 5: 4.244352189556819e-05
# Iter 15 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 16: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936692542916558
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001252095372548909
#             Iterations: 2
#             Function evaluations: 343
#             Gradient evaluations: 2
# Optimisation for index 6 completed in 0.13780713081359863s
# OP result error for index 6: 0.0001252095372548909
# Iter 16 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 17: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.2170009439007689
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1795571885192756e-05
#             Iterations: 10
#             Function evaluations: 1695
#             Gradient evaluations: 10
# Optimisation for index 5 completed in 0.6904079914093018s
# OP result error for index 5: 2.1795571885192756e-05
# Iter 17 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700096 -0.19366928]
# Iter 18: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366928377262999
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.352922361138588e-05
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 6 completed in 0.21167492866516113s
# OP result error for index 6: 9.352922361138588e-05
# Iter 18 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700096 -0.19366928]
# Iter 19: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.2170009590234493
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7757279358732418e-05
#             Iterations: 7
#             Function evaluations: 1188
#             Gradient evaluations: 7
# Optimisation for index 5 completed in 0.4892430305480957s
# OP result error for index 5: 2.7757279358732418e-05
# Iter 19 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700096 -0.19366928]
# Iter 20: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366928377263043
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013730562829533178
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 6 completed in 0.14218783378601074s
# OP result error for index 6: 0.00013730562829533178
# Iter 20 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700096 -0.19366928]
# Iter 21: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700095902344974
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.471047193794544e-05
#             Iterations: 3
#             Function evaluations: 510
#             Gradient evaluations: 3
# Optimisation for index 5 completed in 0.21471381187438965s
# OP result error for index 5: 3.471047193794544e-05
# Iter 21 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700096 -0.19366928]
# Iter 22: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936692837726304
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.473977550383928e-05
#             Iterations: 9
#             Function evaluations: 1518
#             Gradient evaluations: 9
# Optimisation for index 6 completed in 0.6303660869598389s
# OP result error for index 6: 3.473977550383928e-05
# Iter 22 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 23: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.217000940104465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9046357558603435e-05
#             Iterations: 7
#             Function evaluations: 1192
#             Gradient evaluations: 7
# Optimisation for index 5 completed in 0.533592939376831s
# OP result error for index 5: 2.9046357558603435e-05
# Iter 23 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 24: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366924742190278
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.000139070937043093
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 6 completed in 0.14497828483581543s
# OP result error for index 6: 0.000139070937043093
# Iter 24 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 25: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094010446502
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.275754709107465e-05
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 5 completed in 0.14742803573608398s
# OP result error for index 5: 7.275754709107465e-05
# Iter 25 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 26: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366924742190256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3155480218597365e-05
#             Iterations: 5
#             Function evaluations: 856
#             Gradient evaluations: 5
# Optimisation for index 6 completed in 0.3563380241394043s
# OP result error for index 6: 1.3155480218597365e-05
# Iter 26 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 27: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094010446505
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00016533328776003134
#             Iterations: 5
#             Function evaluations: 848
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.35181498527526855s
# OP result error for index 5: 0.00016533328776003134
# Iter 27 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 28: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366924742190256
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.671221612861939e-05
#             Iterations: 4
#             Function evaluations: 682
#             Gradient evaluations: 4
# Optimisation for index 6 completed in 0.280958890914917s
# OP result error for index 6: 4.671221612861939e-05
# Iter 28 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 29: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094010446527
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1742120941297379e-05
#             Iterations: 6
#             Function evaluations: 1018
#             Gradient evaluations: 6
# Optimisation for index 5 completed in 0.41695499420166016s
# OP result error for index 5: 1.1742120941297379e-05
# Iter 29 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 30: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366924742190303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0577647294684892e-05
#             Iterations: 8
#             Function evaluations: 1348
#             Gradient evaluations: 8
# Optimisation for index 6 completed in 0.5493898391723633s
# OP result error for index 6: 1.0577647294684892e-05
# Iter 30 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366925]
# Iter 31: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700094010446483
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001303681473269097
#             Iterations: 3
#             Function evaluations: 515
#             Gradient evaluations: 3
# Optimisation for index 5 completed in 0.21422958374023438s
# OP result error for index 5: 0.0001303681473269097
# Iter 31 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700117 -0.19366969]
# Iter 32: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366969207508153
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.45799784928562e-05
#             Iterations: 2
#             Function evaluations: 343
#             Gradient evaluations: 2
# Optimisation for index 6 completed in 0.13982915878295898s
# OP result error for index 6: 7.45799784928562e-05
# Iter 32 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700099 -0.19366969]
# Iter 33: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700099475038392
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.001354838137284107
#             Iterations: 5
#             Function evaluations: 855
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.3765270709991455s
# OP result error for index 5: 0.001354838137284107
# Iter 33 end: 2 -ve jacs now at [5 6] : SITK: [-0.21699856 -0.19366826]
# Iter 34: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936682581788245
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0010575781203328639
#             Iterations: 3
#             Function evaluations: 517
#             Gradient evaluations: 3
# Optimisation for index 6 completed in 0.2194991111755371s
# OP result error for index 6: 0.0010575781203328639
# Iter 34 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700047 -0.193672  ]
# Iter 35: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.2170004737516746
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.27530034435628e-05
#             Iterations: 7
#             Function evaluations: 1202
#             Gradient evaluations: 7
# Optimisation for index 5 completed in 0.4938502311706543s
# OP result error for index 5: 6.27530034435628e-05
# Iter 35 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700097 -0.19366797]
# Iter 36: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366796613921083
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0001645072387157981
#             Iterations: 4
#             Function evaluations: 693
#             Gradient evaluations: 4
# Optimisation for index 6 completed in 0.28449010848999023s
# OP result error for index 6: 0.0001645072387157981
# Iter 36 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700041 -0.19366935]
# Iter 37: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.2170004092798798
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.1563449916416665e-05
#             Iterations: 5
#             Function evaluations: 857
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.39348387718200684s
# OP result error for index 5: 4.1563449916416665e-05
# Iter 37 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700094 -0.19366935]
# Iter 38: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366934880444828
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011168814696842717
#             Iterations: 3
#             Function evaluations: 520
#             Gradient evaluations: 3
# Optimisation for index 6 completed in 0.21786975860595703s
# OP result error for index 6: 0.00011168814696842717
# Iter 38 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700133 -0.1936692 ]
# Iter 39: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700133002884764
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.609082935645312e-05
#             Iterations: 5
#             Function evaluations: 846
#             Gradient evaluations: 5
# Optimisation for index 5 completed in 0.34910106658935547s
# OP result error for index 5: 3.609082935645312e-05
# Iter 39 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700088 -0.19366969]
# Iter 40: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936696935996095
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0008999137484499682
#             Iterations: 4
#             Function evaluations: 680
#             Gradient evaluations: 4
# Optimisation for index 6 completed in 0.276885986328125s
# OP result error for index 6: 0.0008999137484499682
# Iter 40 end: 2 -ve jacs now at [5 6] : SITK: [-0.21699633 -0.19367052]
# Iter 41: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21699633397032478
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00013169678595431034
#             Iterations: 2
#             Function evaluations: 346
#             Gradient evaluations: 2
# Optimisation for index 5 completed in 0.13852810859680176s
# OP result error for index 5: 0.00013169678595431034
# Iter 41 end: 2 -ve jacs now at [5 6] : SITK: [-0.21699959 -0.19367052]
# Iter 42: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19367051525909793
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.2941565106613e-05
#             Iterations: 6
#             Function evaluations: 1027
#             Gradient evaluations: 6
# Optimisation for index 6 completed in 0.43996405601501465s
# OP result error for index 6: 8.2941565106613e-05
# Iter 42 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700048 -0.19366945]
# Iter 43: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700047602440428
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00011583870435906474
#             Iterations: 3
#             Function evaluations: 520
#             Gradient evaluations: 3
# Optimisation for index 5 completed in 0.21364307403564453s
# OP result error for index 5: 0.00011583870435906474
# Iter 43 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700072 -0.19366951]
# Iter 44: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936695125351973
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015216254175556485
#             Iterations: 4
#             Function evaluations: 681
#             Gradient evaluations: 4
# Optimisation for index 6 completed in 0.2799980640411377s
# OP result error for index 6: 0.00015216254175556485
# Iter 44 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700148 -0.19366968]
# Iter 45: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.2170014826734877
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.4865122356406796e-05
#             Iterations: 7
#             Function evaluations: 1191
#             Gradient evaluations: 7
# Optimisation for index 5 completed in 0.5282838344573975s
# OP result error for index 5: 5.4865122356406796e-05
# Iter 45 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700061 -0.19366885]
# Iter 46: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.19366884983609353
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00021607294594198375
#             Iterations: 5
#             Function evaluations: 854
#             Gradient evaluations: 5
# Optimisation for index 6 completed in 0.351733922958374s
# OP result error for index 6: 0.00021607294594198375
# Iter 46 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700327 -0.1936699 ]
# Iter 47: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700326696380018
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.38286389922823e-05
#             Iterations: 3
#             Function evaluations: 519
#             Gradient evaluations: 3
# Optimisation for index 5 completed in 0.2233438491821289s
# OP result error for index 5: 7.38286389922823e-05
# Iter 47 end: 2 -ve jacs now at [5 6] : SITK: [-0.21699921 -0.19366835]
# Iter 48: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936683511318133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.9636665653835116e-05
#             Iterations: 6
#             Function evaluations: 1028
#             Gradient evaluations: 6
# Optimisation for index 6 completed in 0.42655301094055176s
# OP result error for index 6: 4.9636665653835116e-05
# Iter 48 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700067 -0.19366912]
# Iter 49: Analysing index 5: Original coord: (5, 0, 0), nearest: (5, 4, 0), jdet: -0.21700066915381777
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00012386521283083468
#             Iterations: 2
#             Function evaluations: 347
#             Gradient evaluations: 2
# Optimisation for index 5 completed in 0.14214515686035156s
# OP result error for index 5: 0.00012386521283083468
# Iter 49 end: 2 -ve jacs now at [5 6] : SITK: [-0.2170015  -0.19366912]
# Iter 50: Analysing index 6: Original coord: (6, 0, 0), nearest: (5, 4, 0), jdet: -0.1936691182164074
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.951559706023689e-05
#             Iterations: 7
#             Function evaluations: 1190
#             Gradient evaluations: 7
# Optimisation for index 6 completed in 0.5011529922485352s
# OP result error for index 6: 4.951559706023689e-05
# Iter 50 end: 2 -ve jacs now at [5 6] : SITK: [-0.21700075 -0.19366978]
# Total time taken for iterative SLSQP : 14.791371822357178 split as [0.045999765396118164, 0.00851893424987793, 0.016067981719970703, 0.05035400390625, 0.06704211235046387, 0.008060216903686523, 0.05360889434814453, 0.13211274147033691, 0.49010205268859863, 0.5678248405456543, 0.285534143447876, 0.1435258388519287, 0.5540730953216553, 0.28086209297180176, 0.3485379219055176, 0.13780713081359863, 0.6904079914093018, 0.21167492866516113, 0.4892430305480957, 0.14218783378601074, 0.21471381187438965, 0.6303660869598389, 0.533592939376831, 0.14497828483581543, 0.14742803573608398, 0.3563380241394043, 0.35181498527526855, 0.280958890914917, 0.41695499420166016, 0.5493898391723633, 0.21422958374023438, 0.13982915878295898, 0.3765270709991455, 0.2194991111755371, 0.4938502311706543, 0.28449010848999023, 0.39348387718200684, 0.21786975860595703, 0.34910106658935547, 0.276885986328125, 0.13852810859680176, 0.43996405601501465, 0.21364307403564453, 0.2799980640411377, 0.5282838344573975, 0.351733922958374, 0.2233438491821289, 0.42655301094055176, 0.14214515686035156, 0.5011529922485352]
# Initial error: 6.566029817740786, final error: 6.5660400144478475, deviation: 7.01970974904835e-06
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#             x-def                   y-def            jacobian
#               min       max           min       max       min       max
# initial -3.999655 -0.999914  0.000000e+00  0.000000 -0.217001  1.428312
# final   -3.999655 -0.999913 -1.299260e-07  0.000002 -0.217001  1.428313
# meshgrid shape for plot: (10, 10)

# %%
# data analysis

# Create sample set of points
mpoints_path = "../data/corrected_correspondences_count_touching/mpoints.npy"
fpoints_path = "../data/corrected_correspondences_count_touching/fpoints.npy"

mpoints, fpoints = correspondences.downsample_points(mpoints_path, fpoints_path, debug=False)
#print(mpoints.shape, fpoints.shape) 

fixed_sample = np.zeros((1, 20, 40))

# z values in mpoints, fpoints are for 3 slices numbered 0,1,2
slice_no = 1

# use 
mask = mpoints[:,0]==slice_no
new_mpoints = mpoints[mask].copy()
new_mpoints[:,0] = 0

mask = fpoints[:,0]==slice_no
new_fpoints = fpoints[mask].copy()
new_fpoints[:,0] = 0

print(new_mpoints.shape, new_fpoints.shape)


#test_grad(fixed_sample, msample, fsample)
#red_test_scipy(fixed_sample, new_mpoints[:5], new_fpoints[:5])
run_lapl_and_correction(fixed_sample, new_mpoints, new_fpoints)
# Out:
# (15, 3) (15, 3)
# deformation shape: (3, 1, 20, 40)
# deformation_i shape: (3, 1, 20, 40), phi_init shape: (2, 20, 40)
# init: Negative Jacobians found at [33, 34, 35, 17, 21, 18, 74, 73, 26, 25, 75, 22, 114, 48, 113, 115, 24, 65, 32, 66, 36, 64, 76, 154, 72, 155, 153, 62, 63, 116, 105, 57, 23, 104, 194, 112, 47, 106, 195, 156, 193, 61, 103, 152]
# Iter 1: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 2, 0), jdet: -9.63056143072064
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5157776233644644
#             Iterations: 34
#             Function evaluations: 1861
#             Gradient evaluations: 34
# Optimisation for index 33 completed in 0.2929871082305908s
# OP result error for index 33: 0.5157776233644644
# Iter 1 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57 193  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.63057061 -7.1653646  -6.11270611 -6.0994166  -5.69108333 -5.50269989 -4.47124579 -4.01207468 -3.38441564 -3.16667819 -3.14471143 -2.24383798 -2.01041883 -1.72254657 -1.68152613 -1.5225508  -1.50420304 -1.44944248 -1.29158424 -1.17285569 -1.09424897 -0.96454902 -0.93210326 -0.8965384  -0.72296145 -0.68509253 -0.68366949 -0.67824928 -0.52639406 -0.49952101 -0.48176257 -0.4622459  -0.41360345 -0.36417329 -0.34681242 -0.29859986 -0.29069447 -0.27696617 -0.2168901  -0.18082833 -0.12274627 -0.08707154 -0.03462262]
# Iter 2: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -7.165364600559031
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.010377474251373808
#             Iterations: 16
#             Function evaluations: 890
#             Gradient evaluations: 16
# Optimisation for index 34 completed in 0.1202399730682373s
# OP result error for index 34: 0.010377474251373808
# Iter 2 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63044128 -7.16517089 -6.11270611 -6.0994166  -5.69108333 -5.50269989 -4.47124607 -4.01200575 -3.38441564 -3.16667819 -3.14469126 -2.24383798 -2.01054109 -1.72254657 -1.68164041 -1.52227371 -1.50420304 -1.44944248 -1.29162302 -1.17285569 -1.09434802 -0.96454902 -0.93219571 -0.89554143 -0.72286803 -0.68406971 -0.68378323 -0.67824928 -0.52639406 -0.49937482 -0.48176257 -0.4622459  -0.36417329 -0.34681242 -0.29834202 -0.29058985 -0.27696617 -0.2168901  -0.19550396 -0.18093252 -0.17449808 -0.12274627 -0.08707154 -0.03451213]
# Iter 3: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -6.112706113856028
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.004949971842963415
#             Iterations: 7
#             Function evaluations: 404
#             Gradient evaluations: 7
# Optimisation for index 35 completed in 0.05484175682067871s
# OP result error for index 35: 0.004949971842963415
# Iter 3 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63054375 -7.16541033 -6.11270611 -6.0994166  -5.69108333 -5.50269989 -4.47123712 -4.01203754 -3.38441564 -3.16667819 -3.14470867 -2.24383798 -2.01043135 -1.72254657 -1.68164295 -1.52015234 -1.50420304 -1.44944248 -1.29153616 -1.17285569 -1.09425863 -0.96454902 -0.93211223 -0.89708791 -0.72295015 -0.68528475 -0.68378529 -0.67824928 -0.52639406 -0.49967509 -0.48176257 -0.4622459  -0.36417329 -0.34681242 -0.29902299 -0.29068681 -0.27696617 -0.2168901  -0.19438036 -0.18279182 -0.17411587 -0.12274627 -0.08707154 -0.03461354]
# Iter 4: Analysing index 17: Original coord: (17, 0, 0), nearest: (17, 2, 0), jdet: -6.099416604367864
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935427873869e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 17 completed in 0.05382680892944336s
# OP result error for index 17: 5.587935427873869e-07
# Iter 4 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63054375 -7.16541033 -6.11270611 -6.0994166  -5.69108333 -5.50269989 -4.47123712 -4.01203754 -3.38441564 -3.16667819 -3.14470867 -2.24383798 -2.01043135 -1.72254657 -1.68164295 -1.52015234 -1.50420304 -1.44944248 -1.29153616 -1.17285569 -1.09425863 -0.96454902 -0.93211223 -0.89708791 -0.72295015 -0.68528475 -0.68378529 -0.67824928 -0.52639406 -0.49967509 -0.48176257 -0.4622459  -0.36417329 -0.34681242 -0.29902299 -0.29068681 -0.27696617 -0.2168901  -0.19438036 -0.18279182 -0.17411587 -0.12274627 -0.08707154 -0.03461354]
# Iter 5: Analysing index 21: Original coord: (21, 0, 0), nearest: (21, 2, 0), jdet: -5.6910833296426295
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.148601074388111e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 21 completed in 0.016019821166992188s
# OP result error for index 21: 3.148601074388111e-05
# Iter 5 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63054375 -7.16541033 -6.11270611 -6.0994166  -5.69108333 -5.50269989 -4.47123712 -4.01203754 -3.38441564 -3.16667819 -3.14470867 -2.24383798 -2.01043135 -1.72254657 -1.68164295 -1.52015234 -1.50420218 -1.44944248 -1.29153616 -1.17285569 -1.09425863 -0.96454787 -0.93211223 -0.89708791 -0.72295015 -0.68528475 -0.68378529 -0.67824928 -0.52639304 -0.49967509 -0.48176257 -0.4622459  -0.36417261 -0.34681153 -0.29902299 -0.29068681 -0.27696617 -0.2168901  -0.19438036 -0.18279182 -0.17411587 -0.12274627 -0.08707054 -0.03461354]
# Iter 6: Analysing index 18: Original coord: (18, 0, 0), nearest: (18, 2, 0), jdet: -5.50269988660056
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.92910778405819e-06
#             Iterations: 3
#             Function evaluations: 180
#             Gradient evaluations: 3
# Optimisation for index 18 completed in 0.024016141891479492s
# OP result error for index 18: 7.92910778405819e-06
# Iter 6 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63054375 -7.16541033 -6.11270611 -6.0994166  -5.69108485 -5.50269993 -4.47123712 -4.01203754 -3.38441564 -3.16667819 -3.14470867 -2.24383798 -2.01043135 -1.72254657 -1.68164295 -1.52015234 -1.50420218 -1.44944248 -1.29153616 -1.17285569 -1.09425863 -0.96454787 -0.93211223 -0.89708791 -0.72295015 -0.68528475 -0.68378529 -0.67824928 -0.52639304 -0.49967509 -0.48176257 -0.4622459  -0.36417261 -0.34681153 -0.29902299 -0.29068681 -0.27696617 -0.2168901  -0.19438036 -0.18279182 -0.17411587 -0.12274858 -0.08707054 -0.03461354]
# Iter 7: Analysing index 74: Original coord: (34, 1, 0), nearest: (34, 2, 0), jdet: -4.471237119930492
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0029815005622649098
#             Iterations: 11
#             Function evaluations: 635
#             Gradient evaluations: 11
# Optimisation for index 74 completed in 0.0817420482635498s
# OP result error for index 74: 0.0029815005622649098
# Iter 7 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63056784 -7.16526851 -6.11270239 -6.0994166  -5.69108485 -5.50269993 -4.47130471 -4.01208089 -3.38441564 -3.16667819 -3.14470733 -2.24383798 -2.01052225 -1.72254657 -1.68157295 -1.52082357 -1.50420218 -1.44944248 -1.29159401 -1.17285569 -1.09429419 -0.96454787 -0.9321237  -0.89671738 -0.72289572 -0.68518685 -0.68370285 -0.67824928 -0.52639304 -0.49944447 -0.48176257 -0.4622459  -0.36417261 -0.34681153 -0.29861468 -0.29062862 -0.27696617 -0.2168901  -0.19496899 -0.1821546  -0.17388789 -0.12274858 -0.08707054 -0.03453889]
# Iter 8: Analysing index 73: Original coord: (33, 1, 0), nearest: (33, 2, 0), jdet: -4.012080889835733
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1962942318173533
#             Iterations: 61
#             Function evaluations: 3300
#             Gradient evaluations: 61
# Optimisation for index 73 completed in 0.44696593284606934s
# OP result error for index 73: 1.1962942318173533
# Iter 8 end: 42 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113  24 115  65 154  32  66  36  64  76  72 155 153  62  63 116 105  57  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.63113663 -7.16430425 -6.11264588 -6.0994166  -5.69108485 -5.50269993 -4.47100058 -4.01218762 -3.38441564 -3.16667819 -3.1447161  -2.24383798 -2.01064744 -1.72254657 -1.6817806  -1.50420218 -1.4740936  -1.44944248 -1.39753463 -1.29117207 -1.17285569 -1.09452558 -0.96454787 -0.93251569 -0.72224435 -0.68483465 -0.68386486 -0.67824928 -0.52639304 -0.49962859 -0.48176257 -0.4622459  -0.36417261 -0.34681153 -0.29831113 -0.29134996 -0.27696617 -0.2168901  -0.15029354 -0.12274858 -0.08707054 -0.03496993]
# Iter 9: Analysing index 26: Original coord: (26, 0, 0), nearest: (26, 2, 0), jdet: -3.384415642832325
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935422033719e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 26 completed in 0.04300093650817871s
# OP result error for index 26: 5.587935422033719e-07
# Iter 9 end: 42 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113  24 115  65 154  32  66  36  64  76  72 155 153  62  63 116 105  57  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.63113663 -7.16430425 -6.11264588 -6.0994166  -5.69108485 -5.50269993 -4.47100058 -4.01218762 -3.38441564 -3.16667819 -3.1447161  -2.24383798 -2.01064744 -1.72254657 -1.6817806  -1.50420219 -1.4740936  -1.44944248 -1.39753463 -1.29117207 -1.17285569 -1.09452558 -0.96454789 -0.93251569 -0.72224435 -0.68483465 -0.68386486 -0.67824928 -0.52639305 -0.49962859 -0.48176257 -0.4622459  -0.36417262 -0.34681154 -0.29831113 -0.29134996 -0.27696617 -0.2168901  -0.15029354 -0.12274858 -0.08707055 -0.03496993]
# Iter 10: Analysing index 25: Original coord: (25, 0, 0), nearest: (25, 2, 0), jdet: -3.166678193385732
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.223113749541102e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 25 completed in 0.008361339569091797s
# OP result error for index 25: 9.223113749541102e-06
# Iter 10 end: 42 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113  24 115  65 154  32  66  36  64  76  72 155 153  62  63 116 105  57  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.63113663 -7.16430425 -6.11264588 -6.0994166  -5.69108485 -5.50269993 -4.47100058 -4.01218762 -3.38441564 -3.16667819 -3.1447161  -2.24383776 -2.01064744 -1.72254657 -1.6817806  -1.50420231 -1.4740936  -1.44944248 -1.39753463 -1.29117207 -1.17285569 -1.09452558 -0.96454805 -0.93251569 -0.72224435 -0.68483465 -0.68386486 -0.67824894 -0.52639291 -0.49962859 -0.48176257 -0.4622459  -0.36417252 -0.34681167 -0.29831113 -0.29134996 -0.27696617 -0.2168901  -0.15029354 -0.12274858 -0.08707041 -0.03496993]
# Iter 11: Analysing index 75: Original coord: (35, 1, 0), nearest: (35, 2, 0), jdet: -3.144716100371204
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.007390530454598407
#             Iterations: 28
#             Function evaluations: 1537
#             Gradient evaluations: 28
# Optimisation for index 75 completed in 0.20474910736083984s
# OP result error for index 75: 0.007390530454598407
# Iter 11 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63045108 -7.16551486 -6.11270507 -6.0994166  -5.69108485 -5.50269993 -4.47139123 -4.01190552 -3.38441564 -3.16667819 -3.14473163 -2.24383776 -2.0104789  -1.72254657 -1.68169084 -1.51885457 -1.50420231 -1.44944248 -1.29091681 -1.17285569 -1.09421058 -0.96454805 -0.93200034 -0.89851208 -0.72238921 -0.68511315 -0.68377159 -0.67824894 -0.52639291 -0.49945444 -0.48176257 -0.4622459  -0.36417252 -0.34681167 -0.29865818 -0.29088911 -0.27696617 -0.2168901  -0.19407613 -0.18376269 -0.17328325 -0.12274858 -0.08707041 -0.0347588 ]
# Iter 12: Analysing index 22: Original coord: (22, 0, 0), nearest: (22, 2, 0), jdet: -2.2438377629721566
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.8216575577955584e-05
#             Iterations: 4
#             Function evaluations: 234
#             Gradient evaluations: 4
# Optimisation for index 22 completed in 0.029855966567993164s
# OP result error for index 22: 5.8216575577955584e-05
# Iter 12 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63045108 -7.16551486 -6.11270507 -6.0994166  -5.69108673 -5.50269993 -4.47139123 -4.01190552 -3.38441564 -3.16667928 -3.14473163 -2.24384013 -2.0104789  -1.72254657 -1.68169084 -1.51885457 -1.50420039 -1.44944383 -1.29091681 -1.17285569 -1.09421058 -0.96454548 -0.93200034 -0.89851208 -0.72238921 -0.68511315 -0.68377159 -0.67825263 -0.52639141 -0.49945444 -0.48176395 -0.4622459  -0.36417151 -0.34680961 -0.29865818 -0.29088911 -0.27696617 -0.2168901  -0.19407613 -0.18376269 -0.17328325 -0.12275144 -0.08706893 -0.0347588 ]
# Iter 13: Analysing index 114: Original coord: (34, 2, 0), nearest: (34, 2, 0), jdet: -2.0104788951522434
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.005754395813200744
#             Iterations: 11
#             Function evaluations: 633
#             Gradient evaluations: 11
# Optimisation for index 114 completed in 0.0859529972076416s
# OP result error for index 114: 0.005754395813200744
# Iter 13 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.62766431 -7.16493947 -6.1126965  -6.0994166  -5.69108673 -5.50269993 -4.4711682  -4.01039526 -3.38441564 -3.16667928 -3.14466754 -2.24384013 -2.01053663 -1.72254657 -1.68113088 -1.52115529 -1.50420039 -1.44944383 -1.28963298 -1.17285569 -1.09438564 -0.96454548 -0.93225057 -0.89696623 -0.72239096 -0.68504408 -0.68377388 -0.67825263 -0.52639141 -0.49955016 -0.48176395 -0.4622459  -0.36417151 -0.34680961 -0.29871452 -0.2910077  -0.27696617 -0.2168901  -0.19547881 -0.18194342 -0.17305181 -0.12275144 -0.08706893 -0.03478116]
# Iter 14: Analysing index 48: Original coord: (8, 1, 0), nearest: (8, 2, 0), jdet: -1.7225465687377934
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.587935418629987e-07
#             Iterations: 6
#             Function evaluations: 318
#             Gradient evaluations: 6
# Optimisation for index 48 completed in 0.0436558723449707s
# OP result error for index 48: 5.587935418629987e-07
# Iter 14 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.62766431 -7.16493947 -6.1126965  -6.0994166  -5.69108673 -5.50269993 -4.4711682  -4.01039526 -3.38441564 -3.16667928 -3.14466754 -2.24384013 -2.01053663 -1.72254657 -1.68113088 -1.52115529 -1.50420039 -1.44944383 -1.28963298 -1.17285569 -1.09438564 -0.96454548 -0.93225057 -0.89696623 -0.72239096 -0.68504408 -0.68377388 -0.67825263 -0.52639141 -0.49955016 -0.48176395 -0.4622459  -0.36417151 -0.34680961 -0.29871452 -0.2910077  -0.27696617 -0.2168901  -0.19547881 -0.18194342 -0.17305181 -0.12275144 -0.08706893 -0.03478116]
# Iter 15: Analysing index 113: Original coord: (33, 2, 0), nearest: (33, 2, 0), jdet: -1.6811308833942236
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5049715922832182
#             Iterations: 96
#             Function evaluations: 5087
#             Gradient evaluations: 96
# Optimisation for index 113 completed in 0.6871199607849121s
# OP result error for index 113: 0.5049715922832182
# Iter 15 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57 193  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.62941814 -7.16521373 -6.11270153 -6.0994166  -5.69108673 -5.50269993 -4.47124691 -4.01163429 -3.38441564 -3.16667928 -3.14469145 -2.24384013 -2.0105104  -1.72254657 -1.68162773 -1.5208251  -1.50420039 -1.44944383 -1.29098588 -1.17285569 -1.09431695 -0.96454548 -0.93215588 -0.89203308 -0.72293483 -0.68508565 -0.68375512 -0.67825263 -0.52639141 -0.49952347 -0.48176395 -0.4622459  -0.41888819 -0.36417151 -0.34680961 -0.29866914 -0.29070972 -0.27696617 -0.2168901  -0.18221205 -0.12275144 -0.08706893 -0.03464026]
# Iter 16: Analysing index 115: Original coord: (35, 2, 0), nearest: (35, 2, 0), jdet: -1.520825097199676
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5048633166495144
#             Iterations: 2
#             Function evaluations: 122
#             Gradient evaluations: 2
# Optimisation for index 115 completed in 0.015518903732299805s
# OP result error for index 115: 0.5048633166495144
# Iter 16 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57 193  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.62952961 -7.16520608 -6.11270262 -6.0994166  -5.69108673 -5.50269993 -4.4712779  -4.01165089 -3.38441564 -3.16667928 -3.14470771 -2.24384013 -2.01052729 -1.72254657 -1.68161715 -1.52080678 -1.50420039 -1.44944383 -1.29102861 -1.17285569 -1.09432522 -0.96454548 -0.93216936 -0.89203802 -0.7229032  -0.68508058 -0.68374703 -0.67825263 -0.52639141 -0.49952223 -0.48176395 -0.4622459  -0.41888322 -0.36417151 -0.34680961 -0.29867976 -0.29071852 -0.27696617 -0.2168901  -0.18221598 -0.12275144 -0.08706893 -0.03462961]
# Iter 17: Analysing index 24: Original coord: (24, 0, 0), nearest: (24, 2, 0), jdet: -1.5042003883223383
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.3686712178452585e-05
#             Iterations: 3
#             Function evaluations: 179
#             Gradient evaluations: 3
# Optimisation for index 24 completed in 0.02284407615661621s
# OP result error for index 24: 5.3686712178452585e-05
# Iter 17 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57 193  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.62952961 -7.16520608 -6.11270262 -6.0994166  -5.69108456 -5.50269993 -4.4712779  -4.01165089 -3.38441528 -3.16667819 -3.14470771 -2.24383702 -2.01052729 -1.72254657 -1.68161715 -1.52080678 -1.50420524 -1.44944248 -1.29102861 -1.17285543 -1.09432522 -0.96455196 -0.93216936 -0.89203802 -0.7229032  -0.68508058 -0.68374703 -0.67824777 -0.52639715 -0.49952223 -0.48176257 -0.4622459  -0.41888322 -0.36417537 -0.34681465 -0.29867976 -0.29071852 -0.27696617 -0.21688952 -0.18221598 -0.12274814 -0.0870746  -0.03462961]
# Iter 18: Analysing index 65: Original coord: (25, 1, 0), nearest: (25, 2, 0), jdet: -1.449442483384214
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.277696483132968e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 65 completed in 0.01563286781311035s
# OP result error for index 65: 2.277696483132968e-05
# Iter 18 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57 193  23 104 194 112  47 106 156  61 103 152] : SITK: [-9.62952961 -7.16520608 -6.11270262 -6.0994166  -5.69108456 -5.50269993 -4.4712779  -4.01165089 -3.38441602 -3.16667819 -3.14470771 -2.24383839 -2.01052729 -1.72254657 -1.68161715 -1.52080678 -1.50420227 -1.44944248 -1.29102861 -1.17285595 -1.09432522 -0.96454799 -0.93216936 -0.89203802 -0.7229032  -0.68508058 -0.68374703 -0.67824991 -0.52639539 -0.49952223 -0.48176257 -0.4622459  -0.41888322 -0.36417419 -0.34681174 -0.29867976 -0.29071852 -0.27696617 -0.2168907  -0.18221598 -0.12274814 -0.08707286 -0.03462961]
# Iter 19: Analysing index 32: Original coord: (32, 0, 0), nearest: (32, 2, 0), jdet: -1.2910286146056607
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.2117024687856817
#             Iterations: 81
#             Function evaluations: 4369
#             Gradient evaluations: 81
# Optimisation for index 32 completed in 0.6236362457275391s
# OP result error for index 32: 1.2117024687856817
# Iter 19 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155  62 153  63 116 105  57  23 104 112  47 106 193 192 195 156  61 103 152] : SITK: [-9.6877802  -7.19606289 -6.11338542 -6.0994166  -5.69108456 -5.50269993 -4.49172064 -4.03685524 -3.38441602 -3.16667819 -3.15048803 -2.24383839 -1.9910897  -1.72254657 -1.65390573 -1.52576105 -1.50420227 -1.44944248 -1.30498733 -1.17285595 -1.09432522 -0.96454799 -0.93216936 -0.90215195 -0.72393805 -0.69712022 -0.67824991 -0.66114069 -0.52639539 -0.49952223 -0.48176257 -0.4622459  -0.36417419 -0.34681174 -0.29529671 -0.27696617 -0.2168907  -0.21540572 -0.19987446 -0.19889138 -0.18221598 -0.12274814 -0.08707286 -0.03610217]
# Iter 20: Analysing index 66: Original coord: (26, 1, 0), nearest: (26, 2, 0), jdet: -1.172855951791301
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6202942009300585e-05
#             Iterations: 3
#             Function evaluations: 180
#             Gradient evaluations: 3
# Optimisation for index 66 completed in 0.02302098274230957s
# OP result error for index 66: 2.6202942009300585e-05
# Iter 20 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155  62 153  63 116 105  57  23 104 112  47 106 193 192 195 156  61 103 152] : SITK: [-9.6877802  -7.19606289 -6.11338542 -6.0994166  -5.69108456 -5.50269993 -4.49172064 -4.03685524 -3.38441536 -3.16667819 -3.15048803 -2.24383839 -1.9910897  -1.72254657 -1.65390573 -1.52576105 -1.50420333 -1.44944248 -1.30498733 -1.17285548 -1.09432522 -0.96454942 -0.93216936 -0.90215195 -0.72393805 -0.69712022 -0.67824991 -0.66114069 -0.52639665 -0.49952223 -0.48176257 -0.4622459  -0.36417504 -0.34681285 -0.29529671 -0.27696617 -0.21688964 -0.21540572 -0.19987446 -0.19889138 -0.18221598 -0.12274814 -0.08707411 -0.03610217]
# Iter 21: Analysing index 36: Original coord: (36, 0, 0), nearest: (36, 2, 0), jdet: -1.0943252181956398
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015701392170811338
#             Iterations: 23
#             Function evaluations: 1285
#             Gradient evaluations: 23
# Optimisation for index 36 completed in 0.1721208095550537s
# OP result error for index 36: 0.00015701392170811338
# Iter 21 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155  62 153  63 116 105  57  23 104 112  47 193 106 192 195 156  61 103 152] : SITK: [-9.6756699  -7.16519773 -6.11270185 -6.0994166  -5.69108456 -5.50269993 -4.47142647 -4.04163363 -3.38441536 -3.16667819 -3.14471248 -2.24383839 -2.01079471 -1.72254657 -1.65944825 -1.52074267 -1.50420333 -1.44944248 -1.30498733 -1.17285548 -1.09432372 -0.96454942 -0.93216616 -0.90237459 -0.72393805 -0.68507226 -0.67824991 -0.65253584 -0.52639665 -0.49952058 -0.48176257 -0.4622459  -0.36417504 -0.34681285 -0.29529671 -0.27696617 -0.21953262 -0.21688964 -0.19987446 -0.19480278 -0.18225102 -0.12274814 -0.08707411 -0.03610217]
# Iter 22: Analysing index 64: Original coord: (24, 1, 0), nearest: (24, 2, 0), jdet: -0.9645494163875323
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.223186376992643e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 64 completed in 0.023181915283203125s
# OP result error for index 64: 2.223186376992643e-05
# Iter 22 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155  62 153  63 116 105  57  23 104 112  47 193 106 192 195 156  61 103 152] : SITK: [-9.6756699  -7.16519773 -6.11270185 -6.0994166  -5.69108674 -5.50269993 -4.47142647 -4.04163363 -3.38441572 -3.16667819 -3.14471248 -2.24383703 -2.01079471 -1.72254657 -1.65944825 -1.52074267 -1.50420333 -1.44944248 -1.30498733 -1.17285574 -1.09432372 -0.96454942 -0.93216616 -0.90237459 -0.72393805 -0.68507226 -0.67824779 -0.65253584 -0.52639317 -0.49952058 -0.48176257 -0.4622459  -0.3641727  -0.34681285 -0.29529671 -0.27696617 -0.21953262 -0.21689018 -0.19987446 -0.19480278 -0.18225102 -0.12275145 -0.08707067 -0.03610217]
# Iter 23: Analysing index 76: Original coord: (36, 1, 0), nearest: (36, 2, 0), jdet: -0.932166155744971
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.16493297556627e-05
#             Iterations: 7
#             Function evaluations: 415
#             Gradient evaluations: 7
# Optimisation for index 76 completed in 0.055548906326293945s
# OP result error for index 76: 3.16493297556627e-05
# Iter 23 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155  62 153  63 116 105  57  23 104 112  47 193 106 192 195 156  61 103 152] : SITK: [-9.67566992 -7.16525334 -6.11270352 -6.0994166  -5.69108674 -5.50269993 -4.47139498 -4.04161464 -3.38441572 -3.16667819 -3.14469661 -2.24383703 -2.01077138 -1.72254657 -1.6594612  -1.52075652 -1.50420333 -1.44944248 -1.30498733 -1.17285574 -1.09432087 -0.96454942 -0.93216616 -0.90238238 -0.72393805 -0.68508985 -0.67824779 -0.65252776 -0.52639317 -0.49952065 -0.48176257 -0.4622459  -0.3641727  -0.34681285 -0.29529671 -0.27696617 -0.21952375 -0.21689018 -0.19987446 -0.1948111  -0.1822477  -0.12275145 -0.08707067 -0.03610217]
# Iter 24: Analysing index 154: Original coord: (34, 3, 0), nearest: (34, 3, 0), jdet: -0.9023823783004863
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.56977839147478
#             Iterations: 8
#             Function evaluations: 449
#             Gradient evaluations: 8
# Optimisation for index 154 completed in 0.06015634536743164s
# OP result error for index 154: 0.56977839147478
# Iter 24 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 153 155  62  63 116 105  57 194  23 104 112  47 106 195 156  61 103 152 193] : SITK: [-9.68865522 -7.16526717 -6.11271726 -6.0994166  -5.69108674 -5.50269993 -4.47229275 -4.00743034 -3.38441572 -3.16667819 -3.14469884 -2.24383703 -2.01245418 -1.72254657 -1.68814055 -1.52075727 -1.50420333 -1.44944248 -1.30768219 -1.17285574 -1.09432285 -0.96454942 -0.93215898 -0.87420694 -0.7116724  -0.70105515 -0.68509418 -0.67824779 -0.52639317 -0.49951747 -0.48176257 -0.4622459  -0.36997445 -0.3641727  -0.34681285 -0.30286801 -0.27696617 -0.21689018 -0.19481173 -0.18224278 -0.12275145 -0.08707067 -0.05556195 -0.03226828]
# Iter 25: Analysing index 72: Original coord: (32, 1, 0), nearest: (32, 2, 0), jdet: -0.7116723991880289
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.7141452273622496
#             Iterations: 56
#             Function evaluations: 2995
#             Gradient evaluations: 56
# Optimisation for index 72 completed in 0.4011538028717041s
# OP result error for index 72: 0.7141452273622496
# Iter 25 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 112  47 106 195 192 156 193  61 103 152] : SITK: [-9.63039128 -7.16529294 -6.11271745 -6.0994166  -5.69108674 -5.50269993 -4.47125484 -4.01205371 -3.38441572 -3.16667819 -3.14470326 -2.24383703 -2.0103187  -1.72254657 -1.68160842 -1.52075692 -1.50420333 -1.44944248 -1.2916303  -1.17285574 -1.09432285 -0.96454942 -0.93215898 -0.89706141 -0.72309745 -0.68516848 -0.68131732 -0.67824779 -0.52639317 -0.49951747 -0.48176257 -0.4622459  -0.3641727  -0.34681285 -0.2907408  -0.27696617 -0.21689018 -0.19481167 -0.19120981 -0.18224278 -0.17365568 -0.12275145 -0.08707067 -0.03467815]
# Iter 26: Analysing index 155: Original coord: (35, 3, 0), nearest: (35, 3, 0), jdet: -0.6851684758646083
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00959650885544025
#             Iterations: 17
#             Function evaluations: 983
#             Gradient evaluations: 17
# Optimisation for index 155 completed in 0.13014698028564453s
# OP result error for index 155: 0.00959650885544025
# Iter 26 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63057611 -7.1653138  -6.11258699 -6.0994166  -5.69108674 -5.50269993 -4.47123267 -4.01196122 -3.38441572 -3.16667819 -3.1446125  -2.24383703 -2.01087075 -1.72254657 -1.68162869 -1.52080813 -1.50420333 -1.44944248 -1.2916303  -1.17285574 -1.094304   -0.96454942 -0.93221485 -0.89704998 -0.72293558 -0.6849932  -0.68361932 -0.67824779 -0.52639317 -0.49954231 -0.48176257 -0.4622459  -0.3641727  -0.34681285 -0.30170714 -0.29078581 -0.27696617 -0.21689018 -0.19482767 -0.18225845 -0.1736568  -0.12275145 -0.08707067 -0.03464681]
# Iter 27: Analysing index 153: Original coord: (33, 3, 0), nearest: (33, 3, 0), jdet: -0.683619318895276
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0011782344390643684
#             Iterations: 12
#             Function evaluations: 700
#             Gradient evaluations: 12
# Optimisation for index 153 completed in 0.10730600357055664s
# OP result error for index 153: 0.0011782344390643684
# Iter 27 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63041085 -7.16527415 -6.11270368 -6.0994166  -5.69108674 -5.50269993 -4.47126106 -4.01201576 -3.38441572 -3.16667819 -3.14468961 -2.24383703 -2.01040512 -1.72254657 -1.68159288 -1.52075653 -1.50420333 -1.44944248 -1.29162507 -1.17285574 -1.094304   -0.96454942 -0.93213948 -0.89714186 -0.72289455 -0.68512726 -0.68380508 -0.67824779 -0.52639317 -0.49951727 -0.48176257 -0.4622459  -0.3641727  -0.34681285 -0.29906521 -0.29069146 -0.27696617 -0.21689018 -0.19482146 -0.1822457  -0.17367572 -0.12275145 -0.08707067 -0.03457144]
# Iter 28: Analysing index 62: Original coord: (22, 1, 0), nearest: (22, 2, 0), jdet: -0.6782477949911587
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.930129717238164e-06
#             Iterations: 13
#             Function evaluations: 727
#             Gradient evaluations: 13
# Optimisation for index 62 completed in 0.09444308280944824s
# OP result error for index 62: 4.930129717238164e-06
# Iter 28 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63041085 -7.16527415 -6.11270368 -6.0994166  -5.69108364 -5.50269993 -4.47126106 -4.01201576 -3.38441572 -3.16667786 -3.14468961 -2.2438379  -2.01040512 -1.72254657 -1.68159288 -1.52075653 -1.50420254 -1.44944207 -1.29162507 -1.17285574 -1.094304   -0.96454835 -0.93213948 -0.89714186 -0.72289455 -0.68512726 -0.68380508 -0.67824915 -0.52639404 -0.49951727 -0.48176215 -0.4622459  -0.36417328 -0.34681159 -0.29906521 -0.29069146 -0.27696617 -0.21689018 -0.19482146 -0.1822457  -0.17367572 -0.12274675 -0.08707153 -0.03457144]
# Iter 29: Analysing index 63: Original coord: (23, 1, 0), nearest: (23, 2, 0), jdet: -0.5263940391217264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.346051619238629e-05
#             Iterations: 2
#             Function evaluations: 123
#             Gradient evaluations: 2
# Optimisation for index 63 completed in 0.015646934509277344s
# OP result error for index 63: 4.346051619238629e-05
# Iter 29 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63041085 -7.16527415 -6.11270368 -6.0994166  -5.69108194 -5.50269993 -4.47126106 -4.01201576 -3.38441544 -3.16667851 -3.14468961 -2.24384    -2.01040512 -1.72254657 -1.68159288 -1.52075653 -1.50420254 -1.44944287 -1.29162507 -1.17285554 -1.094304   -0.96454835 -0.93213948 -0.89714186 -0.72289455 -0.68512726 -0.68380508 -0.67825243 -0.52639404 -0.49951727 -0.48176294 -0.4622459  -0.36417328 -0.3468118  -0.29906521 -0.29069146 -0.27696617 -0.21688973 -0.19482146 -0.1822457  -0.17367572 -0.12274417 -0.08707153 -0.03457144]
# Iter 30: Analysing index 116: Original coord: (36, 2, 0), nearest: (36, 2, 0), jdet: -0.4995172692422251
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00041383760771756037
#             Iterations: 13
#             Function evaluations: 766
#             Gradient evaluations: 13
# Optimisation for index 116 completed in 0.10515499114990234s
# OP result error for index 116: 0.00041383760771756037
# Iter 30 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108194 -5.50269993 -4.47125805 -4.01200316 -3.38441544 -3.16667851 -3.14468125 -2.24384    -2.01049547 -1.72254657 -1.68160346 -1.52076338 -1.50420254 -1.44944287 -1.29162507 -1.17285554 -1.09433484 -0.96454835 -0.9321986  -0.89715277 -0.72289455 -0.68508221 -0.68376185 -0.67825243 -0.52639404 -0.49953004 -0.48176294 -0.4622459  -0.36417328 -0.3468118  -0.29904779 -0.29069146 -0.27696617 -0.21688973 -0.19481134 -0.18223832 -0.1736597  -0.12274417 -0.08707153 -0.03457144]
# Iter 31: Analysing index 105: Original coord: (25, 2, 0), nearest: (25, 2, 0), jdet: -0.4817629364351454
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0003263358902060418
#             Iterations: 7
#             Function evaluations: 406
#             Gradient evaluations: 7
# Optimisation for index 105 completed in 0.052720069885253906s
# OP result error for index 105: 0.0003263358902060418
# Iter 31 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108194 -5.50269993 -4.47125805 -4.01200316 -3.38442108 -3.16668202 -3.14468125 -2.24383523 -2.01049547 -1.72254657 -1.68160346 -1.52076338 -1.50419633 -1.44944722 -1.29162507 -1.17285956 -1.09433484 -0.96454006 -0.9321986  -0.89715277 -0.72289455 -0.68508221 -0.68376185 -0.67824498 -0.52640019 -0.49953004 -0.48176368 -0.4622459  -0.36417742 -0.34680445 -0.29904779 -0.29069146 -0.27696617 -0.21689882 -0.19481134 -0.18223832 -0.1736597  -0.12274417 -0.0870776  -0.03457144]
# Iter 32: Analysing index 57: Original coord: (17, 1, 0), nearest: (17, 2, 0), jdet: -0.4622459029790216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7224377975358754e-05
#             Iterations: 2
#             Function evaluations: 119
#             Gradient evaluations: 2
# Optimisation for index 57 completed in 0.015246868133544922s
# OP result error for index 57: 2.7224377975358754e-05
# Iter 32 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108194 -5.50269984 -4.47125805 -4.01200316 -3.38442108 -3.16668202 -3.14468125 -2.24383523 -2.01049547 -1.72254657 -1.68160346 -1.52076338 -1.50419633 -1.44944722 -1.29162507 -1.17285956 -1.09433484 -0.96454006 -0.9321986  -0.89715277 -0.72289455 -0.68508221 -0.68376185 -0.67824498 -0.52640019 -0.49953004 -0.48176368 -0.4622459  -0.36417742 -0.34680445 -0.29904779 -0.29069146 -0.27696617 -0.21689882 -0.19481134 -0.18223832 -0.1736597  -0.12274417 -0.0870776  -0.03457144]
# Iter 33: Analysing index 23: Original coord: (23, 0, 0), nearest: (23, 2, 0), jdet: -0.36417742002198444
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015075307048364984
#             Iterations: 5
#             Function evaluations: 305
#             Gradient evaluations: 5
# Optimisation for index 23 completed in 0.04197096824645996s
# OP result error for index 23: 0.00015075307048364984
# Iter 33 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108692 -5.50269984 -4.47125805 -4.01200316 -3.3844165  -3.16668599 -3.14468125 -2.2438386  -2.01049547 -1.72254657 -1.68160346 -1.52076338 -1.50420782 -1.44945212 -1.29162507 -1.1728563  -1.09433484 -0.96455542 -0.9321986  -0.89715277 -0.72289455 -0.68508221 -0.68376185 -0.67825024 -0.52638791 -0.49953004 -0.48177462 -0.4622459  -0.36416916 -0.34681807 -0.29904779 -0.29069146 -0.27696617 -0.21689144 -0.19481134 -0.18223832 -0.1736597  -0.12275172 -0.08706548 -0.03457144]
# Iter 34: Analysing index 104: Original coord: (24, 2, 0), nearest: (24, 2, 0), jdet: -0.3468180724534111
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4799726198790325e-05
#             Iterations: 8
#             Function evaluations: 466
#             Gradient evaluations: 8
# Optimisation for index 104 completed in 0.05997920036315918s
# OP result error for index 104: 2.4799726198790325e-05
# Iter 34 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108374 -5.50269984 -4.47125805 -4.01200316 -3.38441833 -3.16667788 -3.14468125 -2.24383624 -2.01049547 -1.72254657 -1.68160346 -1.52076338 -1.50420299 -1.44944209 -1.29162507 -1.1728576  -1.09433484 -0.96454896 -0.9321986  -0.89715277 -0.72289455 -0.68508221 -0.68376185 -0.67824656 -0.52639349 -0.49953004 -0.48176222 -0.4622459  -0.36417291 -0.34681234 -0.29904779 -0.29069146 -0.27696617 -0.21689438 -0.19481134 -0.18223832 -0.1736597  -0.12274689 -0.08707098 -0.03457144]
# Iter 35: Analysing index 194: Original coord: (34, 4, 0), nearest: (34, 4, 0), jdet: -0.2990477892843463
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0018051563972052709
#             Iterations: 7
#             Function evaluations: 412
#             Gradient evaluations: 7
# Optimisation for index 194 completed in 0.06586813926696777s
# OP result error for index 194: 0.0018051563972052709
# Iter 35 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63040951 -7.16532484 -6.11270021 -6.0994166  -5.69108374 -5.50269984 -4.47125861 -4.01200032 -3.38441833 -3.16667788 -3.14468165 -2.24383624 -2.01049283 -1.72254657 -1.68177972 -1.52075952 -1.50420299 -1.44944209 -1.29162507 -1.1728576  -1.09433484 -0.96454896 -0.9321943  -0.89702154 -0.72297692 -0.68501531 -0.68374771 -0.67824656 -0.52639349 -0.49947762 -0.48176222 -0.4622459  -0.36417291 -0.34681234 -0.29860529 -0.29069338 -0.27696617 -0.21689438 -0.19481228 -0.18225075 -0.17367147 -0.12274689 -0.08707098 -0.03467745]
# Iter 36: Analysing index 112: Original coord: (32, 2, 0), nearest: (32, 2, 0), jdet: -0.29069338189632715
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.7133504790199785
#             Iterations: 27
#             Function evaluations: 1559
#             Gradient evaluations: 27
# Optimisation for index 112 completed in 0.20024514198303223s
# OP result error for index 112: 0.7133504790199785
# Iter 36 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 112  47 106 195 192 156 193  61 103 152] : SITK: [-9.63055998 -7.16526704 -6.11269749 -6.0994166  -5.69108374 -5.50269984 -4.4712526  -4.01209709 -3.38441833 -3.16667788 -3.14470565 -2.24383624 -2.01050064 -1.72254657 -1.68162279 -1.52075761 -1.50420299 -1.44944209 -1.29162526 -1.1728576  -1.09433484 -0.96454896 -0.9321943  -0.897088   -0.72291938 -0.68502138 -0.68123361 -0.67824656 -0.52639349 -0.49947762 -0.48176222 -0.4622459  -0.36417291 -0.34681234 -0.2906972  -0.27696617 -0.21689438 -0.19481352 -0.19121326 -0.18225075 -0.17366712 -0.12274689 -0.08707098 -0.03462741]
# Iter 37: Analysing index 47: Original coord: (7, 1, 0), nearest: (7, 2, 0), jdet: -0.27696617089886694
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.763079995875309e-06
#             Iterations: 1
#             Function evaluations: 62
#             Gradient evaluations: 1
# Optimisation for index 47 completed in 0.007982015609741211s
# OP result error for index 47: 2.763079995875309e-06
# Iter 37 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 112  47 106 195 192 156 193  61 103 152] : SITK: [-9.63055998 -7.16526704 -6.11269749 -6.0994166  -5.69108374 -5.50269984 -4.4712526  -4.01209709 -3.38441833 -3.16667788 -3.14470565 -2.24383624 -2.01050064 -1.72254657 -1.68162279 -1.52075761 -1.50420299 -1.44944209 -1.29162526 -1.1728576  -1.09433484 -0.96454896 -0.9321943  -0.897088   -0.72291938 -0.68502138 -0.68123361 -0.67824656 -0.52639349 -0.49947762 -0.48176222 -0.4622459  -0.36417291 -0.34681234 -0.2906972  -0.27696617 -0.21689438 -0.19481352 -0.19121326 -0.18225075 -0.17366712 -0.12274689 -0.08707098 -0.03462741]
# Iter 38: Analysing index 106: Original coord: (26, 2, 0), nearest: (26, 2, 0), jdet: -0.21689438250461196
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.858864139680016e-05
#             Iterations: 5
#             Function evaluations: 304
#             Gradient evaluations: 5
# Optimisation for index 106 completed in 0.040107011795043945s
# OP result error for index 106: 6.858864139680016e-05
# Iter 38 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 112  47 106 195 192 156 193  61 103 152] : SITK: [-9.63055998 -7.16526704 -6.11269749 -6.0994166  -5.69108374 -5.50269984 -4.4712526  -4.01209709 -3.38441543 -3.16667788 -3.14470565 -2.24383624 -2.01050064 -1.72254657 -1.68162279 -1.52075761 -1.50420123 -1.44944209 -1.29162526 -1.17285553 -1.09433484 -0.96454661 -0.9321943  -0.897088   -0.72291938 -0.68502138 -0.68123361 -0.67824656 -0.52639557 -0.49947762 -0.48176222 -0.4622459  -0.36417431 -0.34681053 -0.2906972  -0.27696617 -0.21688971 -0.19481352 -0.19121326 -0.18225075 -0.17366712 -0.12274689 -0.08707304 -0.03462741]
# Iter 39: Analysing index 195: Original coord: (35, 4, 0), nearest: (35, 4, 0), jdet: -0.19481351997394056
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.01759823879570699
#             Iterations: 13
#             Function evaluations: 752
#             Gradient evaluations: 13
# Optimisation for index 195 completed in 0.1012580394744873s
# OP result error for index 195: 0.01759823879570699
# Iter 39 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63055998 -7.16526704 -6.11269749 -6.0994166  -5.69108374 -5.50269984 -4.47125331 -4.01209785 -3.38441543 -3.16667788 -3.14470622 -2.24383624 -2.01050829 -1.72254657 -1.68162273 -1.5207577  -1.50420123 -1.44944209 -1.29162526 -1.17285553 -1.09433484 -0.96454661 -0.93219462 -0.89708764 -0.72291938 -0.68510359 -0.68370376 -0.67824656 -0.52639557 -0.49952909 -0.48176222 -0.4622459  -0.36417431 -0.34681053 -0.29097009 -0.2906968  -0.27696617 -0.21688971 -0.19481316 -0.18226238 -0.17366741 -0.12274689 -0.08707304 -0.03463059]
# Iter 40: Analysing index 156: Original coord: (36, 3, 0), nearest: (36, 3, 0), jdet: -0.1822623793649194
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.00015856603395489333
#             Iterations: 11
#             Function evaluations: 646
#             Gradient evaluations: 11
# Optimisation for index 156 completed in 0.08926796913146973s
# OP result error for index 156: 0.00015856603395489333
# Iter 40 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63055998 -7.16527196 -6.11269556 -6.0994166  -5.69108374 -5.50269984 -4.47125468 -4.01209573 -3.38441543 -3.16667788 -3.14470028 -2.24383624 -2.01050806 -1.72254657 -1.68162193 -1.52075807 -1.50420123 -1.44944209 -1.29162526 -1.17285553 -1.09432942 -0.96454661 -0.93217361 -0.89708199 -0.72291938 -0.68509597 -0.68369803 -0.67824656 -0.52639557 -0.49952308 -0.48176222 -0.4622459  -0.36417431 -0.34681053 -0.29096989 -0.2906968  -0.27696617 -0.21688971 -0.19481266 -0.18225417 -0.17366791 -0.12274689 -0.08707304 -0.03463059]
# Iter 41: Analysing index 193: Original coord: (33, 4, 0), nearest: (33, 4, 0), jdet: -0.17366791048951963
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.001378993822196875
#             Iterations: 7
#             Function evaluations: 411
#             Gradient evaluations: 7
# Optimisation for index 193 completed in 0.05456423759460449s
# OP result error for index 193: 0.001378993822196875
# Iter 41 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63055998 -7.16527196 -6.11269556 -6.0994166  -5.69108374 -5.50269984 -4.47125123 -4.01209206 -3.38441543 -3.16667788 -3.14469746 -2.24383624 -2.0105171  -1.72254657 -1.68160527 -1.52075906 -1.50420123 -1.44944209 -1.29162526 -1.17285553 -1.09432942 -0.96454661 -0.93217361 -0.89709354 -0.72291336 -0.68508596 -0.683757   -0.67824656 -0.52639557 -0.4995243  -0.48176222 -0.4622459  -0.36417431 -0.34681053 -0.2985694  -0.29069285 -0.27696617 -0.21688971 -0.19481344 -0.18224444 -0.17366643 -0.12274689 -0.08707304 -0.03462684]
# Iter 42: Analysing index 61: Original coord: (21, 1, 0), nearest: (21, 2, 0), jdet: -0.12274689207735232
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.479664475696292e-05
#             Iterations: 5
#             Function evaluations: 295
#             Gradient evaluations: 5
# Optimisation for index 61 completed in 0.03812384605407715s
# OP result error for index 61: 1.479664475696292e-05
# Iter 42 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63055998 -7.16527196 -6.11269556 -6.0994166  -5.69108336 -5.50269985 -4.47125123 -4.01209206 -3.38441543 -3.16667788 -3.14469746 -2.24383753 -2.0105171  -1.72254657 -1.68160527 -1.52075906 -1.50420138 -1.44944209 -1.29162526 -1.17285553 -1.09432942 -0.9645468  -0.93217361 -0.89709354 -0.72291336 -0.68508596 -0.683757   -0.67824858 -0.5263957  -0.4995243  -0.48176222 -0.4622459  -0.3641744  -0.34681068 -0.2985694  -0.29069285 -0.27696617 -0.21688971 -0.19481344 -0.18224444 -0.17366643 -0.12274633 -0.08707327 -0.03462684]
# Iter 43: Analysing index 103: Original coord: (23, 2, 0), nearest: (23, 2, 0), jdet: -0.08707327249995075
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.964449377223402e-05
#             Iterations: 5
#             Function evaluations: 295
#             Gradient evaluations: 5
# Optimisation for index 103 completed in 0.03760194778442383s
# OP result error for index 103: 2.964449377223402e-05
# Iter 43 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63055998 -7.16527196 -6.11269556 -6.0994166  -5.69108483 -5.50269985 -4.47125123 -4.01209206 -3.38441517 -3.16667843 -3.14469746 -2.24383859 -2.0105171  -1.72254657 -1.68160527 -1.52075906 -1.50420145 -1.44944277 -1.29162526 -1.17285535 -1.09432942 -0.9645469  -0.93217361 -0.89709354 -0.72291336 -0.68508596 -0.683757   -0.67825023 -0.52639338 -0.4995243  -0.48176287 -0.4622459  -0.36417284 -0.34681078 -0.2985694  -0.29069285 -0.27696617 -0.21688928 -0.19481344 -0.18224444 -0.17366643 -0.12274856 -0.08707091 -0.03462684]
# Iter 44: Analysing index 152: Original coord: (32, 3, 0), nearest: (32, 3, 0), jdet: -0.0346268387169824
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.703944563325349e-05
#             Iterations: 8
#             Function evaluations: 475
#             Gradient evaluations: 8
# Optimisation for index 152 completed in 0.06055569648742676s
# OP result error for index 152: 7.703944563325349e-05
# Iter 44 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63056571 -7.16528444 -6.11269556 -6.0994166  -5.69108483 -5.50269985 -4.4712541  -4.0120852  -3.38441517 -3.16667843 -3.14469271 -2.24383859 -2.01050834 -1.72254657 -1.68161087 -1.5207589  -1.50420145 -1.44944277 -1.2916233  -1.17285535 -1.09432942 -0.9645469  -0.93217361 -0.89709169 -0.72290499 -0.68509887 -0.68374655 -0.67825023 -0.52639338 -0.4995243  -0.48176287 -0.4622459  -0.36417284 -0.34681078 -0.29866231 -0.29069514 -0.27696617 -0.21688928 -0.19481304 -0.18224444 -0.17366749 -0.12274856 -0.08707091 -0.03462869]
# Iter 45: Analysing index 33: Original coord: (33, 0, 0), nearest: (33, 2, 0), jdet: -9.630565710359233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6890891373809396
#             Iterations: 506
#             Function evaluations: 26509
#             Gradient evaluations: 506
# Optimisation for index 33 completed in 3.570563793182373s
# OP result error for index 33: 2.6890891373809396
# Iter 45 end: 43 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36 156  64  76  72 155 153  62  63 116 105 193  57  23 104 194 112  47 106  61 103 152 154] : SITK: [-9.63135299 -7.16211763 -6.11243815 -6.0994166  -5.69108483 -5.50269985 -4.47076651 -4.01217802 -3.38441517 -3.16667843 -3.14739076 -2.24383859 -2.01001888 -1.72254657 -1.68038412 -1.57568709 -1.50420145 -1.44944277 -1.29380438 -1.17285535 -1.09431834 -0.97166169 -0.9645469  -0.93177858 -0.72251288 -0.68448253 -0.68338013 -0.67825023 -0.52639338 -0.4973994  -0.48176287 -0.46584549 -0.4622459  -0.36417284 -0.34681078 -0.29905861 -0.29113793 -0.27696617 -0.21688928 -0.12274856 -0.08707091 -0.03487605 -0.03442196]
# Iter 46: Analysing index 34: Original coord: (34, 0, 0), nearest: (34, 2, 0), jdet: -7.162117629529963
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.004851060558571547
#             Iterations: 51
#             Function evaluations: 2795
#             Gradient evaluations: 51
# Optimisation for index 34 completed in 0.38307881355285645s
# OP result error for index 34: 0.004851060558571547
# Iter 46 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63074224 -7.16487401 -6.11303034 -6.0994166  -5.69108483 -5.50269985 -4.47101047 -4.01223683 -3.38441517 -3.16667843 -3.14472043 -2.24383859 -2.01049127 -1.72254657 -1.68136493 -1.52064446 -1.50420145 -1.44944277 -1.29472234 -1.17285535 -1.09447048 -0.9645469  -0.93236901 -0.89710561 -0.72275137 -0.68521221 -0.6836556  -0.67825023 -0.52639338 -0.49958878 -0.48176287 -0.4622459  -0.36417284 -0.34681078 -0.29865643 -0.29082038 -0.27696617 -0.21688928 -0.1949933  -0.18239785 -0.17357061 -0.12274856 -0.08707091 -0.03466957]
# Iter 47: Analysing index 35: Original coord: (35, 0, 0), nearest: (35, 2, 0), jdet: -6.113030335735356
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.0006225008770257319
#             Iterations: 11
#             Function evaluations: 638
#             Gradient evaluations: 11
# Optimisation for index 35 completed in 0.08242678642272949s
# OP result error for index 35: 0.0006225008770257319
# Iter 47 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63072558 -7.16524787 -6.11271332 -6.0994166  -5.69108483 -5.50269985 -4.47120827 -4.01197564 -3.38441517 -3.16667843 -3.14467214 -2.24383859 -2.01050262 -1.72254657 -1.68147562 -1.52072705 -1.50420145 -1.44944277 -1.29450342 -1.17285535 -1.09432328 -0.9645469  -0.93219287 -0.89710202 -0.72267087 -0.68514334 -0.68367638 -0.67825023 -0.52639338 -0.49952982 -0.48176287 -0.4622459  -0.36417284 -0.34681078 -0.29867095 -0.29085471 -0.27696617 -0.21688928 -0.194831   -0.18227031 -0.17371854 -0.12274856 -0.08707091 -0.03469181]
# Iter 48: Analysing index 17: Original coord: (17, 0, 0), nearest: (17, 2, 0), jdet: -6.0994166043679385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.431165785352432e-06
#             Iterations: 6
#             Function evaluations: 334
#             Gradient evaluations: 6
# Optimisation for index 17 completed in 0.04320120811462402s
# OP result error for index 17: 3.431165785352432e-06
# Iter 48 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63072558 -7.16524787 -6.11271332 -6.0994166  -5.69108483 -5.5026999  -4.47120827 -4.01197564 -3.38441517 -3.16667843 -3.14467214 -2.24383859 -2.01050262 -1.72254657 -1.68147562 -1.52072705 -1.50420145 -1.44944277 -1.29450342 -1.17285535 -1.09432328 -0.9645469  -0.93219287 -0.89710202 -0.72267087 -0.68514334 -0.68367638 -0.67825023 -0.52639338 -0.49952982 -0.48176287 -0.4622459  -0.36417284 -0.34681078 -0.29867095 -0.29085471 -0.27696617 -0.21688928 -0.194831   -0.18227031 -0.17371854 -0.12274856 -0.08707091 -0.03469181]
# Iter 49: Analysing index 21: Original coord: (21, 0, 0), nearest: (21, 2, 0), jdet: -5.691084834564451
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6328755019865208e-05
#             Iterations: 8
#             Function evaluations: 458
#             Gradient evaluations: 8
# Optimisation for index 21 completed in 0.058741092681884766s
# OP result error for index 21: 2.6328755019865208e-05
# Iter 49 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63072558 -7.16524787 -6.11271332 -6.0994166  -5.69108469 -5.50269995 -4.47120827 -4.01197564 -3.38441517 -3.16667843 -3.14467214 -2.24383773 -2.01050262 -1.72254657 -1.68147562 -1.52072705 -1.50420269 -1.44944277 -1.29450342 -1.17285535 -1.09432328 -0.96454856 -0.93219287 -0.89710202 -0.72267087 -0.68514334 -0.68367638 -0.67824889 -0.5263947  -0.49952982 -0.48176287 -0.4622459  -0.36417373 -0.34681207 -0.29867095 -0.29085471 -0.27696617 -0.21688928 -0.194831   -0.18227031 -0.17371854 -0.12274834 -0.08707211 -0.03469181]
# Iter 50: Analysing index 18: Original coord: (18, 0, 0), nearest: (18, 2, 0), jdet: -5.502699946983315
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.501640248984959e-06
#             Iterations: 6
#             Function evaluations: 333
#             Gradient evaluations: 6
# Optimisation for index 18 completed in 0.0530552864074707s
# OP result error for index 18: 2.501640248984959e-06
# Iter 50 end: 44 -ve jacs now at [ 33  34  35  17  21  18  74  73  26  25  75  22 114  48 113 115  24  65  32  66  36  64  76 154  72 155 153  62  63 116 105  57  23 104 194 112  47 106 195 156 193  61 103 152] : SITK: [-9.63072558 -7.16524787 -6.11271332 -6.0994166  -5.691083   -5.50269989 -4.47120827 -4.01197564 -3.38441517 -3.16667843 -3.14467214 -2.24383773 -2.01050262 -1.72254657 -1.68147562 -1.52072705 -1.50420269 -1.44944277 -1.29450342 -1.17285535 -1.09432328 -0.96454856 -0.93219287 -0.89710202 -0.72267087 -0.68514334 -0.68367638 -0.67824889 -0.5263947  -0.49952982 -0.48176287 -0.4622459  -0.36417373 -0.34681207 -0.29867095 -0.29085471 -0.27696617 -0.21688928 -0.194831   -0.18227031 -0.17371854 -0.12274577 -0.08707211 -0.03469181]
# Total time taken for iterative SLSQP : 9.29584813117981 split as [0.2929871082305908, 0.1202399730682373, 0.05484175682067871, 0.05382680892944336, 0.016019821166992188, 0.024016141891479492, 0.0817420482635498, 0.44696593284606934, 0.04300093650817871, 0.008361339569091797, 0.20474910736083984, 0.029855966567993164, 0.0859529972076416, 0.0436558723449707, 0.6871199607849121, 0.015518903732299805, 0.02284407615661621, 0.01563286781311035, 0.6236362457275391, 0.02302098274230957, 0.1721208095550537, 0.023181915283203125, 0.055548906326293945, 0.06015634536743164, 0.4011538028717041, 0.13014698028564453, 0.10730600357055664, 0.09444308280944824, 0.015646934509277344, 0.10515499114990234, 0.052720069885253906, 0.015246868133544922, 0.04197096824645996, 0.05997920036315918, 0.06586813926696777, 0.20024514198303223, 0.007982015609741211, 0.040107011795043945, 0.1012580394744873, 0.08926796913146973, 0.05456423759460449, 0.03812384605407715, 0.03760194778442383, 0.06055569648742676, 3.570563793182373, 0.38307881355285645, 0.08242678642272949, 0.04320120811462402, 0.058741092681884766, 0.0530552864074707]
# Initial error: 94.79153304700242, final error: 94.79633367169129, deviation: 0.006583358259033737
# /var/folders/pj/ny1dgkl90cj0mpph_t0mvd000000gn/T/ipykernel_36746/1233820171.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
#              x-def                   y-def            jacobian
#                min       max           min       max       min        max
# initial -13.000722  29.00161  0.000000e+00  0.999538 -9.630561  14.027545
# final   -13.000715  29.00161 -3.876664e-07  0.999602 -9.630726  14.027545
# meshgrid shape for plot: (20, 40)

# %% [markdown]
# ## Real slice

# %%
# # data analysis

# # Create sample set of points
# mpoints_path = "../data/corrected_correspondences_count_touching/mpoints.npy"
# fpoints_path = "../data/corrected_correspondences_count_touching/fpoints.npy"

# mpoints, fpoints = correspondences.downsample_points(mpoints_path, fpoints_path, debug=False)
# #print(mpoints.shape, fpoints.shape) 

# deformation_field_path = "../data/base_unique_correspondences/registered_output/deformation3d.npy"
# deformation_field = np.load(deformation_field_path)

# # select a slice
# def_shape = deformation_field.shape
# print(def_shape)
# deformation_i = deformation_field[:, 349].reshape((def_shape[0], 1, def_shape[2], def_shape[3]))
# print(deformation_i.shape)
# # z values in mpoints, fpoints are for 3 slices numbered 0,1,2
# slice_no = 0

# # use 
# mask = mpoints[:,0]==slice_no
# new_mpoints = mpoints[mask].copy()
# new_mpoints[:,0] = 0

# mask = fpoints[:,0]==slice_no
# new_fpoints = fpoints[mask].copy()
# new_fpoints[:,0] = 0

# print(new_mpoints.shape, new_fpoints.shape)

# phi_corrected, jacobians = iterative_with_jacobians(deformation_i)
# plot_jacobians_iteratively(jacobians, msample, fsample, methodName='SLSQP')
# plot_deformations(msample, fsample, deformation_i, phi_corrected, figsize=(10,10))
# # kept running for 450min

# %% [markdown]
# ## Jdet function testing
